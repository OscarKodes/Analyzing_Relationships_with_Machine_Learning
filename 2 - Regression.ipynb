# %% [markdown]
# # Regression
#
# By: Oscar Ko
#
# This notebook was created for data analysis and classification on this dataset from Stanford:
#
# https://data.stanford.edu/hcmst2017
#
# ---
# ---

# %% [markdown]
# # Step 1: Imports and Data

# %%
import numpy as np
import pandas as pd

import warnings
warnings.filterwarnings('ignore')


df = pd.read_csv("data/df_renamed.csv")

print(df.shape, "\n")

df.info(verbose=True)
# Out:
# (2844, 75)
#
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2844 entries, 0 to 2843
# Data columns (total 75 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   Unnamed: 0                        2844 non-null   int64
#  1   ID                                2844 non-null   int64
#  2   ageGap                            2844 non-null   float64
#  3   attendReligiousServiceFreq        2844 non-null   object
#  4   employmentStatus                  2844 non-null   object
#  5   genderSubjectAttractedTo          2837 non-null   object
#  6   houseType                         2844 non-null   object
#  7   householdAdults_num               2844 non-null   int64
#  8   householdIncome                   2844 non-null   int64
#  9   householdMinor_num                2844 non-null   int64
#  10  householdSize                     2844 non-null   int64
#  11  interracial                       2822 non-null   object
#  12  isHispanic                        2844 non-null   bool
#  13  isLivingTogether                  2844 non-null   object
#  14  isMarried                         2844 non-null   object
#  15  isMetroArea                       2844 non-null   object
#  16  metAs_coworkers                   2780 non-null   object
#  17  metAs_customerAndClient           2780 non-null   object
#  18  metAs_workNeighbors               2780 non-null   object
#  19  metIn_church                      2780 non-null   object
#  20  metIn_college                     2780 non-null   object
#  21  metIn_military                    2780 non-null   object
#  22  metIn_privateParty                2780 non-null   object
#  23  metIn_public                      2780 non-null   object
#  24  metIn_restaurantOrBar             2780 non-null   object
#  25  metIn_school                      2780 non-null   object
#  26  metIn_voluntaryOrg                2780 non-null   object
#  27  metOn_blindDate                   2780 non-null   object
#  28  metOn_businessTrip                2780 non-null   object
#  29  metOn_vacation                    2780 non-null   object
#  30  metOnline_all                     2844 non-null   object
#  31  metOnline_chat                    2780 non-null   object
#  32  metOnline_datingSiteOrApp         2780 non-null   object
#  33  metOnline_gaming                  2780 non-null   object
#  34  metOnline_nonDatingSite           2780 non-null   object
#  35  metOnline_other                   2780 non-null   object
#  36  metOnline_socialNetwork           2780 non-null   object
#  37  metThru_family                    2780 non-null   object
#  38  metThru_friend                    2780 non-null   object
#  39  metThru_notInternetDatingService  2780 non-null   object
#  40  metThru_orAs_neighbors            2780 non-null   object
#  41  met_YearFraction                  2810 non-null   float64
#  42  met_to_shipStart_diff             2747 non-null   float64
#  43  moveIn_YearFraction               2405 non-null   float64
#  44  numRelativesSeePerMonth           2827 non-null   float64
#  45  ownHouseRentOther                 2844 non-null   object
#  46  partnerAge                        2844 non-null   float64
#  47  partnerEduc_years                 2842 non-null   float64
#  48  partnerGender                     2844 non-null   object
#  49  partnerMotherEduc_years           2805 non-null   float64
#  50  partnerParty_DemPos_RepNeg        2844 non-null   int64
#  51  partnerRace                       2844 non-null   object
#  52  partyDifference                   2844 non-null   int64
#  53  region                            2844 non-null   object
#  54  relationshipQuality               2844 non-null   object
#  55  relationshipQuality_isGood        2844 non-null   int64
#  56  relationshipQuality_num           2844 non-null   int64
#  57  season_met                        2818 non-null   object
#  58  season_shipStart                  2781 non-null   object
#  59  sexFrequency                      2844 non-null   object
#  60  shipStart_YearFraction            2757 non-null   float64
#  61  shipStart_to_moveIn_YearFraction  2354 non-null   float64
#  62  straightGayLesbian                2844 non-null   object
#  63  subjectAge                        2844 non-null   int64
#  64  subjectAgeWhenMet                 2810 non-null   float64
#  65  subjectCountryWhenMetPartner      2844 non-null   object
#  66  subjectEduc_years                 2844 non-null   float64
#  67  subjectGender                     2844 non-null   object
#  68  subjectGrewUpInUS                 2844 non-null   object
#  69  subjectMotherEduc_years           2835 non-null   float64
#  70  subjectParty_DemPos_RepNeg        2844 non-null   int64
#  71  subjectRace                       2834 non-null   object
#  72  subjectSexualIdentity             2844 non-null   object
#  73  timesDivorcedOrWidowed            2838 non-null   float64
#  74  whoEarnedMore                     2844 non-null   object
# dtypes: bool(1), float64(14), int64(12), object(48)
# memory usage: 1.6+ MB

# %% [markdown]
# ### Test-Train Stratified Split
#
# - Stratified split to ensure equal proportions of all labels in both sets.
# - Use on "relationshipQuality_isGood"

# %% [markdown]
# First drop the other two outcome labels, leaving just "relationshipQuality_num"

# %%
# Remove "relationshipQuality" and "relationshipQuality_isGood"

df_copy = df.copy().drop(["relationshipQuality", "relationshipQuality_isGood"], axis=1)

success1 = "relationshipQuality_isGood" not in df_copy.columns
success2 = "relationshipQuality" not in df_copy.columns

print("Sucessfully removed both columns?", success1 & success2)
# Out:
# Sucessfully removed both columns? True

# %% [markdown]
# **The Split**
#
# Since the "relationshipQuality_num" is a numeric variable with only 5 values, it can be stratified along the five values as if it were categorical, which helps create equally proportionate test and train sets. (The modeling will still treat it as a numeric variable.)

# %%
# import package
from sklearn.model_selection import train_test_split

# declare our X inputs and y outcomes
X = df_copy.drop("relationshipQuality_num", axis=1)
y = df_copy["relationshipQuality_num"]


# stratify split
X_train, X_test, y_train, y_test = train_test_split(X, 
                                                    y,
                                                    stratify=y, 
                                                    test_size=0.2,
                                                    random_state=42)

print("X_train.shape = ", X_train.shape)
print("X_test.shape = ", X_test.shape)

print("y_train.shape = ", y_train.shape)
print("y_test.shape = ", y_test.shape)

print("\n")
print("y_train class proportions: \n", y_train.value_counts(normalize=True))

print("\n")
print("y_test class proportions: \n", y_test.value_counts(normalize=True))
# Out:
# X_train.shape =  (2275, 72)
# X_test.shape =  (569, 72)
# y_train.shape =  (2275,)
# y_test.shape =  (569,)
#
#
# y_train class proportions:
#  5    0.599560
# 4    0.310330
# 3    0.071209
# 2    0.010989
# 1    0.007912
# Name: relationshipQuality_num, dtype: float64
#
#
# y_test class proportions:
#  5    0.599297
# 4    0.311072
# 3    0.070299
# 2    0.010545
# 1    0.008787
# Name: relationshipQuality_num, dtype: float64

# %% [markdown]
# ### Remove unneeded columns and missing values
#
# The code is the same as in the classification notebook.

# %%
# removing columns --------------------------------------

columns_to_remove = [
    "moveIn_YearFraction",
    "shipStart_to_moveIn_YearFraction",
    "Unnamed: 0", # Also Remove column with no useful info
    "ID" # Also Remove column with no useful info
]

# anything done to the training set has to be done to the testing set
X_train.drop(columns_to_remove, axis=1, inplace=True)
X_test.drop(columns_to_remove, axis=1, inplace=True)


# Dropping NA values ------------------------------------

def cleanDatasets(X_data, y_data):
    
    cols_with_na = X_data.columns[X_data.isna().any()].tolist()
    
    for col in cols_with_na:
        
        indexes = X_data[col].notna()
        X_data = X_data[indexes]
        y_data = y_data[indexes]
    
    # filter odd partner age cases
    age_filter = X_data["partnerAge"] > 5
    X_data = X_data[age_filter]
    y_data = y_data[age_filter]
    
    return X_data, pd.DataFrame(y_data)

# anything done to the training set has to be done to the testing set        
X_train, y_train = cleanDatasets(X_train, y_train)
X_test, y_test = cleanDatasets(X_test, y_test)


# recombine training sets
training_set = pd.concat([X_train, y_train], axis=1)


# Check all cases and columns
print(training_set.shape)


print(X_train.shape, X_test.shape)
# Out:
# (2090, 69)
# (2090, 68) (518, 68)

# %% [markdown]
# ---
# ---
#
# # Step 2: Prepare the Data for Machine Learning
#
# The code is the same as in the classification notebook.

# %%
# First get the numeric columns and the categorical columns

numeric_features = X_train._get_numeric_data().columns

categorical_features = list(set(X_train.columns) - set(numeric_features))

print(len(X_train.columns), len(numeric_features), len(categorical_features))

print(X_train.shape, X_test.shape)
# Out:
# 68 21 47
# (2090, 68) (518, 68)

# %%
# One hot encode categorical features for the X_train and X_test sets

X_train = pd.get_dummies(X_train, columns=categorical_features, drop_first=True)
X_test = pd.get_dummies(X_test, columns=categorical_features, drop_first=True)

print(X_train.shape, X_test.shape)
# Out:
# (2090, 107) (518, 105)

# %% [markdown]
# #### Taking care of the extra columns

# %%
train_extra_cols = []

test_extra_cols = []


for col in X_test.columns:

    if col not in X_train.columns:
        
        test_extra_cols.append(col)
        
        
for col in X_train.columns:

    if col not in X_test.columns:
        
        train_extra_cols.append(col)
        
print(len(train_extra_cols), " extra train columns:\n",  train_extra_cols)
print(len(test_extra_cols), " extra test columns:\n",  test_extra_cols)
# Out:
# 4  extra train columns:
#  ['attendReligiousServiceFreq_Refused', 'subjectGrewUpInUS_Refused', 'partnerGender_[Partner Name] is Other, please specify', 'metOnline_nonDatingSite_yes']
# 2  extra test columns:
#  ['isLivingTogether_Refused', 'subjectCountryWhenMetPartner_Refused']

# %% [markdown]
# **NOTES:** Some options within the categorical columns were not selected by any of the subjects within the **test** group, so those options did not become their own columns when one-hot encoding.
#
# Some options within the categorical columns were not selected by any of the subjects within the **train** group, so those options did not become their own columns when one-hot encoding.
#
# - I will create columns with just zeros to fill in this gap, so the machine learning models can work without error.

# %%
def addZeroCols(row, extra_cols):
    
    for col in extra_cols:
        
        row[col] = 0
        
    return row


X_test = X_test.apply(addZeroCols, args=[train_extra_cols], axis=1)
X_train = X_train.apply(addZeroCols, args=[test_extra_cols], axis=1)

print(X_train.shape, X_test.shape)
# Out:
# (2090, 109) (518, 109)

# %% [markdown]
# ### Feature Scaling on Numeric Columns with Standardization

# %%
# import scaling & column transformer
from sklearn.preprocessing import StandardScaler
from sklearn.compose import ColumnTransformer

# Create a function to scale the train and test sets

def scaleCategoricalFeatures(X_data):
    
    scaler = StandardScaler()

    X_data[numeric_features] = scaler.fit_transform(X_data[numeric_features])
    
    return X_data

X_train = scaleCategoricalFeatures(X_train)
X_test = scaleCategoricalFeatures(X_test)

print(X_train.shape, X_test.shape)
# Out:
# (2090, 109) (518, 109)

# %% [markdown]
# ### Make sure it worked by seeing if Standard Deviations of Numeric Columns are 1

# %%
X_train.describe()
# Out:
#              ageGap  householdAdults_num  householdIncome  householdMinor_num  \
# count  2.090000e+03         2.090000e+03     2.090000e+03        2.090000e+03
# mean   6.209812e-17         1.375295e-16    -5.397065e-17        2.996009e-17
# std    1.000239e+00         1.000239e+00     1.000239e+00        1.000239e+00
# min   -8.615692e-01        -1.391770e+00    -1.349058e+00       -5.497378e-01
# 25%   -6.535665e-01        -2.188671e-01    -7.142473e-01       -5.497378e-01
# 50%   -2.375610e-01        -2.188671e-01    -1.914617e-01       -5.497378e-01
# 75%    1.784444e-01        -2.188671e-01     2.939820e-01        4.398849e-01
# max    8.498554e+00         6.818551e+00     3.094619e+00        7.367244e+00
#
#        householdSize    isHispanic  met_YearFraction  met_to_shipStart_diff  \
# count   2.090000e+03  2.090000e+03      2.090000e+03           2.090000e+03
# mean   -2.291628e-16  2.267192e-16      9.687918e-15           9.298782e-17
# std     1.000239e+00  1.000239e+00      1.000239e+00           1.000239e+00
# min    -1.262110e+00 -3.652474e-01     -3.308361e+00          -3.705394e-01
# 25%    -5.376360e-01 -3.652474e-01     -7.691073e-01          -3.705394e-01
# 50%    -5.376360e-01 -3.652474e-01      2.017838e-01          -3.308403e-01
# 75%     7.301935e-01 -3.652474e-01      8.440656e-01          -1.126409e-01
# max     5.258156e+00  2.737871e+00      1.371824e+00           1.266423e+01
#
#        numRelativesSeePerMonth    partnerAge  ...  \
# count             2.090000e+03  2.090000e+03  ...
# mean              2.287909e-16 -1.130409e-16  ...
# std               1.000239e+00  1.000239e+00  ...
# min              -6.710181e-01 -2.410680e+00  ...
# 25%              -6.710181e-01 -8.618190e-01  ...
# 50%              -2.779059e-01  6.749774e-02  ...
# 75%               3.117625e-01  7.489967e-01  ...
# max               9.156788e+00  2.855448e+00  ...
#
#        subjectRace_Asian or Pacific Islander  \
# count                            2090.000000
# mean                                0.038756
# std                                 0.193059
# min                                 0.000000
# 25%                                 0.000000
# 50%                                 0.000000
# 75%                                 0.000000
# max                                 1.000000
#
#        subjectRace_Black or African American  \
# count                            2090.000000
# mean                                0.087081
# std                                 0.282022
# min                                 0.000000
# 25%                                 0.000000
# 50%                                 0.000000
# 75%                                 0.000000
# max                                 1.000000
#
#        subjectRace_Other (please specify)  subjectRace_White  \
# count                          2090.00000        2090.000000
# mean                              0.02201           0.814354
# std                               0.14675           0.388914
# min                               0.00000           0.000000
# 25%                               0.00000           1.000000
# 50%                               0.00000           1.000000
# 75%                               0.00000           1.000000
# max                               1.00000           1.000000
#
#        houseType_A mobile home  \
# count              2090.000000
# mean                  0.036842
# std                   0.188419
# min                   0.000000
# 25%                   0.000000
# 50%                   0.000000
# 75%                   0.000000
# max                   1.000000
#
#        houseType_A one-family house attached to one or more houses  \
# count                                        2090.000000
# mean                                            0.082775
# std                                             0.275608
# min                                             0.000000
# 25%                                             0.000000
# 50%                                             0.000000
# 75%                                             0.000000
# max                                             1.000000
#
#        houseType_A one-family house detached from any other house  \
# count                                        2090.000000
# mean                                            0.723445
# std                                             0.447402
# min                                             0.000000
# 25%                                             0.000000
# 50%                                             1.000000
# 75%                                             1.000000
# max                                             1.000000
#
#        houseType_Boat, RV, van, etc.  isLivingTogether_Refused  \
# count                    2090.000000                    2090.0
# mean                        0.000957                       0.0
# std                         0.030927                       0.0
# min                         0.000000                       0.0
# 25%                         0.000000                       0.0
# 50%                         0.000000                       0.0
# 75%                         0.000000                       0.0
# max                         1.000000                       0.0
#
#        subjectCountryWhenMetPartner_Refused
# count                                2090.0
# mean                                    0.0
# std                                     0.0
# min                                     0.0
# 25%                                     0.0
# 50%                                     0.0
# 75%                                     0.0
# max                                     0.0
#
# [8 rows x 109 columns]

# %%
# alphbetize column names

X_train = X_train.sort_index(axis=1)
X_test = X_test.sort_index(axis=1)

X_train.info(verbose=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2090 entries, 1087 to 2731
# Data columns (total 109 columns):
#  #    Column                                                                                        Dtype
# ---   ------                                                                                        -----
#  0    ageGap                                                                                        float64
#  1    attendReligiousServiceFreq_More than once a week                                              int64
#  2    attendReligiousServiceFreq_Never                                                              int64
#  3    attendReligiousServiceFreq_Once a week                                                        int64
#  4    attendReligiousServiceFreq_Once a year or less                                                int64
#  5    attendReligiousServiceFreq_Once or twice a month                                              int64
#  6    attendReligiousServiceFreq_Refused                                                            int64
#  7    employmentStatus_retired                                                                      int64
#  8    employmentStatus_unemployed                                                                   int64
#  9    genderSubjectAttractedTo_sexually attracted mostly to same gender, sometimes opposite gender  int64
#  10   genderSubjectAttractedTo_sexually attracted only to opposite gender                           int64
#  11   genderSubjectAttractedTo_sexually attracted only to same gender                               int64
#  12   genderSubjectAttractedTo_sexually attracted to men and women equally                          int64
#  13   houseType_A mobile home                                                                       int64
#  14   houseType_A one-family house attached to one or more houses                                   int64
#  15   houseType_A one-family house detached from any other house                                    int64
#  16   houseType_Boat, RV, van, etc.                                                                 int64
#  17   householdAdults_num                                                                           float64
#  18   householdIncome                                                                               float64
#  19   householdMinor_num                                                                            float64
#  20   householdSize                                                                                 float64
#  21   interracial_yes                                                                               int64
#  22   isHispanic                                                                                    float64
#  23   isLivingTogether_Refused                                                                      int64
#  24   isLivingTogether_Yes                                                                          int64
#  25   isMarried_Yes, I am Married                                                                   int64
#  26   isMetroArea_Non-Metro                                                                         int64
#  27   metAs_coworkers_yes                                                                           int64
#  28   metAs_customerAndClient_yes                                                                   int64
#  29   metAs_workNeighbors_yes                                                                       int64
#  30   metIn_church_yes                                                                              int64
#  31   metIn_college_yes                                                                             int64
#  32   metIn_military_yes                                                                            int64
#  33   metIn_privateParty_yes                                                                        int64
#  34   metIn_public_yes                                                                              int64
#  35   metIn_restaurantOrBar_yes                                                                     int64
#  36   metIn_school_yes                                                                              int64
#  37   metIn_voluntaryOrg_yes                                                                        int64
#  38   metOn_blindDate_yes                                                                           int64
#  39   metOn_businessTrip_yes                                                                        int64
#  40   metOn_vacation_yes                                                                            int64
#  41   metOnline_all_yes                                                                             int64
#  42   metOnline_chat_yes                                                                            int64
#  43   metOnline_datingSiteOrApp_yes                                                                 int64
#  44   metOnline_gaming_yes                                                                          int64
#  45   metOnline_nonDatingSite_yes                                                                   int64
#  46   metOnline_other_yes                                                                           int64
#  47   metOnline_socialNetwork_yes                                                                   int64
#  48   metThru_family_yes                                                                            int64
#  49   metThru_friend_yes                                                                            int64
#  50   metThru_notInternetDatingService_yes                                                          int64
#  51   metThru_orAs_neighbors_yes                                                                    int64
#  52   met_YearFraction                                                                              float64
#  53   met_to_shipStart_diff                                                                         float64
#  54   numRelativesSeePerMonth                                                                       float64
#  55   ownHouseRentOther_Owned or being bought by you or someone in your household                   int64
#  56   ownHouseRentOther_Rented for cash                                                             int64
#  57   partnerAge                                                                                    float64
#  58   partnerEduc_years                                                                             float64
#  59   partnerGender_[Partner Name] is Male                                                          int64
#  60   partnerGender_[Partner Name] is Other, please specify                                         int64
#  61   partnerMotherEduc_years                                                                       float64
#  62   partnerParty_DemPos_RepNeg                                                                    float64
#  63   partnerRace_Asian or Pacific Islander                                                         int64
#  64   partnerRace_Black or African American                                                         int64
#  65   partnerRace_Other (please specify)                                                            int64
#  66   partnerRace_White                                                                             int64
#  67   partyDifference                                                                               float64
#  68   region_Northeast                                                                              int64
#  69   region_South                                                                                  int64
#  70   region_West                                                                                   int64
#  71   season_met_spring                                                                             int64
#  72   season_met_summer                                                                             int64
#  73   season_met_winter                                                                             int64
#  74   season_shipStart_spring                                                                       int64
#  75   season_shipStart_summer                                                                       int64
#  76   season_shipStart_winter                                                                       int64
#  77   sexFrequency_3 to 6 times a week                                                              int64
#  78   sexFrequency_Once a day or more                                                               int64
#  79   sexFrequency_Once a month or less                                                             int64
#  80   sexFrequency_Once or twice a week                                                             int64
#  81   sexFrequency_Refused                                                                          int64
#  82   shipStart_YearFraction                                                                        float64
#  83   straightGayLesbian_hetero couple                                                              int64
#  84   straightGayLesbian_lesbian couple                                                             int64
#  85   subjectAge                                                                                    float64
#  86   subjectAgeWhenMet                                                                             float64
#  87   subjectCountryWhenMetPartner_Refused                                                          int64
#  88   subjectCountryWhenMetPartner_United States                                                    int64
#  89   subjectEduc_years                                                                             float64
#  90   subjectGender_Male                                                                            int64
#  91   subjectGrewUpInUS_Refused                                                                     int64
#  92   subjectGrewUpInUS_United States                                                               int64
#  93   subjectMotherEduc_years                                                                       float64
#  94   subjectParty_DemPos_RepNeg                                                                    float64
#  95   subjectRace_Asian or Pacific Islander                                                         int64
#  96   subjectRace_Black or African American                                                         int64
#  97   subjectRace_Other (please specify)                                                            int64
#  98   subjectRace_White                                                                             int64
#  99   subjectSexualIdentity_Something else                                                          int64
#  100  subjectSexualIdentity_bisexual                                                                int64
#  101  subjectSexualIdentity_gay                                                                     int64
#  102  subjectSexualIdentity_heterosexual or straight                                                int64
#  103  subjectSexualIdentity_lesbian                                                                 int64
#  104  timesDivorcedOrWidowed                                                                        float64
#  105  whoEarnedMore_Refused                                                                         int64
#  106  whoEarnedMore_We earned about the same amount                                                 int64
#  107  whoEarnedMore_[Partner Name] earned more                                                      int64
#  108  whoEarnedMore_[Partner Name] was not working for pay                                          int64
# dtypes: float64(21), int64(88)
# memory usage: 1.8 MB

# %% [markdown]
# ---
# ---
# # Step 3: Regression Modelling

# %% [markdown]
# ### Full Model - Linear Regression

# %%
# select predictor variables and outcome variable for the model ---

X = X_train

y = y_train


# # To create and test interaction terms 

# X['Interaction_term'] = data['predictor_var'] * data['predictor_var2']


# build model ---------------------------------------

from sklearn import datasets, linear_model
from sklearn.linear_model import LinearRegression
import statsmodels.api as sm
from scipy import stats

# require a constant in the model summary
X = sm.add_constant(X)

# build the model and fit it to the data
linear_model = sm.OLS(y, X, hasconst=True)
linear_model = linear_model.fit()


linear_model.summary()

# NOTE: P-values are the probability the results are insignificant
# and due to random chance. 
# With Values lower than the alpha level (0.05), we can reject the null hypothesis

# NOTE: R-squared is the amount of variability within the outcome variable
# that is explained by our model

# NOTE: Interpreting coefficients
# If we hold all other features fixed, a one unit increase 
# in the predictor_variable is correlated with 
# an increase of (coefficient_number) for the outcome_variable

# Prob (F-statistic) = P-value of the model
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                OLS Regression Results
# ===================================================================================
# Dep. Variable:     relationshipQuality_num   R-squared:                       0.193
# Model:                                 OLS   Adj. R-squared:                  0.150
# Method:                      Least Squares   F-statistic:                     4.466
# Date:                     Tue, 27 Sep 2022   Prob (F-statistic):           1.72e-41
# Time:                             14:25:48   Log-Likelihood:                -2112.5
# No. Observations:                     2090   AIC:                             4439.
# Df Residuals:                         1983   BIC:                             5043.
# Df Model:                              106
# Covariance Type:                 nonrobust
# ================================================================================================================================================================
#                                                                                                    coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------------------------------------------------------------------------------
# const                                                                                            4.5686      0.836      5.465      0.000       2.929       6.208
# ageGap                                                                                          -0.0104      0.018     -0.591      0.554      -0.045       0.024
# attendReligiousServiceFreq_More than once a week                                                 0.1268      0.069      1.834      0.067      -0.009       0.262
# attendReligiousServiceFreq_Never                                                                -0.0375      0.049     -0.767      0.443      -0.133       0.058
# attendReligiousServiceFreq_Once a week                                                           0.0306      0.053      0.579      0.563      -0.073       0.134
# attendReligiousServiceFreq_Once a year or less                                                   0.0300      0.052      0.578      0.563      -0.072       0.132
# attendReligiousServiceFreq_Once or twice a month                                                 0.0015      0.064      0.023      0.981      -0.124       0.127
# attendReligiousServiceFreq_Refused                                                              -0.5539      0.352     -1.572      0.116      -1.245       0.137
# employmentStatus_retired                                                                         0.0923      0.053      1.752      0.080      -0.011       0.196
# employmentStatus_unemployed                                                                     -0.0415      0.041     -1.020      0.308      -0.121       0.038
# genderSubjectAttractedTo_sexually attracted mostly to same gender, sometimes opposite gender     0.0781      0.163      0.479      0.632      -0.241       0.398
# genderSubjectAttractedTo_sexually attracted only to opposite gender                              0.0849      0.090      0.946      0.344      -0.091       0.261
# genderSubjectAttractedTo_sexually attracted only to same gender                                  0.2955      0.174      1.702      0.089      -0.045       0.636
# genderSubjectAttractedTo_sexually attracted to men and women equally                             0.0452      0.106      0.427      0.669      -0.162       0.253
# houseType_A mobile home                                                                          0.0694      0.097      0.714      0.475      -0.121       0.260
# houseType_A one-family house attached to one or more houses                                     -0.0391      0.068     -0.570      0.568      -0.173       0.095
# houseType_A one-family house detached from any other house                                      -0.0648      0.058     -1.114      0.265      -0.179       0.049
# houseType_Boat, RV, van, etc.                                                                    0.1844      0.506      0.364      0.716      -0.808       1.176
# householdAdults_num                                                                              0.0167      0.014      1.238      0.216      -0.010       0.043
# householdIncome                                                                                  0.0407      0.019      2.141      0.032       0.003       0.078
# householdMinor_num                                                                              -0.0321      0.013     -2.469      0.014      -0.058      -0.007
# householdSize                                                                                   -0.0132      0.008     -1.583      0.114      -0.029       0.003
# interracial_yes                                                                                 -0.0209      0.056     -0.372      0.710      -0.131       0.089
# isHispanic                                                                                      -0.0125      0.018     -0.701      0.483      -0.047       0.022
# isLivingTogether_Refused                                                                      1.006e-13   2.03e-13      0.496      0.620   -2.98e-13    4.99e-13
# isLivingTogether_Yes                                                                             0.3984      0.054      7.407      0.000       0.293       0.504
# isMarried_Yes, I am Married                                                                     -0.0115      0.050     -0.230      0.818      -0.110       0.087
# isMetroArea_Non-Metro                                                                            0.0562      0.046      1.226      0.220      -0.034       0.146
# metAs_coworkers_yes                                                                             -0.0580      0.047     -1.237      0.216      -0.150       0.034
# metAs_customerAndClient_yes                                                                      0.0111      0.065      0.171      0.864      -0.117       0.139
# metAs_workNeighbors_yes                                                                          0.3374      0.132      2.558      0.011       0.079       0.596
# metIn_church_yes                                                                                 0.0362      0.068      0.529      0.597      -0.098       0.171
# metIn_college_yes                                                                                0.0570      0.064      0.889      0.374      -0.069       0.183
# metIn_military_yes                                                                               0.0594      0.120      0.495      0.621      -0.176       0.295
# metIn_privateParty_yes                                                                          -0.0139      0.053     -0.262      0.793      -0.118       0.090
# metIn_public_yes                                                                                -0.0904      0.088     -1.023      0.306      -0.264       0.083
# metIn_restaurantOrBar_yes                                                                        0.0465      0.042      1.120      0.263      -0.035       0.128
# metIn_school_yes                                                                                 0.1541      0.057      2.703      0.007       0.042       0.266
# metIn_voluntaryOrg_yes                                                                          -0.0749      0.069     -1.078      0.281      -0.211       0.061
# metOn_blindDate_yes                                                                              0.1358      0.086      1.587      0.113      -0.032       0.304
# metOn_businessTrip_yes                                                                           0.5812      0.403      1.443      0.149      -0.209       1.371
# metOn_vacation_yes                                                                               0.0921      0.131      0.701      0.483      -0.166       0.350
# metOnline_all_yes                                                                               -0.4134      0.503     -0.822      0.411      -1.400       0.573
# metOnline_chat_yes                                                                               0.3770      0.506      0.745      0.456      -0.616       1.370
# metOnline_datingSiteOrApp_yes                                                                    0.4404      0.505      0.872      0.383      -0.550       1.430
# metOnline_gaming_yes                                                                             0.4563      0.506      0.901      0.368      -0.537       1.449
# metOnline_nonDatingSite_yes                                                                      0.6513      0.441      1.478      0.140      -0.213       1.516
# metOnline_other_yes                                                                              0.5843      0.508      1.149      0.251      -0.413       1.581
# metOnline_socialNetwork_yes                                                                      0.4750      0.491      0.967      0.334      -0.489       1.439
# metThru_family_yes                                                                              -0.0228      0.046     -0.493      0.622      -0.113       0.068
# metThru_friend_yes                                                                               0.0319      0.037      0.853      0.394      -0.041       0.105
# metThru_notInternetDatingService_yes                                                             0.2165      0.170      1.272      0.203      -0.117       0.550
# metThru_orAs_neighbors_yes                                                                       0.0607      0.065      0.935      0.350      -0.067       0.188
# met_YearFraction                                                                                -5.5089     11.515     -0.478      0.632     -28.091      17.073
# met_to_shipStart_diff                                                                           -1.4765      2.870     -0.514      0.607      -7.105       4.152
# numRelativesSeePerMonth                                                                          0.0177      0.016      1.110      0.267      -0.014       0.049
# ownHouseRentOther_Owned or being bought by you or someone in your household                      0.0621      0.107      0.583      0.560      -0.147       0.271
# ownHouseRentOther_Rented for cash                                                                0.0147      0.108      0.135      0.892      -0.198       0.227
# partnerAge                                                                                       0.0314      0.046      0.679      0.497      -0.059       0.122
# partnerEduc_years                                                                                0.0123      0.020      0.616      0.538      -0.027       0.052
# partnerGender_[Partner Name] is Male                                                            -0.1361      0.179     -0.759      0.448      -0.488       0.215
# partnerGender_[Partner Name] is Other, please specify                                           -0.0517      0.409     -0.127      0.899      -0.853       0.750
# partnerMotherEduc_years                                                                          0.0213      0.017      1.216      0.224      -0.013       0.056
# partnerParty_DemPos_RepNeg                                                                      -0.0112      0.021     -0.530      0.596      -0.053       0.030
# partnerRace_Asian or Pacific Islander                                                            0.4853      0.168      2.892      0.004       0.156       0.815
# partnerRace_Black or African American                                                            0.2986      0.162      1.842      0.066      -0.019       0.616
# partnerRace_Other (please specify)                                                               0.3287      0.166      1.979      0.048       0.003       0.655
# partnerRace_White                                                                                0.4053      0.147      2.762      0.006       0.118       0.693
# partyDifference                                                                                 -0.0272      0.016     -1.722      0.085      -0.058       0.004
# region_Northeast                                                                                -0.0061      0.051     -0.120      0.904      -0.105       0.093
# region_South                                                                                    -0.0336      0.042     -0.793      0.428      -0.117       0.049
# region_West                                                                                      0.0229      0.048      0.478      0.632      -0.071       0.117
# season_met_spring                                                                               -0.0057      0.062     -0.091      0.927      -0.128       0.116
# season_met_summer                                                                                0.0206      0.048      0.426      0.670      -0.074       0.115
# season_met_winter                                                                                0.0041      0.063      0.065      0.948      -0.120       0.128
# season_shipStart_spring                                                                          0.0085      0.049      0.174      0.862      -0.087       0.104
# season_shipStart_summer                                                                          0.0192      0.045      0.422      0.673      -0.070       0.108
# season_shipStart_winter                                                                          0.0803      0.047      1.721      0.085      -0.011       0.172
# sexFrequency_3 to 6 times a week                                                                 0.2474      0.057      4.319      0.000       0.135       0.360
# sexFrequency_Once a day or more                                                                  0.1358      0.099      1.378      0.168      -0.057       0.329
# sexFrequency_Once a month or less                                                               -0.2509      0.045     -5.535      0.000      -0.340      -0.162
# sexFrequency_Once or twice a week                                                                0.1132      0.047      2.433      0.015       0.022       0.204
# sexFrequency_Refused                                                                            -0.0419      0.083     -0.507      0.612      -0.204       0.120
# shipStart_YearFraction                                                                           5.9078     11.307      0.522      0.601     -16.268      28.083
# straightGayLesbian_hetero couple                                                                -0.0604      0.277     -0.218      0.827      -0.603       0.482
# straightGayLesbian_lesbian couple                                                               -0.1648      0.421     -0.391      0.696      -0.991       0.661
# subjectAge                                                                                       0.4829      1.367      0.353      0.724      -2.198       3.164
# subjectAgeWhenMet                                                                               -0.3322      0.962     -0.345      0.730      -2.219       1.555
# subjectCountryWhenMetPartner_Refused                                                         -9.017e-14   1.85e-13     -0.488      0.626   -4.53e-13    2.72e-13
# subjectCountryWhenMetPartner_United States                                                      -0.0757      0.101     -0.753      0.451      -0.273       0.121
# subjectEduc_years                                                                                0.0339      0.021      1.622      0.105      -0.007       0.075
# subjectGender_Male                                                                              -0.0861      0.180     -0.477      0.633      -0.440       0.268
# subjectGrewUpInUS_Refused                                                                       -0.3654      0.705     -0.518      0.605      -1.749       1.018
# subjectGrewUpInUS_United States                                                                  0.1100      0.077      1.423      0.155      -0.042       0.262
# subjectMotherEduc_years                                                                          0.0017      0.018      0.096      0.924      -0.033       0.037
# subjectParty_DemPos_RepNeg                                                                       0.0167      0.021      0.777      0.437      -0.025       0.059
# subjectRace_Asian or Pacific Islander                                                           -0.2568      0.125     -2.046      0.041      -0.503      -0.011
# subjectRace_Black or African American                                                           -0.2045      0.117     -1.746      0.081      -0.434       0.025
# subjectRace_Other (please specify)                                                              -0.1974      0.138     -1.426      0.154      -0.469       0.074
# subjectRace_White                                                                               -0.1036      0.094     -1.101      0.271      -0.288       0.081
# subjectSexualIdentity_Something else                                                            -1.2281      0.719     -1.709      0.088      -2.638       0.181
# subjectSexualIdentity_bisexual                                                                  -0.7762      0.697     -1.114      0.266      -2.143       0.591
# subjectSexualIdentity_gay                                                                       -0.8387      0.725     -1.158      0.247      -2.260       0.582
# subjectSexualIdentity_heterosexual or straight                                                  -0.7292      0.689     -1.058      0.290      -2.081       0.623
# subjectSexualIdentity_lesbian                                                                   -0.8865      0.725     -1.222      0.222      -2.309       0.536
# timesDivorcedOrWidowed                                                                           0.0158      0.020      0.799      0.425      -0.023       0.055
# whoEarnedMore_Refused                                                                            0.2530      0.313      0.808      0.419      -0.361       0.867
# whoEarnedMore_We earned about the same amount                                                    0.1452      0.051      2.852      0.004       0.045       0.245
# whoEarnedMore_[Partner Name] earned more                                                         0.0563      0.040      1.416      0.157      -0.022       0.134
# whoEarnedMore_[Partner Name] was not working for pay                                             0.0981      0.072      1.363      0.173      -0.043       0.239
# ==============================================================================
# Omnibus:                      569.617   Durbin-Watson:                   1.964
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             1610.590
# Skew:                          -1.410   Prob(JB):                         0.00
# Kurtosis:                       6.247   Cond. No.                     1.06e+16
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The smallest eigenvalue is 2.04e-28. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.
# """

# %% [markdown]
# ### Backwards Elimination (Round 1) - Linear Regression (alpha level = 0.05)

# %%
# select predictor variables and outcome variable for the model ---

features = [
    "householdIncome",
    "householdMinor_num",
    "isLivingTogether_Yes",
    "metAs_workNeighbors_yes",
    "metIn_school_yes",
    "partnerRace_Asian or Pacific Islander",
    "partnerRace_White",
    "sexFrequency_3 to 6 times a week",
    "sexFrequency_Once a month or less",
    "sexFrequency_Once or twice a week",
    "subjectRace_Asian or Pacific Islander",
    "whoEarnedMore_We earned about the same amount"
]

X = X_train[features]

y = y_train

# require a constant in the model summary
X = sm.add_constant(X)

# build the model and fit it to the data
linear_model = sm.OLS(y, X, hasconst=True)
linear_model = linear_model.fit()


linear_model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                OLS Regression Results
# ===================================================================================
# Dep. Variable:     relationshipQuality_num   R-squared:                       0.136
# Model:                                 OLS   Adj. R-squared:                  0.131
# Method:                      Least Squares   F-statistic:                     27.26
# Date:                     Tue, 27 Sep 2022   Prob (F-statistic):           5.43e-58
# Time:                             14:51:02   Log-Likelihood:                -2183.4
# No. Observations:                     2090   AIC:                             4393.
# Df Residuals:                         2077   BIC:                             4466.
# Df Model:                               12
# Covariance Type:                 nonrobust
# =================================================================================================================
#                                                     coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------------------------------------
# const                                             3.9155      0.056     69.742      0.000       3.805       4.026
# householdIncome                                   0.0673      0.016      4.333      0.000       0.037       0.098
# householdMinor_num                               -0.0734      0.015     -4.764      0.000      -0.104      -0.043
# isLivingTogether_Yes                              0.4575      0.043     10.682      0.000       0.373       0.541
# metAs_workNeighbors_yes                           0.2984      0.130      2.304      0.021       0.044       0.552
# metIn_school_yes                                  0.1580      0.049      3.199      0.001       0.061       0.255
# partnerRace_Asian or Pacific Islander             0.2375      0.087      2.736      0.006       0.067       0.408
# partnerRace_White                                 0.2127      0.044      4.889      0.000       0.127       0.298
# sexFrequency_3 to 6 times a week                  0.2089      0.052      4.021      0.000       0.107       0.311
# sexFrequency_Once a month or less                -0.2101      0.040     -5.299      0.000      -0.288      -0.132
# sexFrequency_Once or twice a week                 0.1004      0.042      2.400      0.016       0.018       0.183
# subjectRace_Asian or Pacific Islander            -0.1497      0.087     -1.728      0.084      -0.320       0.020
# whoEarnedMore_We earned about the same amount     0.1041      0.046      2.260      0.024       0.014       0.194
# ==============================================================================
# Omnibus:                      585.284   Durbin-Watson:                   1.956
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             1597.753
# Skew:                          -1.467   Prob(JB):                         0.00
# Kurtosis:                       6.121   Cond. No.                         14.1
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %% [markdown]
# ### Backwards Elimination (Round 2) - Linear Regression (alpha level = 0.05)

# %%
# select predictor variables and outcome variable for the model ---

features = [
    "householdIncome",
    "householdMinor_num",
    "isLivingTogether_Yes",
    "metAs_workNeighbors_yes",
    "metIn_school_yes",
    "partnerRace_Asian or Pacific Islander",
    "partnerRace_White",
    "sexFrequency_3 to 6 times a week",
    "sexFrequency_Once a month or less",
    "sexFrequency_Once or twice a week",
    "whoEarnedMore_We earned about the same amount"
]

X = X_train[features]

y = y_train

# require a constant in the model summary
X = sm.add_constant(X)

# build the model and fit it to the data
linear_model = sm.OLS(y, X, hasconst=True)
linear_model = linear_model.fit()


linear_model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                OLS Regression Results
# ===================================================================================
# Dep. Variable:     relationshipQuality_num   R-squared:                       0.135
# Model:                                 OLS   Adj. R-squared:                  0.130
# Method:                      Least Squares   F-statistic:                     29.43
# Date:                     Tue, 27 Sep 2022   Prob (F-statistic):           4.14e-58
# Time:                             14:52:03   Log-Likelihood:                -2184.9
# No. Observations:                     2090   AIC:                             4394.
# Df Residuals:                         2078   BIC:                             4461.
# Df Model:                               11
# Covariance Type:                 nonrobust
# =================================================================================================================
#                                                     coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------------------------------------
# const                                             3.9078      0.056     69.792      0.000       3.798       4.018
# householdIncome                                   0.0662      0.016      4.264      0.000       0.036       0.097
# householdMinor_num                               -0.0728      0.015     -4.726      0.000      -0.103      -0.043
# isLivingTogether_Yes                              0.4595      0.043     10.729      0.000       0.376       0.544
# metAs_workNeighbors_yes                           0.3042      0.130      2.348      0.019       0.050       0.558
# metIn_school_yes                                  0.1611      0.049      3.262      0.001       0.064       0.258
# partnerRace_Asian or Pacific Islander             0.1827      0.081      2.259      0.024       0.024       0.341
# partnerRace_White                                 0.2158      0.043      4.963      0.000       0.131       0.301
# sexFrequency_3 to 6 times a week                  0.2075      0.052      3.992      0.000       0.106       0.309
# sexFrequency_Once a month or less                -0.2096      0.040     -5.283      0.000      -0.287      -0.132
# sexFrequency_Once or twice a week                 0.1001      0.042      2.392      0.017       0.018       0.182
# whoEarnedMore_We earned about the same amount     0.1034      0.046      2.244      0.025       0.013       0.194
# ==============================================================================
# Omnibus:                      590.161   Durbin-Watson:                   1.959
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             1625.955
# Skew:                          -1.476   Prob(JB):                         0.00
# Kurtosis:                       6.156   Cond. No.                         14.1
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %% [markdown]
# ### L1 - Lasso Regression

# %% [markdown]
# #### GridSearchCV for Lasso

# %%
# CONDUCT GRID SEARCH ---------------------------
from sklearn.model_selection import GridSearchCV

# dictionary of parameters to search
param_grid = {"alpha": [0, 1, 2],
             "max_iter":[1, 20, 50, 60]}


# import lasso
from sklearn.linear_model import Lasso

lasso = Lasso()

# grid search on all values of k in dictionary
lasso_grid = GridSearchCV(lasso, param_grid, cv=5)

lasso_grid.fit(X_train, y_train)


# PRINT RESULTS ---------------------------

# best performing params (on training set)
print("best params:\n\n", lasso_grid.best_params_)

# best score parameters 
print("\nbest score:\n\n", lasso_grid.best_score_)
# Out:
# best params:
#
#  {'alpha': 0, 'max_iter': 1}
#
# best score:
#
#  0.06462796553708876

# %% [markdown]
# **NOTE:** Lasso with it's best score with an alpha of 0, is just regular linear regression without regularization. For the final test, I will use Lasso with default parameters.

# %% [markdown]
# ### L2 - Ridge Regression

# %% [markdown]
# #### GridSearchCV for Ridge

# %%
# CONDUCT GRID SEARCH ---------------------------
from sklearn.model_selection import GridSearchCV

# dictionary of parameters to search
param_grid = {"alpha": [110, 120, 130]}


# Import Ridge
from sklearn.linear_model import Ridge

ridge = Ridge()

# grid search on all values of k in dictionary
ridge_grid = GridSearchCV(ridge, param_grid, cv=5)

ridge_grid.fit(X_train, y_train)


# PRINT RESULTS ---------------------------

# best performing params (on training set)
print("best params:\n\n", ridge_grid.best_params_)

# best R-squared  performing parameters
print("\nbest score:\n\n", ridge_grid.best_score_)
# Out:
# best params:
#
#  {'alpha': 120}
#
# best score:
#
#  0.09373438430752132

# %% [markdown]
# ---
# ---
#
# # Step 4: Compare Classification Models

# %% [markdown]
# ### Full Model - Linear Regression (109 Features)

# %%
from sklearn.linear_model import LinearRegression

lr = LinearRegression()

lr.fit(X_train, y_train)

print("---")
print("Training set R^2: {:.2f}".format(lr.score(X_train, y_train)))
print("Test set R^2: {:.2f}".format(lr.score(X_test, y_test)))
# Out:
# ---
# Training set R^2: 0.19
# Test set R^2: -63058860234115137929216.00

# %% [markdown]
# ### Backwards Eliminated Model - Linear Regression (11 Features)

# %%
from sklearn.linear_model import LinearRegression

features = [    
    "householdIncome",
    "householdMinor_num",
    "isLivingTogether_Yes",
    "metAs_workNeighbors_yes",
    "metIn_school_yes",
    "partnerRace_Asian or Pacific Islander",
    "partnerRace_White",
    "sexFrequency_3 to 6 times a week",
    "sexFrequency_Once a month or less",
    "sexFrequency_Once or twice a week",
    "whoEarnedMore_We earned about the same amount"]

X = X_train[features]


lr = LinearRegression().fit(X, y_train)


print("Training set R^2: {:.2f}".format(lr.score(X, y_train)))
print("Test set R^2: {:.2f}".format(lr.score(X_test[features], y_test)))
# Out:
# Training set R^2: 0.13
# Test set R^2: 0.09

# %% [markdown]
# ### Ridge Regression with alpha = 120

# %%
from sklearn.linear_model import Ridge

ridge = Ridge(alpha = 120).fit(X_train, y_train)

print("Training set score: {:.2f}".format(ridge.score(X_train, y_train)))
print("Test set score: {:.2f}".format(ridge.score(X_test, y_test)))
# Out:
# Training set score: 0.17
# Test set score: 0.13

# %% [markdown]
# ### Default Lasso

# %%
from sklearn.linear_model import Lasso

lasso = Lasso().fit(X_train, y_train)
print("Training set score: {:.2f}".format(lasso.score(X_train, y_train)))
print("Test set score: {:.2f}".format(lasso.score(X_test, y_test)))
print("Number of features used:", np.sum(lasso.coef_ != 0))
# Out:
# Training set score: 0.00
# Test set score: -0.00
# Number of features used: 0

# %% [markdown]
# ---
# ---
#
# # Step 5: Conclusions
