# %% [markdown]
# # Exploratory Analysis & Classification
#
# By: Oscar Ko
#
# This notebook was created for data analysis and classification on this dataset from Stanford:
#
# https://data.stanford.edu/hcmst2017
#
# ---
# ---

# %% [markdown]
# # Step 1: Imports and Data

# %%
import numpy as np
import pandas as pd

import warnings
warnings.filterwarnings('ignore')


df = pd.read_csv("data/df_renamed.csv")

print(df.shape, "\n")

df.info(verbose=True)
# Out:
# (2844, 75)
#
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2844 entries, 0 to 2843
# Data columns (total 75 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   Unnamed: 0                        2844 non-null   int64
#  1   ID                                2844 non-null   int64
#  2   ageGap                            2844 non-null   float64
#  3   attendReligiousServiceFreq        2844 non-null   object
#  4   employmentStatus                  2844 non-null   object
#  5   genderSubjectAttractedTo          2837 non-null   object
#  6   houseType                         2844 non-null   object
#  7   householdAdults_num               2844 non-null   int64
#  8   householdIncome                   2844 non-null   int64
#  9   householdMinor_num                2844 non-null   int64
#  10  householdSize                     2844 non-null   int64
#  11  interracial                       2822 non-null   object
#  12  isHispanic                        2844 non-null   bool
#  13  isLivingTogether                  2844 non-null   object
#  14  isMarried                         2844 non-null   object
#  15  isMetroArea                       2844 non-null   object
#  16  metAs_coworkers                   2780 non-null   object
#  17  metAs_customerAndClient           2780 non-null   object
#  18  metAs_workNeighbors               2780 non-null   object
#  19  metIn_church                      2780 non-null   object
#  20  metIn_college                     2780 non-null   object
#  21  metIn_military                    2780 non-null   object
#  22  metIn_privateParty                2780 non-null   object
#  23  metIn_public                      2780 non-null   object
#  24  metIn_restaurantOrBar             2780 non-null   object
#  25  metIn_school                      2780 non-null   object
#  26  metIn_voluntaryOrg                2780 non-null   object
#  27  metOn_blindDate                   2780 non-null   object
#  28  metOn_businessTrip                2780 non-null   object
#  29  metOn_vacation                    2780 non-null   object
#  30  metOnline_all                     2844 non-null   object
#  31  metOnline_chat                    2780 non-null   object
#  32  metOnline_datingSiteOrApp         2780 non-null   object
#  33  metOnline_gaming                  2780 non-null   object
#  34  metOnline_nonDatingSite           2780 non-null   object
#  35  metOnline_other                   2780 non-null   object
#  36  metOnline_socialNetwork           2780 non-null   object
#  37  metThru_family                    2780 non-null   object
#  38  metThru_friend                    2780 non-null   object
#  39  metThru_notInternetDatingService  2780 non-null   object
#  40  metThru_orAs_neighbors            2780 non-null   object
#  41  met_YearFraction                  2810 non-null   float64
#  42  met_to_shipStart_diff             2747 non-null   float64
#  43  moveIn_YearFraction               2405 non-null   float64
#  44  numRelativesSeePerMonth           2827 non-null   float64
#  45  ownHouseRentOther                 2844 non-null   object
#  46  partnerAge                        2844 non-null   float64
#  47  partnerEduc_years                 2842 non-null   float64
#  48  partnerGender                     2844 non-null   object
#  49  partnerMotherEduc_years           2805 non-null   float64
#  50  partnerParty_DemPos_RepNeg        2844 non-null   int64
#  51  partnerRace                       2844 non-null   object
#  52  partyDifference                   2844 non-null   int64
#  53  region                            2844 non-null   object
#  54  relationshipQuality               2844 non-null   object
#  55  relationshipQuality_isGood        2844 non-null   int64
#  56  relationshipQuality_num           2844 non-null   int64
#  57  season_met                        2818 non-null   object
#  58  season_shipStart                  2781 non-null   object
#  59  sexFrequency                      2844 non-null   object
#  60  shipStart_YearFraction            2757 non-null   float64
#  61  shipStart_to_moveIn_YearFraction  2354 non-null   float64
#  62  straightGayLesbian                2844 non-null   object
#  63  subjectAge                        2844 non-null   int64
#  64  subjectAgeWhenMet                 2810 non-null   float64
#  65  subjectCountryWhenMetPartner      2844 non-null   object
#  66  subjectEduc_years                 2844 non-null   float64
#  67  subjectGender                     2844 non-null   object
#  68  subjectGrewUpInUS                 2844 non-null   object
#  69  subjectMotherEduc_years           2835 non-null   float64
#  70  subjectParty_DemPos_RepNeg        2844 non-null   int64
#  71  subjectRace                       2834 non-null   object
#  72  subjectSexualIdentity             2844 non-null   object
#  73  timesDivorcedOrWidowed            2838 non-null   float64
#  74  whoEarnedMore                     2844 non-null   object
# dtypes: bool(1), float64(14), int64(12), object(48)
# memory usage: 1.6+ MB

# %% [markdown]
# ### Test-Train Stratified Split
#
# - Stratified split to ensure equal proportions of all labels in both sets.
# - Use on "relationshipQuality_isGood"

# %% [markdown]
# First drop the other two outcome labels, leaving just "relationshipQuality_isGood"

# %%
# Remove "relationshipQuality" and "relationshipQuality_num"

df_copy = df.copy().drop(["relationshipQuality", "relationshipQuality_num"], axis=1)

success1 = "relationshipQuality_num" not in df_copy.columns
success2 = "relationshipQuality" not in df_copy.columns

print("Sucessfully removed both columns?", success1 & success2)
# Out:
# Sucessfully removed both columns? True

# %% [markdown]
# **The Split**

# %%
# import package
from sklearn.model_selection import train_test_split

# declare our X inputs and y outcomes
X = df_copy.drop("relationshipQuality_isGood", axis=1)
y = df_copy["relationshipQuality_isGood"]


# stratify split
X_train, X_test, y_train, y_test = train_test_split(X, 
                                                    y,
                                                    stratify=y, 
                                                    test_size=0.2,
                                                    random_state=42)

print("X_train.shape = ", X_train.shape)
print("X_test.shape = ", X_test.shape)

print("y_train.shape = ", y_train.shape)
print("y_test.shape = ", y_test.shape)

print("\n")
print("y_train class proportions: \n", y_train.value_counts(normalize=True))

print("\n")
print("y_test class proportions: \n", y_test.value_counts(normalize=True))
# Out:
# X_train.shape =  (2275, 72)
# X_test.shape =  (569, 72)
# y_train.shape =  (2275,)
# y_test.shape =  (569,)
#
#
# y_train class proportions:
#  1    0.90989
# 0    0.09011
# Name: relationshipQuality_isGood, dtype: float64
#
#
# y_test class proportions:
#  1    0.910369
# 0    0.089631
# Name: relationshipQuality_isGood, dtype: float64

# %% [markdown]
# ### X_train Summary Statistics

# %%
X_train.describe()
# Out:
#         Unnamed: 0            ID       ageGap  householdAdults_num  \
# count  2275.000000  2.275000e+03  2275.000000          2275.000000
# mean   1785.339341  2.175449e+06     4.370110             2.200440
# std    1010.610098  6.470539e+05     6.120972             0.895754
# min       1.000000  5.300100e+04     0.000000             1.000000
# 25%     914.500000  1.811954e+06     1.000000             2.000000
# 50%    1807.000000  2.279341e+06     3.000000             2.000000
# 75%    2653.000000  2.762445e+06     6.000000             2.000000
# max    3508.000000  2.969933e+06    86.000000             9.000000
#
#        householdIncome  householdMinor_num  householdSize  met_YearFraction  \
# count      2275.000000         2275.000000    2275.000000       2250.000000
# mean      93148.901099            0.560879       2.761319       1994.377522
# std       67842.768330            1.021820       1.437559         16.889129
# min        2500.000000            0.000000       1.000000       1939.208400
# 25%       45000.000000            0.000000       2.000000       1981.458400
# 50%       80000.000000            0.000000       2.000000       1997.791600
# 75%      112500.000000            1.000000       4.000000       2008.708400
# max      300000.000000            8.000000      10.000000       2017.541600
#
#        met_to_shipStart_diff  moveIn_YearFraction  ...  \
# count            2200.000000          1930.000000  ...
# mean                1.617764          1995.512353  ...
# std                 4.435628            15.874591  ...
# min                 0.000000          1944.375000  ...
# 25%                 0.000000          1983.625000  ...
# 50%                 0.166748          1998.458400  ...
# 75%                 1.083283          2009.458400  ...
# max                54.750000          2017.541600  ...
#
#        partnerParty_DemPos_RepNeg  partyDifference  shipStart_YearFraction  \
# count                 2275.000000      2275.000000             2208.000000
# mean                    -0.029011         1.191209             1996.054011
# std                      1.903809         1.176175               16.609877
# min                     -3.000000         0.000000             1942.375000
# 25%                     -1.000000         0.000000             1983.625000
# 50%                      0.000000         1.000000             1999.541600
# 75%                      1.000000         2.000000             2010.291600
# max                      3.000000         6.000000             2017.875000
#
#        shipStart_to_moveIn_YearFraction   subjectAge  subjectAgeWhenMet  \
# count                       1889.000000  2275.000000        2250.000000
# mean                           1.932019    49.288791          26.171111
# std                            2.712029    16.323754          11.241342
# min                            0.000000    18.000000           0.000000
# 25%                            0.333374    35.000000          18.000000
# 50%                            1.083252    51.000000          23.000000
# 75%                            2.416626    62.000000          31.000000
# max                           31.500000    93.000000          84.000000
#
#        subjectEduc_years  subjectMotherEduc_years  subjectParty_DemPos_RepNeg  \
# count        2275.000000              2271.000000                 2275.000000
# mean           14.100220                12.343901                    0.142418
# std             2.528392                 3.128096                    2.117259
# min             0.000000                 0.000000                   -3.000000
# 25%            12.000000                12.000000                   -2.000000
# 50%            13.000000                12.000000                    1.000000
# 75%            16.000000                14.000000                    2.000000
# max            20.000000                20.000000                    3.000000
#
#        timesDivorcedOrWidowed
# count             2269.000000
# mean                 0.360952
# std                  0.661148
# min                  0.000000
# 25%                  0.000000
# 50%                  0.000000
# 75%                  1.000000
# max                  4.000000
#
# [8 rows x 24 columns]

# %% [markdown]
# ### Check the training set for missing values

# %%
# combine the X_train and y_train into a dataframe
training_set = pd.concat([X_train, y_train], axis=1)

# check records and features
print(training_set.shape)
# Out:
# (2275, 73)

# %%
# Check for any missing values
print(training_set.isnull().values.any())

# Check number of missing values
print("Count of na's:", training_set.isnull().values.sum())

# Check number of rows with missing values
print("Cases with missing values:", training_set.isna().any(axis=1).sum())
# Out:
# True
# Count of na's: 2252
# Cases with missing values: 469

# %%
pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)

training_set.isna().sum()
# Out:
# Unnamed: 0                            0
# ID                                    0
# ageGap                                0
# attendReligiousServiceFreq            0
# employmentStatus                      0
# genderSubjectAttractedTo              7
# houseType                             0
# householdAdults_num                   0
# householdIncome                       0
# householdMinor_num                    0
# householdSize                         0
# interracial                          19
# isHispanic                            0
# isLivingTogether                      0
# isMarried                             0
# isMetroArea                           0
# metAs_coworkers                      49
# metAs_customerAndClient              49
# metAs_workNeighbors                  49
# metIn_church                         49
# metIn_college                        49
# metIn_military                       49
# metIn_privateParty                   49
# metIn_public                         49
# metIn_restaurantOrBar                49
# metIn_school                         49
# metIn_voluntaryOrg                   49
# metOn_blindDate                      49
# metOn_businessTrip                   49
# metOn_vacation                       49
# metOnline_all                         0
# metOnline_chat                       49
# metOnline_datingSiteOrApp            49
# metOnline_gaming                     49
# metOnline_nonDatingSite              49
# metOnline_other                      49
# metOnline_socialNetwork              49
# metThru_family                       49
# metThru_friend                       49
# metThru_notInternetDatingService     49
# metThru_orAs_neighbors               49
# met_YearFraction                     25
# met_to_shipStart_diff                75
# moveIn_YearFraction                 345
# numRelativesSeePerMonth              13
# ownHouseRentOther                     0
# partnerAge                            0
# partnerEduc_years                     2
# partnerGender                         0
# partnerMotherEduc_years              29
# partnerParty_DemPos_RepNeg            0
# partnerRace                           0
# partyDifference                       0
# region                                0
# season_met                           19
# season_shipStart                     47
# sexFrequency                          0
# shipStart_YearFraction               67
# shipStart_to_moveIn_YearFraction    386
# straightGayLesbian                    0
# subjectAge                            0
# subjectAgeWhenMet                    25
# subjectCountryWhenMetPartner          0
# subjectEduc_years                     0
# subjectGender                         0
# subjectGrewUpInUS                     0
# subjectMotherEduc_years               4
# subjectParty_DemPos_RepNeg            0
# subjectRace                           7
# subjectSexualIdentity                 0
# timesDivorcedOrWidowed                6
# whoEarnedMore                         0
# relationshipQuality_isGood            0
# dtype: int64

# %% [markdown]
# ### Remove unneeded columns

# %% [markdown]
# Columns related to couples first moving in together have over 300 missing values. This is due to not all couples moving in together. Since 300 is a large chunk of our 2275 records, I will remove these columns.

# %%
columns_to_remove = [
    "moveIn_YearFraction",
    "shipStart_to_moveIn_YearFraction",
    "Unnamed: 0", # Also Remove column with no useful info
    "ID" # Also Remove column with no useful info
]

# anything done to the training set has to be done to the testing set
training_set.drop(columns_to_remove, axis=1, inplace=True)
X_train.drop(columns_to_remove, axis=1, inplace=True)
X_test.drop(columns_to_remove, axis=1, inplace=True)

# Recheck the na's
training_set.isna().sum()
# Out:
# ageGap                               0
# attendReligiousServiceFreq           0
# employmentStatus                     0
# genderSubjectAttractedTo             7
# houseType                            0
# householdAdults_num                  0
# householdIncome                      0
# householdMinor_num                   0
# householdSize                        0
# interracial                         19
# isHispanic                           0
# isLivingTogether                     0
# isMarried                            0
# isMetroArea                          0
# metAs_coworkers                     49
# metAs_customerAndClient             49
# metAs_workNeighbors                 49
# metIn_church                        49
# metIn_college                       49
# metIn_military                      49
# metIn_privateParty                  49
# metIn_public                        49
# metIn_restaurantOrBar               49
# metIn_school                        49
# metIn_voluntaryOrg                  49
# metOn_blindDate                     49
# metOn_businessTrip                  49
# metOn_vacation                      49
# metOnline_all                        0
# metOnline_chat                      49
# metOnline_datingSiteOrApp           49
# metOnline_gaming                    49
# metOnline_nonDatingSite             49
# metOnline_other                     49
# metOnline_socialNetwork             49
# metThru_family                      49
# metThru_friend                      49
# metThru_notInternetDatingService    49
# metThru_orAs_neighbors              49
# met_YearFraction                    25
# met_to_shipStart_diff               75
# numRelativesSeePerMonth             13
# ownHouseRentOther                    0
# partnerAge                           0
# partnerEduc_years                    2
# partnerGender                        0
# partnerMotherEduc_years             29
# partnerParty_DemPos_RepNeg           0
# partnerRace                          0
# partyDifference                      0
# region                               0
# season_met                          19
# season_shipStart                    47
# sexFrequency                         0
# shipStart_YearFraction              67
# straightGayLesbian                   0
# subjectAge                           0
# subjectAgeWhenMet                   25
# subjectCountryWhenMetPartner         0
# subjectEduc_years                    0
# subjectGender                        0
# subjectGrewUpInUS                    0
# subjectMotherEduc_years              4
# subjectParty_DemPos_RepNeg           0
# subjectRace                          7
# subjectSexualIdentity                0
# timesDivorcedOrWidowed               6
# whoEarnedMore                        0
# relationshipQuality_isGood           0
# dtype: int64

# %%
# Check all cases and columns
print(training_set.shape)

# Check number of rows with missing values
print("Cases with missing values:", training_set.isna().any(axis=1).sum())
# Out:
# (2275, 69)
# Cases with missing values: 183

# %% [markdown]
# Since 183 records is not too much compared to the 2275 in total, I will op to remove these missing values.

# %%
# Dropping NA values

def cleanDatasets(X_data, y_data):
    
    cols_with_na = X_data.columns[X_data.isna().any()].tolist()
    
    for col in cols_with_na:
        
        indexes = X_data[col].notna()
        X_data = X_data[indexes]
        y_data = y_data[indexes]
    
    # filter odd partner age cases
    age_filter = X_data["partnerAge"] > 5
    X_data = X_data[age_filter]
    y_data = y_data[age_filter]
    
    return X_data, pd.DataFrame(y_data)

# anything done to the training set has to be done to the testing set        
X_train, y_train = cleanDatasets(X_train, y_train)
X_test, y_test = cleanDatasets(X_test, y_test)


# recombine training sets
training_set = pd.concat([X_train, y_train], axis=1)


# Check all cases and columns
print(training_set.shape)

# Check number of rows with missing values
print("Cases with missing values:", training_set.isna().any(axis=1).sum())
# Out:
# (2086, 69)
# Cases with missing values: 0

# %%
print(X_train.shape, X_test.shape)
# Out:
# (2086, 68) (522, 68)

# %% [markdown]
# ---
# ---
#
# # Step 2: Prepare the Data for Machine Learning

# %% [markdown]
# ### One-Hot Encode Categorical Features

# %%
# First get the numeric columns and the categorical columns

numeric_features = X_test._get_numeric_data().columns

categorical_features = list(set(X_test.columns) - set(numeric_features))

print(len(X_test.columns), len(numeric_features), len(categorical_features))

print(X_train.shape, X_test.shape)
# Out:
# 68 21 47
# (2086, 68) (522, 68)

# %%
# One hot encode categorical features for the X_train and X_test sets

X_train = pd.get_dummies(X_train, columns=categorical_features, drop_first=True)
X_test = pd.get_dummies(X_test, columns=categorical_features, drop_first=True)

print(X_train.shape, X_test.shape)
# Out:
# (2086, 109) (522, 103)

# %% [markdown]
# #### Why are the columns different? Which columns are extra?

# %%
extra_cols = []

for col in X_train.columns:

    if col not in X_test.columns:
        
        extra_cols.append(col)
        
print(len(extra_cols), " extra columns:\n",  extra_cols)
# Out:
# 6  extra columns:
#  ['houseType_Boat, RV, van, etc.', 'attendReligiousServiceFreq_Refused', 'subjectSexualIdentity_Something else', 'partnerGender_[Partner Name] is Other, please specify', 'subjectCountryWhenMetPartner_Refused', 'subjectGrewUpInUS_Refused']

# %% [markdown]
# **NOTES:** Some options within the categorical columns were not selected by any of the subjects within the test group, so those options did not become their own columns when one-hot encoding.
#
# - I will create columns with just zeros to fill in this gap, so the machine learning models can work without error.

# %%
def addZeroCols(row, extra_cols):
    
    for col in extra_cols:
        
        row[col] = 0
        
    return row


X_test = X_test.apply(addZeroCols, args=[extra_cols], axis=1)

X_test.shape
# Out:
# (522, 109)

# %% [markdown]
# ### Feature Scaling on Numeric Columns with Standardization

# %%
# import scaling & column transformer
from sklearn.preprocessing import StandardScaler
from sklearn.compose import ColumnTransformer

# Create a function to scale the train and test sets

def scaleCategoricalFeatures(X_data):
    
    scaler = StandardScaler()

    X_data[numeric_features] = scaler.fit_transform(X_data[numeric_features])
    
    return X_data

X_train = scaleCategoricalFeatures(X_train)
X_test = scaleCategoricalFeatures(X_test)

print(X_train.shape, X_test.shape)
# Out:
# (2086, 109) (522, 109)

# %% [markdown]
# ### Make sure it worked by seeing if Standard Deviations of Numeric Columns are 1

# %%
X_train.describe()
# Out:
#              ageGap  householdAdults_num  householdIncome  householdMinor_num  \
# count  2.086000e+03         2.086000e+03     2.086000e+03        2.086000e+03
# mean  -9.822227e-17         2.194367e-16    -1.277342e-17       -1.889402e-16
# std    1.000240e+00         1.000240e+00     1.000240e+00        1.000240e+00
# min   -8.663993e-01        -1.370496e+00    -1.352377e+00       -5.437185e-01
# 25%   -6.528451e-01        -2.246624e-01    -7.233332e-01       -5.437185e-01
# 50%   -2.257368e-01        -2.246624e-01    -2.052970e-01       -5.437185e-01
# 75%    2.013716e-01        -2.246624e-01     2.757367e-01        4.494486e-01
# max    8.743539e+00         7.796171e+00     3.050931e+00        7.401619e+00
#
#        householdSize    isHispanic  met_YearFraction  met_to_shipStart_diff  \
# count   2.086000e+03  2.086000e+03      2.086000e+03           2.086000e+03
# mean   -1.087470e-16 -2.186384e-16      1.468517e-15          -1.836844e-16
# std     1.000240e+00  1.000240e+00      1.000240e+00           1.000240e+00
# min    -1.247327e+00 -3.580187e-01     -3.278417e+00          -3.672507e-01
# 25%    -5.319231e-01 -3.580187e-01     -7.714796e-01          -3.672507e-01
# 50%    -5.319231e-01 -3.580187e-01      1.997939e-01          -3.299298e-01
# 75%     8.988849e-01 -3.580187e-01      8.535088e-01          -1.247741e-01
# max     5.191309e+00  2.793150e+00      1.385658e+00           1.188668e+01
#
#        numRelativesSeePerMonth    partnerAge  partnerEduc_years  \
# count             2.086000e+03  2.086000e+03       2.086000e+03
# mean              9.639940e-18 -2.081003e-16       8.568835e-18
# std               1.000240e+00  1.000240e+00       1.000240e+00
# min              -6.752955e-01 -2.423264e+00      -5.827128e+00
# 25%              -6.752955e-01 -8.720442e-01      -9.278194e-01
# 50%              -2.828547e-01  5.868756e-02      -1.112679e-01
# 75%               3.058066e-01  8.032730e-01       7.052836e-01
# max               9.135726e+00  2.850883e+00       2.338387e+00
#
#        partnerMotherEduc_years  partnerParty_DemPos_RepNeg  partyDifference  \
# count             2.086000e+03                2.086000e+03     2.086000e+03
# mean             -2.720938e-16               -7.792534e-17    -6.946877e-17
# std               1.000240e+00                1.000240e+00     1.000240e+00
# min              -3.986223e+00               -1.556312e+00    -1.010826e+00
# 25%              -1.194090e-01               -5.112559e-01    -1.010826e+00
# 50%              -1.194090e-01                1.127218e-02    -1.629840e-01
# 75%               5.250599e-01                5.338003e-01     6.848579e-01
# max               2.458467e+00                1.578856e+00     4.076225e+00
#
#        shipStart_YearFraction    subjectAge  subjectAgeWhenMet  \
# count            2.086000e+03  2.086000e+03       2.086000e+03
# mean             6.747665e-15 -9.037194e-17      -1.385384e-16
# std              1.000240e+00  1.000240e+00       1.000240e+00
# min             -3.231729e+00 -1.935127e+00      -2.338727e+00
# 25%             -7.566663e-01 -8.847141e-01      -7.247565e-01
# 50%              2.066944e-01  1.039098e-01      -2.764313e-01
# 75%              8.569023e-01  7.835886e-01       4.408889e-01
# max              1.326008e+00  2.699047e+00       5.193135e+00
#
#        subjectEduc_years  subjectMotherEduc_years  subjectParty_DemPos_RepNeg  \
# count       2.086000e+03             2.086000e+03                2.086000e+03
# mean       -2.592472e-16             1.551704e-16               -8.616736e-17
# std         1.000240e+00             1.000240e+00                1.000240e+00
# min        -5.659006e+00            -4.058590e+00               -1.485462e+00
# 25%        -8.623029e-01            -1.338962e-01               -1.013678e+00
# 50%        -4.625776e-01            -1.338962e-01                4.016717e-01
# 75%         7.365983e-01             5.202195e-01                8.734551e-01
# max         2.335499e+00             2.482566e+00                1.345238e+00
#
#        timesDivorcedOrWidowed  metAs_coworkers_yes  metOnline_gaming_yes  \
# count            2.086000e+03          2086.000000           2086.000000
# mean            -4.907122e-17             0.170182              0.003835
# std              1.000240e+00             0.375883              0.061824
# min             -5.390762e-01             0.000000              0.000000
# 25%             -5.390762e-01             0.000000              0.000000
# 50%             -5.390762e-01             0.000000              0.000000
# 75%              9.784851e-01             0.000000              0.000000
# max              5.531169e+00             1.000000              1.000000
#
#        interracial_yes  metOn_blindDate_yes  metIn_church_yes  \
# count      2086.000000          2086.000000       2086.000000
# mean          0.159636             0.033557          0.060403
# std           0.366356             0.180129          0.238289
# min           0.000000             0.000000          0.000000
# 25%           0.000000             0.000000          0.000000
# 50%           0.000000             0.000000          0.000000
# 75%           0.000000             0.000000          0.000000
# max           1.000000             1.000000          1.000000
#
#        metOnline_datingSiteOrApp_yes  metOnline_other_yes  \
# count                    2086.000000          2086.000000
# mean                        0.060882             0.029722
# std                         0.239171             0.169860
# min                         0.000000             0.000000
# 25%                         0.000000             0.000000
# 50%                         0.000000             0.000000
# 75%                         0.000000             0.000000
# max                         1.000000             1.000000
#
#        metOnline_socialNetwork_yes  \
# count                  2086.000000
# mean                      0.013902
# std                       0.117113
# min                       0.000000
# 25%                       0.000000
# 50%                       0.000000
# 75%                       0.000000
# max                       1.000000
#
#        genderSubjectAttractedTo_sexually attracted mostly to same gender, sometimes opposite gender  \
# count                                        2086.000000
# mean                                            0.020614
# std                                             0.142121
# min                                             0.000000
# 25%                                             0.000000
# 50%                                             0.000000
# 75%                                             0.000000
# max                                             1.000000
#
#        genderSubjectAttractedTo_sexually attracted only to opposite gender  \
# count                                        2086.000000
# mean                                            0.807287
# std                                             0.394524
# min                                             0.000000
# 25%                                             1.000000
# 50%                                             1.000000
# 75%                                             1.000000
# max                                             1.000000
#
#        genderSubjectAttractedTo_sexually attracted only to same gender  \
# count                                        2086.000000
# mean                                            0.060882
# std                                             0.239171
# min                                             0.000000
# 25%                                             0.000000
# 50%                                             0.000000
# 75%                                             0.000000
# max                                             1.000000
#
#        genderSubjectAttractedTo_sexually attracted to men and women equally  \
# count                                        2086.000000
# mean                                            0.043145
# std                                             0.203232
# min                                             0.000000
# 25%                                             0.000000
# 50%                                             0.000000
# 75%                                             0.000000
# max                                             1.000000
#
#        region_Northeast  region_South  region_West  metThru_family_yes  \
# count       2086.000000   2086.000000  2086.000000         2086.000000
# mean           0.182646      0.366731     0.227229            0.143816
# std            0.386469      0.482028     0.419142            0.350987
# min            0.000000      0.000000     0.000000            0.000000
# 25%            0.000000      0.000000     0.000000            0.000000
# 50%            0.000000      0.000000     0.000000            0.000000
# 75%            0.000000      1.000000     0.000000            0.000000
# max            1.000000      1.000000     1.000000            1.000000
#
#        metIn_restaurantOrBar_yes  metOn_businessTrip_yes  \
# count                2086.000000             2086.000000
# mean                    0.204698                0.001918
# std                     0.403578                0.043758
# min                     0.000000                0.000000
# 25%                     0.000000                0.000000
# 50%                     0.000000                0.000000
# 75%                     0.000000                0.000000
# max                     1.000000                1.000000
#
#        metThru_orAs_neighbors_yes  season_met_spring  season_met_summer  \
# count                 2086.000000        2086.000000        2086.000000
# mean                     0.059444           0.221477           0.310163
# std                      0.236510           0.415340           0.462671
# min                      0.000000           0.000000           0.000000
# 25%                      0.000000           0.000000           0.000000
# 50%                      0.000000           0.000000           0.000000
# 75%                      0.000000           0.000000           1.000000
# max                      1.000000           1.000000           1.000000
#
#        season_met_winter  houseType_A mobile home  \
# count        2086.000000              2086.000000
# mean            0.191755                 0.034036
# std             0.393775                 0.181366
# min             0.000000                 0.000000
# 25%             0.000000                 0.000000
# 50%             0.000000                 0.000000
# 75%             0.000000                 0.000000
# max             1.000000                 1.000000
#
#        houseType_A one-family house attached to one or more houses  \
# count                                        2086.000000
# mean                                            0.081016
# std                                             0.272926
# min                                             0.000000
# 25%                                             0.000000
# 50%                                             0.000000
# 75%                                             0.000000
# max                                             1.000000
#
#        houseType_A one-family house detached from any other house  \
# count                                        2086.000000
# mean                                            0.731064
# std                                             0.443513
# min                                             0.000000
# 25%                                             0.000000
# 50%                                             1.000000
# 75%                                             1.000000
# max                                             1.000000
#
#        houseType_Boat, RV, van, etc.  metAs_customerAndClient_yes  \
# count                    2086.000000                  2086.000000
# mean                        0.001438                     0.063758
# std                         0.037905                     0.244381
# min                         0.000000                     0.000000
# 25%                         0.000000                     0.000000
# 50%                         0.000000                     0.000000
# 75%                         0.000000                     0.000000
# max                         1.000000                     1.000000
#
#        metAs_workNeighbors_yes  metIn_voluntaryOrg_yes  whoEarnedMore_Refused  \
# count              2086.000000             2086.000000            2086.000000
# mean                  0.013423                0.059444               0.002397
# std                   0.115104                0.236510               0.048911
# min                   0.000000                0.000000               0.000000
# 25%                   0.000000                0.000000               0.000000
# 50%                   0.000000                0.000000               0.000000
# 75%                   0.000000                0.000000               0.000000
# max                   1.000000                1.000000               1.000000
#
#        whoEarnedMore_We earned about the same amount  \
# count                                    2086.000000
# mean                                        0.121285
# std                                         0.326536
# min                                         0.000000
# 25%                                         0.000000
# 50%                                         0.000000
# 75%                                         0.000000
# max                                         1.000000
#
#        whoEarnedMore_[Partner Name] earned more  \
# count                               2086.000000
# mean                                   0.412752
# std                                    0.492447
# min                                    0.000000
# 25%                                    0.000000
# 50%                                    0.000000
# 75%                                    1.000000
# max                                    1.000000
#
#        whoEarnedMore_[Partner Name] was not working for pay  \
# count                                        2086.000000
# mean                                            0.061841
# std                                             0.240924
# min                                             0.000000
# 25%                                             0.000000
# 50%                                             0.000000
# 75%                                             0.000000
# max                                             1.000000
#
#        employmentStatus_retired  employmentStatus_unemployed  \
# count               2086.000000                  2086.000000
# mean                   0.183126                     0.222435
# std                    0.386862                     0.415982
# min                    0.000000                     0.000000
# 25%                    0.000000                     0.000000
# 50%                    0.000000                     0.000000
# 75%                    0.000000                     0.000000
# max                    1.000000                     1.000000
#
#        isLivingTogether_Refused  isLivingTogether_Yes  isMetroArea_Non-Metro  \
# count               2086.000000           2086.000000            2086.000000
# mean                   0.000479              0.845638               0.139022
# std                    0.021895              0.361382               0.346052
# min                    0.000000              0.000000               0.000000
# 25%                    0.000000              1.000000               0.000000
# 50%                    0.000000              1.000000               0.000000
# 75%                    0.000000              1.000000               0.000000
# max                    1.000000              1.000000               1.000000
#
#        attendReligiousServiceFreq_More than once a week  \
# count                                       2086.000000
# mean                                           0.081975
# std                                            0.274393
# min                                            0.000000
# 25%                                            0.000000
# 50%                                            0.000000
# 75%                                            0.000000
# max                                            1.000000
#
#        attendReligiousServiceFreq_Never  \
# count                       2086.000000
# mean                           0.288591
# std                            0.453216
# min                            0.000000
# 25%                            0.000000
# 50%                            0.000000
# 75%                            1.000000
# max                            1.000000
#
#        attendReligiousServiceFreq_Once a week  \
# count                             2086.000000
# mean                                 0.188399
# std                                  0.391124
# min                                  0.000000
# 25%                                  0.000000
# 50%                                  0.000000
# 75%                                  0.000000
# max                                  1.000000
#
#        attendReligiousServiceFreq_Once a year or less  \
# count                                     2086.000000
# mean                                         0.189837
# std                                          0.392266
# min                                          0.000000
# 25%                                          0.000000
# 50%                                          0.000000
# 75%                                          0.000000
# max                                          1.000000
#
#        attendReligiousServiceFreq_Once or twice a month  \
# count                                       2086.000000
# mean                                           0.085331
# std                                            0.279440
# min                                            0.000000
# 25%                                            0.000000
# 50%                                            0.000000
# 75%                                            0.000000
# max                                            1.000000
#
#        attendReligiousServiceFreq_Refused  metOnline_all_yes  \
# count                         2086.000000        2086.000000
# mean                             0.001918           0.119367
# std                              0.043758           0.324298
# min                              0.000000           0.000000
# 25%                              0.000000           0.000000
# 50%                              0.000000           0.000000
# 75%                              0.000000           0.000000
# max                              1.000000           1.000000
#
#        subjectGender_Male  metIn_public_yes  straightGayLesbian_hetero couple  \
# count         2086.000000       2086.000000                       2086.000000
# mean             0.499521          0.034036                          0.922339
# std              0.500120          0.181366                          0.267701
# min              0.000000          0.000000                          0.000000
# 25%              0.000000          0.000000                          1.000000
# 50%              0.000000          0.000000                          1.000000
# 75%              1.000000          0.000000                          1.000000
# max              1.000000          1.000000                          1.000000
#
#        straightGayLesbian_lesbian couple  season_shipStart_spring  \
# count                        2086.000000              2086.000000
# mean                            0.032598                 0.232502
# std                             0.177625                 0.422529
# min                             0.000000                 0.000000
# 25%                             0.000000                 0.000000
# 50%                             0.000000                 0.000000
# 75%                             0.000000                 0.000000
# max                             1.000000                 1.000000
#
#        season_shipStart_summer  season_shipStart_winter  \
# count              2086.000000              2086.000000
# mean                  0.274688                 0.234899
# std                   0.446464                 0.424038
# min                   0.000000                 0.000000
# 25%                   0.000000                 0.000000
# 50%                   0.000000                 0.000000
# 75%                   1.000000                 0.000000
# max                   1.000000                 1.000000
#
#        metOnline_nonDatingSite_yes  metThru_notInternetDatingService_yes  \
# count                  2086.000000                           2086.000000
# mean                      0.001438                              0.010067
# std                       0.037905                              0.099853
# min                       0.000000                              0.000000
# 25%                       0.000000                              0.000000
# 50%                       0.000000                              0.000000
# 75%                       0.000000                              0.000000
# max                       1.000000                              1.000000
#
#        subjectSexualIdentity_Something else  subjectSexualIdentity_bisexual  \
# count                           2086.000000                     2086.000000
# mean                               0.006232                        0.085810
# std                                0.078716                        0.280151
# min                                0.000000                        0.000000
# 25%                                0.000000                        0.000000
# 50%                                0.000000                        0.000000
# 75%                                0.000000                        0.000000
# max                                1.000000                        1.000000
#
#        subjectSexualIdentity_gay  \
# count                2086.000000
# mean                    0.044104
# std                     0.205374
# min                     0.000000
# 25%                     0.000000
# 50%                     0.000000
# 75%                     0.000000
# max                     1.000000
#
#        subjectSexualIdentity_heterosexual or straight  \
# count                                     2086.000000
# mean                                         0.838447
# std                                          0.368129
# min                                          0.000000
# 25%                                          1.000000
# 50%                                          1.000000
# 75%                                          1.000000
# max                                          1.000000
#
#        subjectSexualIdentity_lesbian  \
# count                    2086.000000
# mean                        0.024449
# std                         0.154475
# min                         0.000000
# 25%                         0.000000
# 50%                         0.000000
# 75%                         0.000000
# max                         1.000000
#
#        ownHouseRentOther_Owned or being bought by you or someone in your household  \
# count                                        2086.000000
# mean                                            0.726750
# std                                             0.445735
# min                                             0.000000
# 25%                                             0.000000
# 50%                                             1.000000
# 75%                                             1.000000
# max                                             1.000000
#
#        ownHouseRentOther_Rented for cash  metIn_military_yes  \
# count                        2086.000000         2086.000000
# mean                            0.246405            0.016299
# std                             0.431020            0.126654
# min                             0.000000            0.000000
# 25%                             0.000000            0.000000
# 50%                             0.000000            0.000000
# 75%                             0.000000            0.000000
# max                             1.000000            1.000000
#
#        partnerRace_Asian or Pacific Islander  \
# count                            2086.000000
# mean                                0.045062
# std                                 0.207491
# min                                 0.000000
# 25%                                 0.000000
# 50%                                 0.000000
# 75%                                 0.000000
# max                                 1.000000
#
#        partnerRace_Black or African American  \
# count                            2086.000000
# mean                                0.082934
# std                                 0.275848
# min                                 0.000000
# 25%                                 0.000000
# 50%                                 0.000000
# 75%                                 0.000000
# max                                 1.000000
#
#        partnerRace_Other (please specify)  partnerRace_White  \
# count                         2086.000000        2086.000000
# mean                             0.049856           0.812560
# std                              0.217700           0.390358
# min                              0.000000           0.000000
# 25%                              0.000000           1.000000
# 50%                              0.000000           1.000000
# 75%                              0.000000           1.000000
# max                              1.000000           1.000000
#
#        partnerGender_[Partner Name] is Male  \
# count                           2086.000000
# mean                               0.513423
# std                                0.499940
# min                                0.000000
# 25%                                0.000000
# 50%                                1.000000
# 75%                                1.000000
# max                                1.000000
#
#        partnerGender_[Partner Name] is Other, please specify  \
# count                                        2086.000000
# mean                                            0.001438
# std                                             0.037905
# min                                             0.000000
# 25%                                             0.000000
# 50%                                             0.000000
# 75%                                             0.000000
# max                                             1.000000
#
#        isMarried_Yes, I am Married  subjectRace_Asian or Pacific Islander  \
# count                  2086.000000                            2086.000000
# mean                      0.734420                               0.039789
# std                       0.441747                               0.195510
# min                       0.000000                               0.000000
# 25%                       0.000000                               0.000000
# 50%                       1.000000                               0.000000
# 75%                       1.000000                               0.000000
# max                       1.000000                               1.000000
#
#        subjectRace_Black or African American  \
# count                            2086.000000
# mean                                0.083413
# std                                 0.276572
# min                                 0.000000
# 25%                                 0.000000
# 50%                                 0.000000
# 75%                                 0.000000
# max                                 1.000000
#
#        subjectRace_Other (please specify)  subjectRace_White  \
# count                         2086.000000        2086.000000
# mean                             0.022052           0.821668
# std                              0.146887           0.382884
# min                              0.000000           0.000000
# 25%                              0.000000           1.000000
# 50%                              0.000000           1.000000
# 75%                              0.000000           1.000000
# max                              1.000000           1.000000
#
#        sexFrequency_3 to 6 times a week  sexFrequency_Once a day or more  \
# count                       2086.000000                      2086.000000
# mean                           0.131352                         0.028763
# std                            0.337866                         0.167180
# min                            0.000000                         0.000000
# 25%                            0.000000                         0.000000
# 50%                            0.000000                         0.000000
# 75%                            0.000000                         0.000000
# max                            1.000000                         1.000000
#
#        sexFrequency_Once a month or less  sexFrequency_Once or twice a week  \
# count                        2086.000000                        2086.000000
# mean                            0.351390                           0.261745
# std                             0.477519                           0.439690
# min                             0.000000                           0.000000
# 25%                             0.000000                           0.000000
# 50%                             0.000000                           0.000000
# 75%                             1.000000                           1.000000
# max                             1.000000                           1.000000
#
#        sexFrequency_Refused  subjectCountryWhenMetPartner_Refused  \
# count           2086.000000                           2086.000000
# mean               0.041707                              0.000479
# std                0.199966                              0.021895
# min                0.000000                              0.000000
# 25%                0.000000                              0.000000
# 50%                0.000000                              0.000000
# 75%                0.000000                              0.000000
# max                1.000000                              1.000000
#
#        subjectCountryWhenMetPartner_United States  metOnline_chat_yes  \
# count                                 2086.000000         2086.000000
# mean                                     0.965484            0.010067
# std                                      0.182594            0.099853
# min                                      0.000000            0.000000
# 25%                                      1.000000            0.000000
# 50%                                      1.000000            0.000000
# 75%                                      1.000000            0.000000
# max                                      1.000000            1.000000
#
#        metIn_college_yes  metIn_school_yes  metThru_friend_yes  \
# count        2086.000000       2086.000000         2086.000000
# mean            0.082454          0.108821            0.296740
# std             0.275122          0.311489            0.456931
# min             0.000000          0.000000            0.000000
# 25%             0.000000          0.000000            0.000000
# 50%             0.000000          0.000000            0.000000
# 75%             0.000000          0.000000            1.000000
# max             1.000000          1.000000            1.000000
#
#        subjectGrewUpInUS_Refused  subjectGrewUpInUS_United States  \
# count                2086.000000                      2086.000000
# mean                    0.000479                         0.942474
# std                     0.021895                         0.232901
# min                     0.000000                         0.000000
# 25%                     0.000000                         1.000000
# 50%                     0.000000                         1.000000
# 75%                     0.000000                         1.000000
# max                     1.000000                         1.000000
#
#        metOn_vacation_yes  metIn_privateParty_yes
# count         2086.000000             2086.000000
# mean             0.014861                0.101630
# std              0.121025                0.302233
# min              0.000000                0.000000
# 25%              0.000000                0.000000
# 50%              0.000000                0.000000
# 75%              0.000000                0.000000
# max              1.000000                1.000000

# %%
# alphbetize column names

X_train = X_train.sort_index(axis=1)
X_test = X_test.sort_index(axis=1)

X_train.info(verbose=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2086 entries, 1994 to 75
# Data columns (total 109 columns):
#  #    Column                                                                                        Dtype
# ---   ------                                                                                        -----
#  0    ageGap                                                                                        float64
#  1    attendReligiousServiceFreq_More than once a week                                              uint8
#  2    attendReligiousServiceFreq_Never                                                              uint8
#  3    attendReligiousServiceFreq_Once a week                                                        uint8
#  4    attendReligiousServiceFreq_Once a year or less                                                uint8
#  5    attendReligiousServiceFreq_Once or twice a month                                              uint8
#  6    attendReligiousServiceFreq_Refused                                                            uint8
#  7    employmentStatus_retired                                                                      uint8
#  8    employmentStatus_unemployed                                                                   uint8
#  9    genderSubjectAttractedTo_sexually attracted mostly to same gender, sometimes opposite gender  uint8
#  10   genderSubjectAttractedTo_sexually attracted only to opposite gender                           uint8
#  11   genderSubjectAttractedTo_sexually attracted only to same gender                               uint8
#  12   genderSubjectAttractedTo_sexually attracted to men and women equally                          uint8
#  13   houseType_A mobile home                                                                       uint8
#  14   houseType_A one-family house attached to one or more houses                                   uint8
#  15   houseType_A one-family house detached from any other house                                    uint8
#  16   houseType_Boat, RV, van, etc.                                                                 uint8
#  17   householdAdults_num                                                                           float64
#  18   householdIncome                                                                               float64
#  19   householdMinor_num                                                                            float64
#  20   householdSize                                                                                 float64
#  21   interracial_yes                                                                               uint8
#  22   isHispanic                                                                                    float64
#  23   isLivingTogether_Refused                                                                      uint8
#  24   isLivingTogether_Yes                                                                          uint8
#  25   isMarried_Yes, I am Married                                                                   uint8
#  26   isMetroArea_Non-Metro                                                                         uint8
#  27   metAs_coworkers_yes                                                                           uint8
#  28   metAs_customerAndClient_yes                                                                   uint8
#  29   metAs_workNeighbors_yes                                                                       uint8
#  30   metIn_church_yes                                                                              uint8
#  31   metIn_college_yes                                                                             uint8
#  32   metIn_military_yes                                                                            uint8
#  33   metIn_privateParty_yes                                                                        uint8
#  34   metIn_public_yes                                                                              uint8
#  35   metIn_restaurantOrBar_yes                                                                     uint8
#  36   metIn_school_yes                                                                              uint8
#  37   metIn_voluntaryOrg_yes                                                                        uint8
#  38   metOn_blindDate_yes                                                                           uint8
#  39   metOn_businessTrip_yes                                                                        uint8
#  40   metOn_vacation_yes                                                                            uint8
#  41   metOnline_all_yes                                                                             uint8
#  42   metOnline_chat_yes                                                                            uint8
#  43   metOnline_datingSiteOrApp_yes                                                                 uint8
#  44   metOnline_gaming_yes                                                                          uint8
#  45   metOnline_nonDatingSite_yes                                                                   uint8
#  46   metOnline_other_yes                                                                           uint8
#  47   metOnline_socialNetwork_yes                                                                   uint8
#  48   metThru_family_yes                                                                            uint8
#  49   metThru_friend_yes                                                                            uint8
#  50   metThru_notInternetDatingService_yes                                                          uint8
#  51   metThru_orAs_neighbors_yes                                                                    uint8
#  52   met_YearFraction                                                                              float64
#  53   met_to_shipStart_diff                                                                         float64
#  54   numRelativesSeePerMonth                                                                       float64
#  55   ownHouseRentOther_Owned or being bought by you or someone in your household                   uint8
#  56   ownHouseRentOther_Rented for cash                                                             uint8
#  57   partnerAge                                                                                    float64
#  58   partnerEduc_years                                                                             float64
#  59   partnerGender_[Partner Name] is Male                                                          uint8
#  60   partnerGender_[Partner Name] is Other, please specify                                         uint8
#  61   partnerMotherEduc_years                                                                       float64
#  62   partnerParty_DemPos_RepNeg                                                                    float64
#  63   partnerRace_Asian or Pacific Islander                                                         uint8
#  64   partnerRace_Black or African American                                                         uint8
#  65   partnerRace_Other (please specify)                                                            uint8
#  66   partnerRace_White                                                                             uint8
#  67   partyDifference                                                                               float64
#  68   region_Northeast                                                                              uint8
#  69   region_South                                                                                  uint8
#  70   region_West                                                                                   uint8
#  71   season_met_spring                                                                             uint8
#  72   season_met_summer                                                                             uint8
#  73   season_met_winter                                                                             uint8
#  74   season_shipStart_spring                                                                       uint8
#  75   season_shipStart_summer                                                                       uint8
#  76   season_shipStart_winter                                                                       uint8
#  77   sexFrequency_3 to 6 times a week                                                              uint8
#  78   sexFrequency_Once a day or more                                                               uint8
#  79   sexFrequency_Once a month or less                                                             uint8
#  80   sexFrequency_Once or twice a week                                                             uint8
#  81   sexFrequency_Refused                                                                          uint8
#  82   shipStart_YearFraction                                                                        float64
#  83   straightGayLesbian_hetero couple                                                              uint8
#  84   straightGayLesbian_lesbian couple                                                             uint8
#  85   subjectAge                                                                                    float64
#  86   subjectAgeWhenMet                                                                             float64
#  87   subjectCountryWhenMetPartner_Refused                                                          uint8
#  88   subjectCountryWhenMetPartner_United States                                                    uint8
#  89   subjectEduc_years                                                                             float64
#  90   subjectGender_Male                                                                            uint8
#  91   subjectGrewUpInUS_Refused                                                                     uint8
#  92   subjectGrewUpInUS_United States                                                               uint8
#  93   subjectMotherEduc_years                                                                       float64
#  94   subjectParty_DemPos_RepNeg                                                                    float64
#  95   subjectRace_Asian or Pacific Islander                                                         uint8
#  96   subjectRace_Black or African American                                                         uint8
#  97   subjectRace_Other (please specify)                                                            uint8
#  98   subjectRace_White                                                                             uint8
#  99   subjectSexualIdentity_Something else                                                          uint8
#  100  subjectSexualIdentity_bisexual                                                                uint8
#  101  subjectSexualIdentity_gay                                                                     uint8
#  102  subjectSexualIdentity_heterosexual or straight                                                uint8
#  103  subjectSexualIdentity_lesbian                                                                 uint8
#  104  timesDivorcedOrWidowed                                                                        float64
#  105  whoEarnedMore_Refused                                                                         uint8
#  106  whoEarnedMore_We earned about the same amount                                                 uint8
#  107  whoEarnedMore_[Partner Name] earned more                                                      uint8
#  108  whoEarnedMore_[Partner Name] was not working for pay                                          uint8
# dtypes: float64(21), uint8(88)
# memory usage: 602.3 KB

# %% [markdown]
# ---
# ---
# # Step 3: Logistic Regression - Coefficients & P-Values

# %% [markdown]
# ### Fix all column names - StatsModels doesn't work with spaces in name

# %%
def replaceChars(col):
    
    chars = [",", " ", "(", ")", ".", "-"]
    result = col[:]
    
    for txt in chars:
        
        result = result.replace(txt, "_")
    
    result = result.replace("[Partner Name]", "_partner_")
    result = result.replace("[Partner_Name]", "_partner_")
    result = result.replace("__please_specify_", "")
    
    return result

X_train.columns = [replaceChars(col) for col in X_train.columns]
X_test.columns = [replaceChars(col) for col in X_test.columns]

list(X_train.columns)
# Out:
# ['ageGap',
#  'attendReligiousServiceFreq_More_than_once_a_week',
#  'attendReligiousServiceFreq_Never',
#  'attendReligiousServiceFreq_Once_a_week',
#  'attendReligiousServiceFreq_Once_a_year_or_less',
#  'attendReligiousServiceFreq_Once_or_twice_a_month',
#  'attendReligiousServiceFreq_Refused',
#  'employmentStatus_retired',
#  'employmentStatus_unemployed',
#  'genderSubjectAttractedTo_sexually_attracted_mostly_to_same_gender__sometimes_opposite_gender',
#  'genderSubjectAttractedTo_sexually_attracted_only_to_opposite_gender',
#  'genderSubjectAttractedTo_sexually_attracted_only_to_same_gender',
#  'genderSubjectAttractedTo_sexually_attracted_to_men_and_women_equally',
#  'houseType_A_mobile_home',
#  'houseType_A_one_family_house_attached_to_one_or_more_houses',
#  'houseType_A_one_family_house_detached_from_any_other_house',
#  'houseType_Boat__RV__van__etc_',
#  'householdAdults_num',
#  'householdIncome',
#  'householdMinor_num',
#  'householdSize',
#  'interracial_yes',
#  'isHispanic',
#  'isLivingTogether_Refused',
#  'isLivingTogether_Yes',
#  'isMarried_Yes__I_am_Married',
#  'isMetroArea_Non_Metro',
#  'metAs_coworkers_yes',
#  'metAs_customerAndClient_yes',
#  'metAs_workNeighbors_yes',
#  'metIn_church_yes',
#  'metIn_college_yes',
#  'metIn_military_yes',
#  'metIn_privateParty_yes',
#  'metIn_public_yes',
#  'metIn_restaurantOrBar_yes',
#  'metIn_school_yes',
#  'metIn_voluntaryOrg_yes',
#  'metOn_blindDate_yes',
#  'metOn_businessTrip_yes',
#  'metOn_vacation_yes',
#  'metOnline_all_yes',
#  'metOnline_chat_yes',
#  'metOnline_datingSiteOrApp_yes',
#  'metOnline_gaming_yes',
#  'metOnline_nonDatingSite_yes',
#  'metOnline_other_yes',
#  'metOnline_socialNetwork_yes',
#  'metThru_family_yes',
#  'metThru_friend_yes',
#  'metThru_notInternetDatingService_yes',
#  'metThru_orAs_neighbors_yes',
#  'met_YearFraction',
#  'met_to_shipStart_diff',
#  'numRelativesSeePerMonth',
#  'ownHouseRentOther_Owned_or_being_bought_by_you_or_someone_in_your_household',
#  'ownHouseRentOther_Rented_for_cash',
#  'partnerAge',
#  'partnerEduc_years',
#  'partnerGender__partner__is_Male',
#  'partnerGender__partner__is_Other__please_specify',
#  'partnerMotherEduc_years',
#  'partnerParty_DemPos_RepNeg',
#  'partnerRace_Asian_or_Pacific_Islander',
#  'partnerRace_Black_or_African_American',
#  'partnerRace_Other',
#  'partnerRace_White',
#  'partyDifference',
#  'region_Northeast',
#  'region_South',
#  'region_West',
#  'season_met_spring',
#  'season_met_summer',
#  'season_met_winter',
#  'season_shipStart_spring',
#  'season_shipStart_summer',
#  'season_shipStart_winter',
#  'sexFrequency_3_to_6_times_a_week',
#  'sexFrequency_Once_a_day_or_more',
#  'sexFrequency_Once_a_month_or_less',
#  'sexFrequency_Once_or_twice_a_week',
#  'sexFrequency_Refused',
#  'shipStart_YearFraction',
#  'straightGayLesbian_hetero_couple',
#  'straightGayLesbian_lesbian_couple',
#  'subjectAge',
#  'subjectAgeWhenMet',
#  'subjectCountryWhenMetPartner_Refused',
#  'subjectCountryWhenMetPartner_United_States',
#  'subjectEduc_years',
#  'subjectGender_Male',
#  'subjectGrewUpInUS_Refused',
#  'subjectGrewUpInUS_United_States',
#  'subjectMotherEduc_years',
#  'subjectParty_DemPos_RepNeg',
#  'subjectRace_Asian_or_Pacific_Islander',
#  'subjectRace_Black_or_African_American',
#  'subjectRace_Other',
#  'subjectRace_White',
#  'subjectSexualIdentity_Something_else',
#  'subjectSexualIdentity_bisexual',
#  'subjectSexualIdentity_gay',
#  'subjectSexualIdentity_heterosexual_or_straight',
#  'subjectSexualIdentity_lesbian',
#  'timesDivorcedOrWidowed',
#  'whoEarnedMore_Refused',
#  'whoEarnedMore_We_earned_about_the_same_amount',
#  'whoEarnedMore__partner__earned_more',
#  'whoEarnedMore__partner__was_not_working_for_pay']

# %% [markdown]
# ### Logistic Regression with StatModels

# %%
# import models for logistic regression summary
# in the style of R summary
import statsmodels.formula.api as smf

import warnings
warnings.filterwarnings('ignore')


train_data = pd.concat([X_train, y_train], axis=1)


# select predictors for the model
predictor_list = list(train_data.columns)

outcome_var = "relationshipQuality_isGood"

predictor_list.remove(outcome_var)

predictor_vars = " + ".join(predictor_list)



log_model = smf.logit(f"{outcome_var} ~ {predictor_vars}", data=train_data)

result = log_model.fit(method='bfgs')


result.summary()
# Out:
# Warning: Maximum number of iterations has been exceeded.
#          Current function value: 0.240266
#          Iterations: 35
#          Function evaluations: 36
#          Gradient evaluations: 36
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                Logit Regression Results
# ======================================================================================
# Dep. Variable:     relationshipQuality_isGood   No. Observations:                 2086
# Model:                                  Logit   Df Residuals:                     1977
# Method:                                   MLE   Df Model:                          108
# Date:                        Sun, 25 Sep 2022   Pseudo R-squ.:                  0.1855
# Time:                                14:53:10   Log-Likelihood:                -501.19
# converged:                              False   LL-Null:                       -615.37
# Covariance Type:                    nonrobust   LLR p-value:                 1.262e-10
# ================================================================================================================================================================
#                                                                                                    coef    std err          z      P>|z|      [0.025      0.975]
# ----------------------------------------------------------------------------------------------------------------------------------------------------------------
# Intercept                                                                                        0.4390      3.859      0.114      0.909      -7.124       8.002
# ageGap                                                                                          -0.0399      0.087     -0.457      0.648      -0.211       0.131
# attendReligiousServiceFreq_More_than_once_a_week                                                 0.4977      0.463      1.076      0.282      -0.409       1.404
# attendReligiousServiceFreq_Never                                                                -0.2609      0.275     -0.949      0.343      -0.800       0.278
# attendReligiousServiceFreq_Once_a_week                                                           0.1593      0.310      0.514      0.607      -0.448       0.766
# attendReligiousServiceFreq_Once_a_year_or_less                                                  -0.1048      0.299     -0.351      0.726      -0.690       0.481
# attendReligiousServiceFreq_Once_or_twice_a_month                                                 0.1272      0.368      0.345      0.730      -0.595       0.849
# attendReligiousServiceFreq_Refused                                                              -0.2978      1.594     -0.187      0.852      -3.422       2.827
# employmentStatus_retired                                                                         0.0706      0.331      0.213      0.831      -0.578       0.719
# employmentStatus_unemployed                                                                     -0.1542      0.221     -0.696      0.486      -0.588       0.280
# genderSubjectAttractedTo_sexually_attracted_mostly_to_same_gender__sometimes_opposite_gender     0.1981      0.801      0.247      0.805      -1.371       1.767
# genderSubjectAttractedTo_sexually_attracted_only_to_opposite_gender                              0.6848      0.398      1.719      0.086      -0.096       1.466
# genderSubjectAttractedTo_sexually_attracted_only_to_same_gender                                  0.1135      0.884      0.128      0.898      -1.619       1.846
# genderSubjectAttractedTo_sexually_attracted_to_men_and_women_equally                            -0.2533      0.461     -0.550      0.582      -1.156       0.649
# houseType_A_mobile_home                                                                         -0.1726      0.533     -0.324      0.746      -1.216       0.871
# houseType_A_one_family_house_attached_to_one_or_more_houses                                     -0.0942      0.346     -0.272      0.786      -0.773       0.585
# houseType_A_one_family_house_detached_from_any_other_house                                      -0.1365      0.293     -0.466      0.641      -0.710       0.437
# houseType_Boat__RV__van__etc_                                                                    0.0205      4.094      0.005      0.996      -8.004       8.046
# householdAdults_num                                                                             -0.0045   1.22e+06  -3.73e-09      1.000   -2.39e+06    2.39e+06
# householdIncome                                                                                  0.2021      0.126      1.604      0.109      -0.045       0.449
# householdMinor_num                                                                              -0.0991   1.41e+06  -7.05e-08      1.000   -2.76e+06    2.76e+06
# householdSize                                                                                   -0.0742   1.95e+06   -3.8e-08      1.000   -3.83e+06    3.83e+06
# interracial_yes                                                                                  0.1445      0.298      0.484      0.628      -0.440       0.729
# isHispanic                                                                                      -0.0999      0.090     -1.113      0.266      -0.276       0.076
# isLivingTogether_Refused                                                                         0.0293      2.756      0.011      0.992      -5.372       5.431
# isLivingTogether_Yes                                                                             0.8937      0.257      3.482      0.000       0.391       1.397
# isMarried_Yes__I_am_Married                                                                      0.1220      0.266      0.458      0.647      -0.400       0.644
# isMetroArea_Non_Metro                                                                            0.4477      0.295      1.519      0.129      -0.130       1.025
# metAs_coworkers_yes                                                                             -0.6605      0.253     -2.606      0.009      -1.157      -0.164
# metAs_customerAndClient_yes                                                                      0.1002      0.414      0.242      0.809      -0.711       0.911
# metAs_workNeighbors_yes                                                                          0.4646      0.934      0.497      0.619      -1.367       2.296
# metIn_church_yes                                                                                 0.0414      0.459      0.090      0.928      -0.859       0.942
# metIn_college_yes                                                                                0.3156      0.455      0.694      0.487      -0.575       1.206
# metIn_military_yes                                                                              -0.1657      0.772     -0.215      0.830      -1.678       1.347
# metIn_privateParty_yes                                                                          -0.0108      0.315     -0.034      0.973      -0.627       0.606
# metIn_public_yes                                                                                -0.1926      0.468     -0.412      0.681      -1.109       0.724
# metIn_restaurantOrBar_yes                                                                        0.2172      0.249      0.872      0.383      -0.271       0.705
# metIn_school_yes                                                                                 0.4278      0.384      1.113      0.266      -0.326       1.181
# metIn_voluntaryOrg_yes                                                                          -0.2136      0.428     -0.499      0.617      -1.052       0.625
# metOn_blindDate_yes                                                                              0.3927      0.630      0.623      0.533      -0.843       1.628
# metOn_businessTrip_yes                                                                           0.0591      2.046      0.029      0.977      -3.952       4.070
# metOn_vacation_yes                                                                               0.4213      0.898      0.469      0.639      -1.338       2.181
# metOnline_all_yes                                                                                0.2492      7.230      0.034      0.973     -13.922      14.420
# metOnline_chat_yes                                                                              -0.1556      7.260     -0.021      0.983     -14.385      14.074
# metOnline_datingSiteOrApp_yes                                                                    0.1297      7.228      0.018      0.986     -14.037      14.296
# metOnline_gaming_yes                                                                             0.1182      7.387      0.016      0.987     -14.360      14.596
# metOnline_nonDatingSite_yes                                                                      0.0792      6.886      0.011      0.991     -13.417      13.575
# metOnline_other_yes                                                                              0.1761      7.233      0.024      0.981     -14.000      14.352
# metOnline_socialNetwork_yes                                                                     -0.0882      7.183     -0.012      0.990     -14.166      13.990
# metThru_family_yes                                                                              -0.4629      0.247     -1.871      0.061      -0.948       0.022
# metThru_friend_yes                                                                              -0.0347      0.221     -0.157      0.875      -0.467       0.398
# metThru_notInternetDatingService_yes                                                             0.3886      0.993      0.392      0.695      -1.557       2.334
# metThru_orAs_neighbors_yes                                                                       0.4585      0.437      1.050      0.294      -0.397       1.314
# met_YearFraction                                                                                -0.3251     93.761     -0.003      0.997    -184.092     183.442
# met_to_shipStart_diff                                                                            0.3275     24.857      0.013      0.989     -48.391      49.046
# numRelativesSeePerMonth                                                                          0.0870      0.100      0.870      0.384      -0.109       0.283
# ownHouseRentOther_Owned_or_being_bought_by_you_or_someone_in_your_household                      0.5949      0.452      1.315      0.188      -0.292       1.481
# ownHouseRentOther_Rented_for_cash                                                                0.4780      0.462      1.034      0.301      -0.428       1.384
# partnerAge                                                                                      -0.5069      0.241     -2.104      0.035      -0.979      -0.035
# partnerEduc_years                                                                                0.1372      0.111      1.234      0.217      -0.081       0.355
# partnerGender__partner__is_Male                                                                  0.1511      0.974      0.155      0.877      -1.758       2.060
# partnerGender__partner__is_Other__please_specify                                                 0.0483      2.513      0.019      0.985      -4.876       4.973
# partnerMotherEduc_years                                                                          0.2523      0.089      2.828      0.005       0.077       0.427
# partnerParty_DemPos_RepNeg                                                                       0.0572      0.127      0.451      0.652      -0.191       0.306
# partnerRace_Asian_or_Pacific_Islander                                                            0.7416      0.887      0.836      0.403      -0.998       2.481
# partnerRace_Black_or_African_American                                                           -0.0576      0.828     -0.070      0.945      -1.681       1.565
# partnerRace_Other                                                                                0.1679      0.815      0.206      0.837      -1.429       1.765
# partnerRace_White                                                                                0.2732      0.743      0.368      0.713      -1.182       1.729
# partyDifference                                                                                  0.0584      0.095      0.616      0.538      -0.127       0.244
# region_Northeast                                                                                -0.0750      0.278     -0.270      0.787      -0.619       0.470
# region_South                                                                                     0.0877      0.241      0.365      0.715      -0.384       0.559
# region_West                                                                                      0.2441      0.278      0.879      0.379      -0.300       0.788
# season_met_spring                                                                                0.2079      0.358      0.581      0.561      -0.494       0.910
# season_met_summer                                                                                0.2944      0.279      1.055      0.291      -0.253       0.841
# season_met_winter                                                                                0.4261      0.371      1.150      0.250      -0.300       1.152
# season_shipStart_spring                                                                         -0.2681      0.275     -0.974      0.330      -0.807       0.271
# season_shipStart_summer                                                                         -0.1002      0.271     -0.370      0.712      -0.632       0.431
# season_shipStart_winter                                                                         -0.2502      0.265     -0.946      0.344      -0.769       0.268
# sexFrequency_3_to_6_times_a_week                                                                 0.8945      0.356      2.513      0.012       0.197       1.592
# sexFrequency_Once_a_day_or_more                                                                  0.1124      0.504      0.223      0.823      -0.875       1.099
# sexFrequency_Once_a_month_or_less                                                               -0.8633      0.256     -3.377      0.001      -1.364      -0.362
# sexFrequency_Once_or_twice_a_week                                                                0.5145      0.296      1.736      0.083      -0.066       1.095
# sexFrequency_Refused                                                                            -0.1223      0.504     -0.243      0.808      -1.111       0.866
# shipStart_YearFraction                                                                          -0.2425     92.153     -0.003      0.998    -180.859     180.374
# straightGayLesbian_hetero_couple                                                                -0.0009      1.300     -0.001      0.999      -2.549       2.548
# straightGayLesbian_lesbian_couple                                                                0.3967      2.177      0.182      0.855      -3.871       4.664
# subjectAge                                                                                       0.4637      8.170      0.057      0.955     -15.549      16.477
# subjectAgeWhenMet                                                                                0.1886      5.624      0.034      0.973     -10.835      11.212
# subjectCountryWhenMetPartner_Refused                                                             0.0048     12.788      0.000      1.000     -25.059      25.069
# subjectCountryWhenMetPartner_United_States                                                      -0.1567      0.603     -0.260      0.795      -1.339       1.026
# subjectEduc_years                                                                                0.0662      0.119      0.556      0.578      -0.167       0.300
# subjectGender_Male                                                                              -0.0701      0.971     -0.072      0.942      -1.973       1.833
# subjectGrewUpInUS_Refused                                                                        0.0195      5.035      0.004      0.997      -9.849       9.888
# subjectGrewUpInUS_United_States                                                                 -0.2031      0.449     -0.453      0.651      -1.082       0.676
# subjectMotherEduc_years                                                                          0.0935      0.095      0.981      0.327      -0.093       0.280
# subjectParty_DemPos_RepNeg                                                                       0.0048      0.125      0.038      0.970      -0.241       0.250
# subjectRace_Asian_or_Pacific_Islander                                                           -0.6082      0.637     -0.955      0.340      -1.857       0.640
# subjectRace_Black_or_African_American                                                           -0.0136      0.645     -0.021      0.983      -1.278       1.251
# subjectRace_Other                                                                                0.0243      0.700      0.035      0.972      -1.348       1.397
# subjectRace_White                                                                                0.3104      0.523      0.594      0.553      -0.714       1.335
# subjectSexualIdentity_Something_else                                                            -0.3161      3.164     -0.100      0.920      -6.517       5.885
# subjectSexualIdentity_bisexual                                                                   0.3333      3.045      0.109      0.913      -5.635       6.302
# subjectSexualIdentity_gay                                                                        0.1262      3.198      0.039      0.969      -6.143       6.395
# subjectSexualIdentity_heterosexual_or_straight                                                   0.0557      3.011      0.018      0.985      -5.845       5.956
# subjectSexualIdentity_lesbian                                                                    0.2118      3.205      0.066      0.947      -6.070       6.494
# timesDivorcedOrWidowed                                                                          -0.1790      0.102     -1.750      0.080      -0.379       0.021
# whoEarnedMore_Refused                                                                            0.0694      1.859      0.037      0.970      -3.575       3.714
# whoEarnedMore_We_earned_about_the_same_amount                                                    0.7870      0.325      2.425      0.015       0.151       1.423
# whoEarnedMore__partner__earned_more                                                              0.2732      0.222      1.231      0.218      -0.162       0.708
# whoEarnedMore__partner__was_not_working_for_pay                                                  0.5132      0.432      1.188      0.235      -0.333       1.360
# ================================================================================================================================================================
# """

# %% [markdown]
# ### Backwards Elimination: Logistic Regression with (Alpha Level 0.15)
#
# - I have chosen 0.15 as the alpha level instead of 0.05 because some features might change in significance when features are removed.
#
# - At the last state of backwards elimination, I will eliminate based on a threshold of 0.05 as it is conventional.

# %%
import warnings
warnings.filterwarnings('ignore')


features_to_keep = [
    "genderSubjectAttractedTo_sexually_attracted_only_to_opposite_gender",
    "householdIncome",
    "isLivingTogether_Yes",
    "isMetroArea_Non_Metro",
    "metAs_coworkers_yes",
    "metThru_family_yes",
    "partnerAge",
    "partnerMotherEduc_years",
    "sexFrequency_3_to_6_times_a_week",
    "sexFrequency_Once_a_month_or_less",
    "sexFrequency_Once_or_twice_a_week",
    "timesDivorcedOrWidowed",
    "whoEarnedMore_We_earned_about_the_same_amount"
]


train_data = pd.concat([X_train[features_to_keep], y_train], axis=1)

# select predictors for the model
predictor_list = list(train_data.columns)

outcome_var = "relationshipQuality_isGood"

predictor_list.remove(outcome_var)

predictor_vars = " + ".join(predictor_list)


log_model = smf.logit(f"{outcome_var} ~ {predictor_vars}", data=train_data)

result = log_model.fit(method='bfgs')


result.summary()
# Out:
# Warning: Maximum number of iterations has been exceeded.
#          Current function value: 0.260504
#          Iterations: 35
#          Function evaluations: 36
#          Gradient evaluations: 36
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                Logit Regression Results
# ======================================================================================
# Dep. Variable:     relationshipQuality_isGood   No. Observations:                 2086
# Model:                                  Logit   Df Residuals:                     2072
# Method:                                   MLE   Df Model:                           13
# Date:                        Sun, 25 Sep 2022   Pseudo R-squ.:                  0.1169
# Time:                                14:53:25   Log-Likelihood:                -543.41
# converged:                              False   LL-Null:                       -615.37
# Covariance Type:                    nonrobust   LLR p-value:                 3.461e-24
# =======================================================================================================================================
#                                                                           coef    std err          z      P>|z|      [0.025      0.975]
# ---------------------------------------------------------------------------------------------------------------------------------------
# Intercept                                                               1.7157      0.266      6.452      0.000       1.194       2.237
# genderSubjectAttractedTo_sexually_attracted_only_to_opposite_gender     0.4277      0.190      2.247      0.025       0.055       0.801
# householdIncome                                                         0.3271      0.104      3.136      0.002       0.123       0.532
# isLivingTogether_Yes                                                    0.8070      0.194      4.168      0.000       0.428       1.186
# isMetroArea_Non_Metro                                                   0.4306      0.263      1.637      0.102      -0.085       0.946
# metAs_coworkers_yes                                                    -0.7209      0.198     -3.637      0.000      -1.109      -0.332
# metThru_family_yes                                                     -0.3878      0.227     -1.712      0.087      -0.832       0.056
# partnerAge                                                              0.4465      0.100      4.467      0.000       0.251       0.642
# partnerMotherEduc_years                                                 0.2617      0.074      3.515      0.000       0.116       0.408
# sexFrequency_3_to_6_times_a_week                                        0.6957      0.311      2.234      0.025       0.085       1.306
# sexFrequency_Once_a_month_or_less                                      -0.7177      0.204     -3.510      0.000      -1.118      -0.317
# sexFrequency_Once_or_twice_a_week                                       0.6926      0.263      2.633      0.008       0.177       1.208
# timesDivorcedOrWidowed                                                 -0.1453      0.078     -1.857      0.063      -0.299       0.008
# whoEarnedMore_We_earned_about_the_same_amount                           0.4975      0.278      1.786      0.074      -0.048       1.043
# =======================================================================================================================================
# """

# %% [markdown]
# ### Backwards Elimination: Logistic Regression with (Alpha Level 0.10)

# %%
import warnings
warnings.filterwarnings('ignore')


features_to_keep = [
    "genderSubjectAttractedTo_sexually_attracted_only_to_opposite_gender",
    "householdIncome",
    "isLivingTogether_Yes",
    "metAs_coworkers_yes",
    "metThru_family_yes",
    "partnerAge",
    "partnerMotherEduc_years",
    "sexFrequency_3_to_6_times_a_week",
    "sexFrequency_Once_a_month_or_less",
    "sexFrequency_Once_or_twice_a_week",
    "timesDivorcedOrWidowed",
    "whoEarnedMore_We_earned_about_the_same_amount"
]


train_data = pd.concat([X_train[features_to_keep], y_train], axis=1)

# select predictors for the model
predictor_list = list(train_data.columns)

outcome_var = "relationshipQuality_isGood"

predictor_list.remove(outcome_var)

predictor_vars = " + ".join(predictor_list)


log_model = smf.logit(f"{outcome_var} ~ {predictor_vars}", data=train_data)

result = log_model.fit(method='bfgs')


result.summary()
# Out:
# Warning: Maximum number of iterations has been exceeded.
#          Current function value: 0.261213
#          Iterations: 35
#          Function evaluations: 36
#          Gradient evaluations: 36
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                Logit Regression Results
# ======================================================================================
# Dep. Variable:     relationshipQuality_isGood   No. Observations:                 2086
# Model:                                  Logit   Df Residuals:                     2073
# Method:                                   MLE   Df Model:                           12
# Date:                        Sun, 25 Sep 2022   Pseudo R-squ.:                  0.1145
# Time:                                14:53:31   Log-Likelihood:                -544.89
# converged:                              False   LL-Null:                       -615.37
# Covariance Type:                    nonrobust   LLR p-value:                 3.846e-24
# =======================================================================================================================================
#                                                                           coef    std err          z      P>|z|      [0.025      0.975]
# ---------------------------------------------------------------------------------------------------------------------------------------
# Intercept                                                               1.7290      0.266      6.509      0.000       1.208       2.250
# genderSubjectAttractedTo_sexually_attracted_only_to_opposite_gender     0.4439      0.190      2.340      0.019       0.072       0.816
# householdIncome                                                         0.3076      0.103      2.983      0.003       0.105       0.510
# isLivingTogether_Yes                                                    0.8290      0.193      4.290      0.000       0.450       1.208
# metAs_coworkers_yes                                                    -0.7096      0.198     -3.585      0.000      -1.098      -0.322
# metThru_family_yes                                                     -0.3974      0.226     -1.756      0.079      -0.841       0.046
# partnerAge                                                              0.4430      0.100      4.440      0.000       0.247       0.639
# partnerMotherEduc_years                                                 0.2629      0.075      3.522      0.000       0.117       0.409
# sexFrequency_3_to_6_times_a_week                                        0.6965      0.311      2.239      0.025       0.087       1.306
# sexFrequency_Once_a_month_or_less                                      -0.7042      0.204     -3.450      0.001      -1.104      -0.304
# sexFrequency_Once_or_twice_a_week                                       0.6932      0.263      2.637      0.008       0.178       1.208
# timesDivorcedOrWidowed                                                 -0.1370      0.078     -1.757      0.079      -0.290       0.016
# whoEarnedMore_We_earned_about_the_same_amount                           0.4866      0.278      1.749      0.080      -0.059       1.032
# =======================================================================================================================================
# """

# %% [markdown]
# ### Backwards Elimination: Logistic Regression with (Alpha Level 0.05)

# %%
import warnings
warnings.filterwarnings('ignore')


features_to_keep = [
    "householdIncome",
    "isLivingTogether_Yes",
    "metAs_coworkers_yes",
    "partnerAge",
    "partnerMotherEduc_years",
    "sexFrequency_3_to_6_times_a_week",
    "sexFrequency_Once_a_month_or_less",
    "sexFrequency_Once_or_twice_a_week"
]


train_data = pd.concat([X_train[features_to_keep], y_train], axis=1)

# select predictors for the model
predictor_list = list(train_data.columns)

outcome_var = "relationshipQuality_isGood"

predictor_list.remove(outcome_var)

predictor_vars = " + ".join(predictor_list)


log_model = smf.logit(f"{outcome_var} ~ {predictor_vars}", data=train_data)

result = log_model.fit(method='bfgs')


result.summary()
# Out:
# Warning: Maximum number of iterations has been exceeded.
#          Current function value: 0.264344
#          Iterations: 35
#          Function evaluations: 36
#          Gradient evaluations: 36
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                Logit Regression Results
# ======================================================================================
# Dep. Variable:     relationshipQuality_isGood   No. Observations:                 2086
# Model:                                  Logit   Df Residuals:                     2077
# Method:                                   MLE   Df Model:                            8
# Date:                        Sun, 25 Sep 2022   Pseudo R-squ.:                  0.1039
# Time:                                15:10:28   Log-Likelihood:                -551.42
# converged:                              False   LL-Null:                       -615.37
# Covariance Type:                    nonrobust   LLR p-value:                 7.741e-24
# =====================================================================================================
#                                         coef    std err          z      P>|z|      [0.025      0.975]
# -----------------------------------------------------------------------------------------------------
# Intercept                             2.0366      0.228      8.937      0.000       1.590       2.483
# householdIncome                       0.3134      0.102      3.071      0.002       0.113       0.513
# isLivingTogether_Yes                  0.8388      0.193      4.354      0.000       0.461       1.216
# metAs_coworkers_yes                  -0.6509      0.194     -3.348      0.001      -1.032      -0.270
# partnerAge                            0.4386      0.092      4.747      0.000       0.257       0.620
# partnerMotherEduc_years               0.2760      0.074      3.728      0.000       0.131       0.421
# sexFrequency_3_to_6_times_a_week      0.7093      0.311      2.279      0.023       0.099       1.319
# sexFrequency_Once_a_month_or_less    -0.7120      0.202     -3.518      0.000      -1.109      -0.315
# sexFrequency_Once_or_twice_a_week     0.6962      0.262      2.660      0.008       0.183       1.209
# =====================================================================================================
# """

# %% [markdown]
# #### Can whether or not a subject has met their partner online help predict if they're likely to rate their relationship as good?

# %%
import warnings
warnings.filterwarnings('ignore')


features_to_keep = [
    "metOnline_all_yes"
]


train_data = pd.concat([X_train[features_to_keep], y_train], axis=1)

# select predictors for the model
predictor_list = list(train_data.columns)

outcome_var = "relationshipQuality_isGood"

predictor_list.remove(outcome_var)

predictor_vars = " + ".join(predictor_list)


log_model = smf.logit(f"{outcome_var} ~ {predictor_vars}", data=train_data)

result = log_model.fit(method='bfgs')


result.summary()
# Out:
# Optimization terminated successfully.
#          Current function value: 0.294996
#          Iterations: 17
#          Function evaluations: 18
#          Gradient evaluations: 18
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                Logit Regression Results
# ======================================================================================
# Dep. Variable:     relationshipQuality_isGood   No. Observations:                 2086
# Model:                                  Logit   Df Residuals:                     2084
# Method:                                   MLE   Df Model:                            1
# Date:                        Sun, 25 Sep 2022   Pseudo R-squ.:               7.245e-06
# Time:                                14:53:45   Log-Likelihood:                -615.36
# converged:                               True   LL-Null:                       -615.37
# Covariance Type:                    nonrobust   LLR p-value:                    0.9248
# =====================================================================================
#                         coef    std err          z      P>|z|      [0.025      0.975]
# -------------------------------------------------------------------------------------
# Intercept             2.3564      0.083     28.399      0.000       2.194       2.519
# metOnline_all_yes    -0.0226      0.238     -0.095      0.924      -0.489       0.444
# =====================================================================================
# """

# %% [markdown]
# ---
# ---
#
# # Step 4: Build, Test, & Compare Classification Models
#
# - Fit K-Nearest Neighbors Model
#
#     - Full Model with all features
#     - Model with only backwards elimnated features
#
# - Fit Logistic Regression Model
#
#     - Full Model with all features
#     - Model with only backwards eliminated features
#
# - Test all four models on Train & Test sets
#
#     - Confusion Matrix, F1-score, Accuracy Score

# %% [markdown]
# ### K-Nearest Neighbors - Full Model

# %%
import warnings
warnings.filterwarnings('ignore')


# Create instance of KNN --------------------
from sklearn.neighbors import KNeighborsClassifier

KNN1 = KNeighborsClassifier()

# Fit instance
KNN_full = KNN1.fit(X_train, y_train) 

print(KNN_full)
# Out:
# KNeighborsClassifier()

# %% [markdown]
# ### K-Nearest Neighbors - Backwards Eliminated Features

# %%
backwards_features = [
    "householdIncome",
    "isLivingTogether_Yes",
    "metAs_coworkers_yes",
    "partnerAge",
    "partnerMotherEduc_years",
    "sexFrequency_3_to_6_times_a_week",
    "sexFrequency_Once_a_month_or_less",
    "sexFrequency_Once_or_twice_a_week"
]

# Create instance of KNN --------------------
from sklearn.neighbors import KNeighborsClassifier

KNN2 = KNeighborsClassifier()

# Fit instance
KNN_back = KNN2.fit(X_train[backwards_features], y_train)


print(KNN_back)
# Out:
# KNeighborsClassifier()

# %% [markdown]
# ### GridSearchCV - Logistic Regression for Full Model
#
# - Using GridSearchCV to find the best parameters for Logistic Regression.
#
# - With a highly imbalanced labels, it would be best to use "balanced" class_weight.
#
# - (If we don't do this, the model might end up predicting all cases as "1" because most cases in the dataset are "1")

# %%
# Create instance of LogisticRegression --------------------
from sklearn.linear_model import LogisticRegression

log1 = LogisticRegression()

# CONDUCT GRID SEARCH ---------------------------

from sklearn.model_selection import GridSearchCV

# dictionary of parameters to search
param_grid = {
    "C": [1e-400, 1e-350, 1e-300], # default 1, Inverse of regularization strength
    "penalty": ['l1', 'l2,' 'elasticnet', 'none'],
    "class_weight": ['balanced']
} 

# grid search on all values of k in dictionary
log1_grid = GridSearchCV(log1, param_grid, cv=5)

log1_grid.fit(X_train, y_train)


# PRINT RESULTS ---------------------------

# best performing (on training set)
print("best params:\n\n", log1_grid.best_params_)

# accuracy of best performing k

print("\nbest score:\n\n", log1_grid.best_score_, "\n\n")
# Out:
# best params:
#
#  {'C': 0.0, 'class_weight': 'balanced', 'penalty': 'none'}
#
# best score:
#
#  0.718608653746859

# %% [markdown]
# ### Logistic Regression - Full Model

# %%
# Create instance of LogisticRegression --------------------
from sklearn.linear_model import LogisticRegression

log1 = LogisticRegression(C=0, 
                          class_weight="balanced",
                         penalty='none')

# Fit instance
log_full = log1.fit(X_train, y_train)

print(log_full)
# Out:
# LogisticRegression(C=0, class_weight='balanced', penalty='none')

# %% [markdown]
# ### GridSearchCV - Logistic Regression for Backwards Eliminated Features

# %%
# Create instance of LogisticRegression --------------------
from sklearn.linear_model import LogisticRegression

log2 = LogisticRegression()

# CONDUCT GRID SEARCH ---------------------------

from sklearn.model_selection import GridSearchCV

# dictionary of parameters to search
param_grid = {
    "C": [1e-400, 1e-350, 1e-300], # default 1, Inverse of regularization strength
    "penalty": ['l1', 'l2,' 'elasticnet', 'none'],
    "class_weight": ['balanced']
} 


# grid search on all values of k in dictionary
log2_grid = GridSearchCV(log2, param_grid, cv=5)

log2_grid.fit(X_train[backwards_features], y_train)


# PRINT RESULTS ---------------------------

# best performing (on training set)
print("best params:\n\n", log2_grid.best_params_)

# accuracy of best performing k

print("\nbest score:\n\n", log2_grid.best_score_, "\n\n")
# Out:
# best params:
#
#  {'C': 0.0, 'class_weight': 'balanced', 'penalty': 'none'}
#
# best score:
#
#  0.6989673333103852

# %% [markdown]
# ### Logistic Regression - Backwards Eliminated Features

# %%
backwards_features = [
    "householdIncome",
    "isLivingTogether_Yes",
    "metAs_coworkers_yes",
    "partnerAge",
    "partnerMotherEduc_years",
    "sexFrequency_3_to_6_times_a_week",
    "sexFrequency_Once_a_month_or_less",
    "sexFrequency_Once_or_twice_a_week"
]

# Create instance of LogisticRegression --------------------
from sklearn.linear_model import LogisticRegression

log2 = LogisticRegression(C=0, 
                          class_weight="balanced",
                         penalty='none')

# Fit instance
log_back = log2.fit(X_train[backwards_features], y_train)

print(log_back)
# Out:
# LogisticRegression(C=0, class_weight='balanced', penalty='none')

# %%
# CROSS VALIDATION with StratifiedShuffleSplit ------------------------------

from sklearn.model_selection import StratifiedShuffleSplit
from sklearn.model_selection import cross_val_score


sss = StratifiedShuffleSplit(n_splits=5,
                               test_size=0.2, 
                               random_state=42)

cv_scores_KNN_full = cross_val_score(KNN_full, X_train, y_train, cv=sss)
cv_scores_KNN_back = cross_val_score(KNN_back, X_train[backwards_features], y_train, cv=sss)
cv_scores_log_full = cross_val_score(log_full, X_train, y_train, cv=sss)
cv_scores_log_back = cross_val_score(log_back, X_train[backwards_features], y_train, cv=sss)

print("Cross Validation Scores on Train Sets: ---------------\n")

print("Mean of cv_scores (KNN_full): {}\n".format(np.mean(cv_scores_KNN_full)))

print("Mean of cv_scores (KNN_back): {}\n".format(np.mean(cv_scores_KNN_back)))

print("Mean of cv_scores (log_full): {}\n".format(np.mean(cv_scores_log_full)))

print("Mean of cv_scores (log_back): {}\n".format(np.mean(cv_scores_log_back)))


# CONFUSION MATRIX ------------------------------------------------------

# Predictions
y_pred_KNN_full = KNN_full.predict(X_test)
y_pred_KNN_back = KNN_back.predict(X_test[backwards_features])
y_pred_log_full = log_full.predict(X_test)
y_pred_log_back = log_back.predict(X_test[backwards_features])


# Confusion Matrix 
from sklearn.metrics import confusion_matrix

confusion_KNN_full = confusion_matrix(y_test, y_pred_KNN_full)
confusion_KNN_back = confusion_matrix(y_test, y_pred_KNN_back)
confusion_log_full = confusion_matrix(y_test, y_pred_log_full)
confusion_log_back = confusion_matrix(y_test, y_pred_log_back)

cmtx_KNN_full = pd.DataFrame(
    confusion_KNN_full, 
    index=['true: 0', 'true: 1'], 
    columns=['pred: 0', 'pred: 1']
)

cmtx_KNN_back = pd.DataFrame(
    confusion_KNN_back, 
    index=['true: 0', 'true: 1'], 
    columns=['pred: 0', 'pred: 1']
)

cmtx_log_full = pd.DataFrame(
    confusion_log_full, 
    index=['true: 0', 'true: 1'], 
    columns=['pred: 0', 'pred: 1']
)

cmtx_log_back = pd.DataFrame(
    confusion_log_back, 
    index=['true: 0', 'true: 1'], 
    columns=['pred: 0', 'pred: 1']
)

print("\nConfusion Matrix on Test Sets: ---------------")

print("\nKNN_full")
print(cmtx_KNN_full)
print("\nKNN_back")
print(cmtx_KNN_back)
print("\nlog_full")
print(cmtx_log_full)
print("\nlog_back")
print(cmtx_log_back)
print("\n")



# EVALUATION METRICS Precision, Recall, and f1-score ---------------------
from sklearn.metrics import classification_report

print("Evaluation Metrics on Test Sets: ---------------\n")


print("\nEvaluation Metrics KNN_full:")
print(classification_report(y_test, 
                            y_pred_KNN_full,
                            target_names=["0 - Subject Rated NOT Good", "1 - Subject Rated IS Good"]))

print("\nEvaluation Metrics KNN_back:")
print(classification_report(y_test, 
                            y_pred_KNN_back,
                            target_names=["0 - Subject Rated NOT Good", "1 - Subject Rated IS Good"]))

print("\nEvaluation Metrics log_full:")
print(classification_report(y_test, 
                            y_pred_log_full,
                            target_names=["0 - Subject Rated NOT Good", "1 - Subject Rated IS Good"]))

print("\nEvaluation Metrics log_back:")
print(classification_report(y_test, 
                            y_pred_log_back,
                            target_names=["0 - Subject Rated NOT Good", "1 - Subject Rated IS Good"]))
# Out:
# Cross Validation Scores on Train Sets: ---------------
#
# Mean of cv_scores (KNN_full): 0.9110047846889952
#
# Mean of cv_scores (KNN_back): 0.9095693779904306
#
# Mean of cv_scores (log_full): 0.7129186602870814
#
# Mean of cv_scores (log_back): 0.6875598086124401
#
#
# Confusion Matrix on Test Sets: ---------------
#
# KNN_full
#          pred: 0  pred: 1
# true: 0        0       48
# true: 1        2      472
#
# KNN_back
#          pred: 0  pred: 1
# true: 0        0       48
# true: 1        7      467
#
# log_full
#          pred: 0  pred: 1
# true: 0       30       18
# true: 1      126      348
#
# log_back
#          pred: 0  pred: 1
# true: 0       32       16
# true: 1      158      316
#
#
# Evaluation Metrics on Test Sets: ---------------
#
#
# Evaluation Metrics KNN_full:
#                             precision    recall  f1-score   support
#
# 0 - Subject Rated NOT Good       0.00      0.00      0.00        48
#  1 - Subject Rated IS Good       0.91      1.00      0.95       474
#
#                   accuracy                           0.90       522
#                  macro avg       0.45      0.50      0.47       522
#               weighted avg       0.82      0.90      0.86       522
#
#
# Evaluation Metrics KNN_back:
#                             precision    recall  f1-score   support
#
# 0 - Subject Rated NOT Good       0.00      0.00      0.00        48
#  1 - Subject Rated IS Good       0.91      0.99      0.94       474
#
#                   accuracy                           0.89       522
#                  macro avg       0.45      0.49      0.47       522
#               weighted avg       0.82      0.89      0.86       522
#
#
# Evaluation Metrics log_full:
#                             precision    recall  f1-score   support
#
# 0 - Subject Rated NOT Good       0.19      0.62      0.29        48
#  1 - Subject Rated IS Good       0.95      0.73      0.83       474
#
#                   accuracy                           0.72       522
#                  macro avg       0.57      0.68      0.56       522
#               weighted avg       0.88      0.72      0.78       522
#
#
# Evaluation Metrics log_back:
#                             precision    recall  f1-score   support
#
# 0 - Subject Rated NOT Good       0.17      0.67      0.27        48
#  1 - Subject Rated IS Good       0.95      0.67      0.78       474
#
#                   accuracy                           0.67       522
#                  macro avg       0.56      0.67      0.53       522
#               weighted avg       0.88      0.67      0.74       522

# %% [markdown]
# **NOTES:**
#
# Since the outcome variable of "relationshipQuality_isGood," is imbalanced, it is best to use the weighted average f1-score because it takes into account the proporation of each label in the dataset, and it is the harmonic mean of precision and recall.
#
# (Accuracy is not a good metric because if the labels are imbalanced, the model can get a high accuracy by just predicting all the same class.)
#
# **Weighted avg f1-scores:**
#
# - KNN Full Model - 86%
# - KNN Backwards Model - 86%
# - Logistic Regression Full Model - 78%
# - Logistic Regression Backwards Model - 74%
#
# I am using K-Nearest Neighbors as a benchmark to compare the Logistic model to because KNN is often a decently performing model, and it is also a simple algorithm.
#
# Logistic regression did fairly well compared to KNN.
#
# And more importantly, the backwards eliminated features still performed very well on their own. The Full Model had 109 features, and in the end we had 8 features that still accounted for about 74% of the variability in "relationshipQuality_isGood."
#
#
# - "householdIncome" coef = 0.3134
#
#     - More income, higher subject rated relationship quality
#
#
# - "isLivingTogether_Yes" coef = 0.3134
#
#     - If living together, higher subject rated relationship quality
#
#
# - "partnerAge" coef = 0.4386
#
#     - If partner & subject older, higher subject rated relationship quality
#
#
# - "partnerMotherEduc_years" coef = 0.2760
#
#     - If more education overall, higher subject rated relationship quality
#
#
# - "sexFrequency_3_to_6_times_a_week" coef = 0.7093
#
#     - If weekly sex, higher subject rated relationship quality
#
#
# - "sexFrequency_Once_or_twice_a_week" coef = 0.6962
#
#     - If weekly sex, higher subject rated relationship quality
#
#
# - "metAs_coworkers_yes" coef = -0.6509
#
#     - If met as coworkers, lower subject rated relationship quality
#
#
# - "sexFrequency_Once_a_month_or_less" coef = -0.7120
#
#     - If low frequency sex, lower subject rated relationship quality
#
#
#
# *Pluses* (Income, living together, age, education, high sex frequency)
#
#
# *Minuses* (met as coworkers, low sex frequency)

# %% [markdown]
# ---
# ---
#
# # Step 5: Conclusions

# %% [markdown]
# **NOTES:**
#
# *Pluses*
#
# - higher Income
#
# - living together
#
# - older age
#
# - Older relationships
#
# - more education
#
# - high sex frequency
#
#
# *Minuses*
#
# - household minors
#
# - met as coworkers
#
# - low sex frequency
#
# - larger age gap
