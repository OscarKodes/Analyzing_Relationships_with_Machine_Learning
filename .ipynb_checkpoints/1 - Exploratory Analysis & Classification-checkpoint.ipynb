# %% [markdown]
# # Exploratory Analysis & Classification
#
# By: Oscar Ko
#
# This notebook is created for initial data preperation on this dataset from Stanford.
#
# https://data.stanford.edu/hcmst2017
#
# ---
# ---

# %% [markdown]
# # Imports and Data

# %%
import numpy as np
import pandas as pd

import warnings
warnings.filterwarnings('ignore')


df = pd.read_csv("data/df_renamed.csv")

print(df.shape, "\n")

df.info(verbose=True)
# Out:
# (2844, 76)
#
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2844 entries, 0 to 2843
# Data columns (total 76 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   Unnamed: 0                        2844 non-null   int64
#  1   ID                                2844 non-null   int64
#  2   ageGap                            2844 non-null   float64
#  3   ageWhenMet                        2810 non-null   float64
#  4   attendReligiousServiceFreq        2844 non-null   object
#  5   employmentStatus                  2844 non-null   object
#  6   genderSubjectAttractedTo          2837 non-null   object
#  7   houseType                         2844 non-null   object
#  8   householdAdults_num               2844 non-null   int64
#  9   householdIncome                   2844 non-null   int64
#  10  householdMinor_num                2844 non-null   int64
# ...

# %% [markdown]
# # Test-Train Stratified Split
#
# - Stratified split to ensure equal proportions of all labels in both sets.
# - Use on "relationshipQuality_isGood"

# %% [markdown]
# **First drop the other two outcome labels, leaving just "relationshipQuality_isGood"**

# %%
# Remove "relationshipQuality" and "relationshipQuality_num"

df_copy = df.copy().drop(["relationshipQuality", "relationshipQuality_num"], axis=1)

success1 = "relationshipQuality_num" not in df_copy.columns
success2 = "relationshipQuality" not in df_copy.columns

print("Sucessfully removed both columns?", success1 & success2)
# Out:
# Sucessfully removed both columns? True

# %% [markdown]
# **Train-Test Stratified Split**

# %%
# import package
from sklearn.model_selection import train_test_split

# declare our X inputs and y outcomes
X = df_copy.drop("relationshipQuality_isGood", axis=1)
y = df_copy["relationshipQuality_isGood"]


# stratify split
X_train, X_test, y_train, y_test = train_test_split(X, 
                                                    y,
                                                    stratify=y, 
                                                    test_size=0.2,
                                                    random_state=42)

print("X_train.shape = ", X_train.shape)
print("X_test.shape = ", X_test.shape)

print("y_train.shape = ", y_train.shape)
print("y_test.shape = ", y_test.shape)

print("\n")
print("y_train class proportions: \n", y_train.value_counts(normalize=True))

print("\n")
print("y_test class proportions: \n", y_test.value_counts(normalize=True))
# Out:
# X_train.shape =  (2275, 73)
# X_test.shape =  (569, 73)
# y_train.shape =  (2275,)
# y_test.shape =  (569,)
#
#
# y_train class proportions:
#  1    0.90989
# 0    0.09011
# Name: relationshipQuality_isGood, dtype: float64
#
#
# y_test class proportions:
#  1    0.910369
# 0    0.089631
# Name: relationshipQuality_isGood, dtype: float64

# %% [markdown]
# ### X_train Summary Statistics

# %%
X_train.describe()
# Out:
#         Unnamed: 0            ID       ageGap   ageWhenMet  \
# count  2275.000000  2.275000e+03  2275.000000  2250.000000
# mean   1785.339341  2.175449e+06     4.370110    26.171111
# std    1010.610098  6.470539e+05     6.120972    11.241342
# min       1.000000  5.300100e+04     0.000000     0.000000
# 25%     914.500000  1.811954e+06     1.000000    18.000000
# 50%    1807.000000  2.279341e+06     3.000000    23.000000
# 75%    2653.000000  2.762445e+06     6.000000    31.000000
# max    3508.000000  2.969933e+06    86.000000    84.000000
#
#        householdAdults_num  householdIncome  householdMinor_num  \
# count          2275.000000      2275.000000         2275.000000
# mean              2.200440     93148.901099            0.560879
# std               0.895754     67842.768330            1.021820
# min               1.000000      2500.000000            0.000000
# 25%               2.000000     45000.000000            0.000000
# ...

# %% [markdown]
# ### Check the training set for missing values

# %%
# combine the X_train and y_train into a dataframe
training_set = pd.concat([X_train, y_train], axis=1)

# check records and features
print(training_set.shape)
# Out:
# (2275, 74)

# %%
# Check for any missing values
print(training_set.isnull().values.any())

# Check number of missing values
print("Count of na's:", training_set.isnull().values.sum())

# Check number of rows with missing values
print("Cases with missing values:", training_set.isna().any(axis=1).sum())
# Out:
# True
# Count of na's: 2252
# Cases with missing values: 469

# %%
pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)

training_set.isna().sum()
# Out:
# Unnamed: 0                            0
# ID                                    0
# ageGap                                0
# ageWhenMet                           25
# attendReligiousServiceFreq            0
# employmentStatus                      0
# genderSubjectAttractedTo              7
# houseType                             0
# householdAdults_num                   0
# householdIncome                       0
# householdMinor_num                    0
# householdSize                         0
# interracial                          19
# isHispanic                            0
# isLivingTogether                      0
# isMarried                             0
# isMetroArea                           0
# metAs_coworkers                      49
# metAs_customerAndClient              49
# metAs_workNeighbors                  49
# metIn_church                         49
# metIn_college                        49
# metIn_military                       49
# ...

# %% [markdown]
# ### Remove unneeded columns

# %% [markdown]
# Columns related to couples first moving in together have over 300 missing values. This is due to not all couples moving in together. Since 300 is a large chunk of our 2275 records, I will remove these columns.

# %%
columns_to_remove = [
    "moveIn_YearFraction",
    "shipStart_to_moveIn_YearFraction",
    "Unnamed: 0", # Also Remove column with no useful info
    "ID" # Also Remove column with no useful info
]

# anything done to the training set has to be done to the testing set
training_set.drop(columns_to_remove, axis=1, inplace=True)
X_train.drop(columns_to_remove, axis=1, inplace=True)
X_test.drop(columns_to_remove, axis=1, inplace=True)

# Recheck the na's
training_set.isna().sum()
# Out:
# ageGap                               0
# ageWhenMet                          25
# attendReligiousServiceFreq           0
# employmentStatus                     0
# genderSubjectAttractedTo             7
# houseType                            0
# householdAdults_num                  0
# householdIncome                      0
# householdMinor_num                   0
# householdSize                        0
# interracial                         19
# isHispanic                           0
# isLivingTogether                     0
# isMarried                            0
# isMetroArea                          0
# metAs_coworkers                     49
# metAs_customerAndClient             49
# metAs_workNeighbors                 49
# metIn_church                        49
# metIn_college                       49
# metIn_military                      49
# metIn_privateParty                  49
# metIn_public                        49
# metIn_restaurantOrBar               49
# ...

# %%
# Check all cases and columns
print(training_set.shape)

# Check number of rows with missing values
print("Cases with missing values:", training_set.isna().any(axis=1).sum())
# Out:
# (2275, 70)
# Cases with missing values: 183

# %% [markdown]
# Since 183 records is not too much compared to the 2275 in total, I will op to remove these missing values.

# %%
# Dropping NA values

def cleanDatasets(X_data, y_data):
    
    cols_with_na = X_data.columns[X_data.isna().any()].tolist()
    
    for col in cols_with_na:
        
        indexes = X_data[col].notna()
        X_data = X_data[indexes]
        y_data = y_data[indexes]
    
    # filter odd partner age cases
    age_filter = X_data["partnerAge"] > 5
    X_data = X_data[age_filter]
    y_data = y_data[age_filter]
    
    return X_data, pd.DataFrame(y_data)

# anything done to the training set has to be done to the testing set        
X_train, y_train = cleanDatasets(X_train, y_train)
X_test, y_test = cleanDatasets(X_test, y_test)


# recombine training sets
training_set = pd.concat([X_train, y_train], axis=1)


# Check all cases and columns
print(training_set.shape)

# Check number of rows with missing values
print("Cases with missing values:", training_set.isna().any(axis=1).sum())
# Out:
# (2086, 70)
# Cases with missing values: 0

# %% [markdown]
# ---
# ---
# # Exploratory Data Analysis

# %%
X_train.describe()
# Out:
#             ageGap   ageWhenMet  householdAdults_num  householdIncome  \
# count  2086.000000  2086.000000          2086.000000      2086.000000
# mean      4.057047    26.082934             2.196069     93870.445829
# std       4.683775    11.155295             0.872936     67579.043960
# min       0.000000     0.000000             1.000000      2500.000000
# 25%       1.000000    18.000000             2.000000     45000.000000
# 50%       3.000000    23.000000             2.000000     80000.000000
# 75%       5.000000    31.000000             2.000000    112500.000000
# max      45.000000    84.000000             9.000000    300000.000000
#
#        householdMinor_num  householdSize  met_YearFraction  \
# count         2086.000000    2086.000000       2086.000000
# mean             0.547459       2.743528       1994.269459
# std              1.007121       1.398147         16.799039
# min              0.000000       1.000000       1939.208400
# ...

# %%
# import visualization packages
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %% [markdown]
# ### Correlation Matrix Heatmap (Columns 0 to 45)

# %%
# limit the number of columns
corr_df = training_set.iloc[:,0:45]
corr_df["relationshipQuality_isGood"] = training_set["relationshipQuality_isGood"]

# calculate the correlation matrix
corr_matrix = corr_df.corr()

# set larger plot size
sns.set(rc = {'figure.figsize':(15,8)})

# Generate a custom diverging colormap
cmap = sns.diverging_palette(10, 133, as_cmap=True)

# plot the heatmap
sns.heatmap(corr_matrix,
            annot=True,
            cmap=cmap,
            vmin=-1, 
            vmax=1,
            xticklabels=corr_matrix.columns,
            yticklabels=corr_matrix.columns,
            center=0,
            linewidths=.5)
# Out:
# <AxesSubplot:>

# %% [markdown]
# **Notes:**
#
# - It seems most of the columns visualized here do not have much correlation with relationshipQuality_isGood.
#
# - Higher household income seems to be slightly correlated with higher rated relationships.
#
# - Number of Household size & number of minors in household are correlated because they are both based on counting household members. When using machine learning, it might be best to keep this in mind.
#
#     - (Same for met_YearFraction and PartnerAge/SubjectAge. Older couples probably met in earlier years.)
#
# ---

# %% [markdown]
# ### Correlation Matrix Heatmap (Columns 45 to 90)

# %%
# limit the number of columns
corr_df = training_set.iloc[:,45:90]
corr_df["relationshipQuality_isGood"] = training_set["relationshipQuality_isGood"]

# calculate the correlation matrix
corr_matrix = corr_df.corr()

# set larger plot size
sns.set(rc = {'figure.figsize':(15,8)})

# Generate a custom diverging colormap
cmap = sns.diverging_palette(10, 133, as_cmap=True)

# plot the heatmap
sns.heatmap(corr_matrix,
            annot=True,
            cmap=cmap,
            vmin=-1, 
            vmax=1,
            xticklabels=corr_matrix.columns,
            yticklabels=corr_matrix.columns,
            center=0,
            linewidths=.5)
# Out:
# <AxesSubplot:>

# %% [markdown]
# **Notes:**
#
# - It seems most of the columns visualized here do not have much correlation with relationshipQuality_isGood.
#
#
#     - subjectAge and education seems to have some very weak correlation with relationship quality.
#
# ---

# %% [markdown]
# ### Top positive correlations

# %%
correlations = training_set.corr()

s = correlations.unstack()

sorted_vals = s.sort_values(kind="quicksort", ascending=False)

col_count = len(correlations)

top_rows = 24

print(sorted_vals[0 + col_count: top_rows + col_count])
# Out:
# met_YearFraction            shipStart_YearFraction        0.964212
# shipStart_YearFraction      met_YearFraction              0.964212
# subjectAge                  partnerAge                    0.926556
# partnerAge                  subjectAge                    0.926556
# householdMinor_num          householdSize                 0.783710
# householdSize               householdMinor_num            0.783710
# householdAdults_num         householdSize                 0.697480
# householdSize               householdAdults_num           0.697480
# partnerParty_DemPos_RepNeg  subjectParty_DemPos_RepNeg    0.662116
# subjectParty_DemPos_RepNeg  partnerParty_DemPos_RepNeg    0.662116
# ageWhenMet                  timesDivorcedOrWidowed        0.529973
# timesDivorcedOrWidowed      ageWhenMet                    0.529973
# partnerEduc_years           subjectEduc_years             0.516242
# subjectEduc_years           partnerEduc_years             0.516242
# ...

# %% [markdown]
# **NOTES:**
#
# (Top Positive Correlations)
#
# **Interesting Findings:**
#
# - (partnerParty_DemPos_RepNeg, subjectParty_DemPos_RepNeg) People date others that have similar political ideologies.
#
# - (partnerEduc_years + subjectEduc_years) Partners and subjects education years are strongly correlated. People date others with is similar education levels.
#
# - (ageGap + ageWhenMet) The older a subject is when meeting partner, the more larger their age gap is to be.
#
# - (subjectMotherEduc_years + partnerMotherEduc_years) The education of partner's and subject's mothers are correlated too!
#
#
#     - (subjectMotherEduc_years + subjectEduc_years) Probably because the more education a mother has had, the more education the subject is likely to have had.
#
#     - (partnerEduc_years + partnerMotherEduc_years) Same as above.
#
#
# **Less interesting Findings:**
#
# - (met_YearFraction + shipStart_YearFraction) The time couples met and the time they started their relationships are correlated.
#
#
# - (partnerAge + subjectAge) Partner age and subject ages are correlated. Most people date in their age range.
#
#
# - (householdSize + householdMinor_num/householdAdults_num) All of these are are correlated since they all count members.
#
#
# - (ageWhenMet, timesDivorcedOrWidowed) Age when met and number of times divorced/widowed are correlated. The older a couple is when they met the more likely they've had a past marriage that ended.
#
# - (householdIncome, subjectEduc_years/partnerEduc_years) The more years of education the couple has had, the higher their household income tends to be.
#
# - (ageWhenMet + met_YearFraction) The older a subject is when meeting partner, the more recent the meeting year will be.
#
#
#
#
# ---

# %% [markdown]
# ### Top negative correlations

# %%
correlations = training_set.corr()

s = correlations.unstack()

sorted_vals = s.sort_values(kind="quicksort", ascending=True)

col_count = len(correlations)

top_rows = 24

print(sorted_vals[0 + col_count: top_rows + col_count])
# Out:
# subjectAge                  partnerMotherEduc_years      -0.209677
# partnerMotherEduc_years     subjectAge                   -0.209677
# partnerAge                  partnerMotherEduc_years      -0.206991
# partnerMotherEduc_years     partnerAge                   -0.206991
# ageWhenMet                  householdSize                -0.204729
# householdSize               ageWhenMet                   -0.204729
# met_to_shipStart_diff       met_YearFraction             -0.184173
# met_YearFraction            met_to_shipStart_diff        -0.184173
# ageWhenMet                  householdAdults_num          -0.163909
# householdAdults_num         ageWhenMet                   -0.163909
# ageWhenMet                  householdMinor_num           -0.142147
# householdMinor_num          ageWhenMet                   -0.142147
# isHispanic                  subjectMotherEduc_years      -0.136869
# subjectMotherEduc_years     isHispanic                   -0.136869
# ...

# %% [markdown]
# **NOTES:**
#
# (Top Negative Correlations)
#
# **Interesting Findings:**
#
# - (subjectAge, partnerMotherEduc_years) The older a subject is, the more likely they are to date a partner who has a mother with more years of education.
#
# - (partnerAge, partnerMotherEduc_years) The older a partner is, the more likely they are to have a mother with higher education.
#
# - (met_to_shipStart_diff + met_YearFraction) The more recent the year the subject met their partner, the shorter the timespan will be from moving from just meeting as strangers to being in a relationship.
#
#
#     - This is strange because a visualization by Nathan Yau shows the opposite:
#
#         - https://flowingdata.com/2019/03/19/the-relationship-timeline-continues-to-stretch/
#
#         - Maybe it was because Yau's visualization was based on median time gaps?
#
#         - Could their be some outlier couples that are skewing the data?
#
# - (isHispanic + subjectMotherEduc_years/partnerMotherEduc_years/subjectEduc_years) If a subject identified as Hispanic, their education, their mother's education, and their partner's mother's education levels are likely to be a bit lower.
#
#
# - (subjectMotherEduc_years + numOfTimesMarried) The higher a subject's mother's education is, the more likely they are to have been married at least once.
#
#
# **Less interesting Findings:**
#
# - (ageWhenMet, householdSize/householdAdults_num/householdMinor_num) The younger the subject was when meeting their partner, the larger their household size is likely to be. (Probably because older couples are more likely to have children.)
#
# - (numOfTimesMarried + met_YearFraction) A subject is more likely to be married one or more times if they met their partner longer time ago.
#
#     - Couples that met long ago probably got married and count as 1 marriage, which brings the average up.
#
# - (householdIncome, shipStart_YearFraction/met_YearFraction) The more recent a relationship has started, their household income will likely be lower. Maybe this is due to the fact that older couples had more time to accumulate wealth.
#
# - (met_YearFraction, relationshipQuality_isGood) The farther back a couple has met, the more likely the subject is to rate their relationship higher. - Lasted the test of time.
#
#
# ---

# %% [markdown]
# ### Top Positive Correlations with RelationshipQuality_isGood

# %%
label_correlations = training_set.corr()["relationshipQuality_isGood"]

sorted_vals = label_correlations.sort_values(kind="quicksort", ascending=False)

print(sorted_vals[0: 10])
# Out:
# relationshipQuality_isGood    1.000000
# householdIncome               0.102004
# subjectAge                    0.099504
# partnerEduc_years             0.088878
# partnerAge                    0.085148
# subjectEduc_years             0.074172
# partnerMotherEduc_years       0.069184
# subjectMotherEduc_years       0.041551
# met_to_shipStart_diff         0.039575
# numRelativesSeePerMonth       0.001642
# Name: relationshipQuality_isGood, dtype: float64

# %% [markdown]
# **NOTES:**
#
# (Top Positive Correlations with RelationshipQuality_isGood)
#
# **Interesting Findings:**
#
# - (householdIncome) With higher household's incomes, the subjects rated their relationship slightly higher.
#
# - (subjectAge/partnerAge) The higher a subject's or partner's age, the more likely they are to rate their relationship quality higher.
#
#
# - (partnerEduc_years/subjectEduc_years/partnerMotherEduc_years/subjectMotherEduc_years) The higher the education levels of a partner, a subject, and their mothers is the more likely they are to rate their relationship quality higher.
#
#
# - (met_to_shipStart_diff) The larger the gap between meeting their partners and starting a relationship is, the higher the subject will rate their relationship quality.
#
#
# - (numRelativesSeePerMonth) The more frequently subject sees their relatives, the higher they tend to rate their relationship with their partner.
#
#
# ---

# %% [markdown]
# ### Top Negative Correlations with RelationshipQuality_isGood

# %%
label_correlations = training_set.corr()["relationshipQuality_isGood"]

sorted_vals = label_correlations.sort_values(kind="quicksort", ascending=True)

print(sorted_vals[0: 11])
# Out:
# met_YearFraction             -0.118335
# shipStart_YearFraction       -0.109320
# householdMinor_num           -0.075959
# householdSize                -0.060212
# subjectParty_DemPos_RepNeg   -0.058733
# ageGap                       -0.053706
# isHispanic                   -0.050636
# partnerParty_DemPos_RepNeg   -0.042629
# ageWhenMet                   -0.033898
# timesDivorcedOrWidowed       -0.030248
# partyDifference              -0.014736
# Name: relationshipQuality_isGood, dtype: float64

# %% [markdown]
# **NOTES:**
#
# (Top Negative Correlations with RelationshipQuality_isGood)
#
# **Interesting Findings:**
#
# - (householdMinor_num/householdSize) The higher the number of minors in a subject's household, the lower they tend to rate their relationships.
#
# - (subjectParty_DemPos_RepNeg/partnerParty_DemPos_RepNeg) The more a subject/partner leaned more towards the democratic party, the lower the subject tended to rate their relationships.
#
#
# - (ageGap) The higher the age gap in a relationship, the lower the subject tends to rate their relationship.
#
#
# - (isHispanic) If the subject identifies as Hispanic, the lower the subject tends to rate their relationship.
#
#
# - (ageWhenMet) The higher the subject's age when met, the lower the subject tends to rate their relationship.
#
# - (timesDivorcedOrWidowed) The more times a subject has been divorced or widowed in the past, the lower the subjects tend to rate their relationships.
#
# - (partyDifference) The larger the gap between a couple's political party leanings, the lower the subjects tend to rate their relationships.
#
#
# **Less interesting Findings:**
#
# - (met_YearFraction/shipStart_YearFraction) The farther back a subject has met their partner, the higher the subject will rate their relationship.
#
#
#    - If a relationship has lasted that long to at least be their more recent relationship (whether still together or not), then it has stood the test of time.
#
#
#
# ---

# %%
training_set.hist(figsize=(20,20))
# Out:
# array([[<AxesSubplot:title={'center':'ageGap'}>,
#         <AxesSubplot:title={'center':'ageWhenMet'}>,
#         <AxesSubplot:title={'center':'householdAdults_num'}>,
#         <AxesSubplot:title={'center':'householdIncome'}>,
#         <AxesSubplot:title={'center':'householdMinor_num'}>],
#        [<AxesSubplot:title={'center':'householdSize'}>,
#         <AxesSubplot:title={'center':'met_YearFraction'}>,
#         <AxesSubplot:title={'center':'met_to_shipStart_diff'}>,
#         <AxesSubplot:title={'center':'numRelativesSeePerMonth'}>,
#         <AxesSubplot:title={'center':'partnerAge'}>],
#        [<AxesSubplot:title={'center':'partnerEduc_years'}>,
#         <AxesSubplot:title={'center':'partnerMotherEduc_years'}>,
#         <AxesSubplot:title={'center':'partnerParty_DemPos_RepNeg'}>,
#         <AxesSubplot:title={'center':'partyDifference'}>,
#         <AxesSubplot:title={'center':'shipStart_YearFraction'}>],
#        [<AxesSubplot:title={'center':'subjectAge'}>,
# ...

# %% [markdown]
# **NOTES:**
#
# - Many couples met in their 20's and 30's.
#
# - The distribution of partner ages is slightly older than subject ages
#
# - Most relationships started in recent years.
#
# - In this dataset, most subjects have been married 1 time.
#
# ---

# %% [markdown]
# ### Exploring Democrat v Republican
#
#
# #### Ages:
#
# Investigating way being more democratic seems to have subjects rate their relationships lower.
#
# Could it be that democrats are younger and republicans are older?
#
# (Older relationships have stood the test of time and other failed relationships, so it's possible that it's more of an age related issue than a political party issue.)

# %%
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.ticker import PercentFormatter




dems = training_set[training_set["subjectParty_DemPos_RepNeg"] > 0]
reps = training_set[training_set["subjectParty_DemPos_RepNeg"] < 0]



plt.hist(dems["subjectAge"], 
        bins=10, 
        alpha=0.5, 
        label='Democrat Leaning',
        color="blue",
        weights=np.ones(len(dems)) / len(dems))
plt.hist(reps["subjectAge"], 
        bins=10, 
        alpha=0.5, 
        label='Republican Leaning',
        color="red",
        weights=np.ones(len(reps)) / len(reps))

plt.gca().yaxis.set_major_formatter(PercentFormatter(1))

plt.title("Democrat and Republican Subject Ages")
plt.legend(loc='upper right')
plt.show()

# %% [markdown]
# **NOTES:**
#
# - It seems that Republicans are slightly older.

# %%
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.ticker import PercentFormatter



dems = training_set[training_set["subjectParty_DemPos_RepNeg"] > 0]
reps = training_set[training_set["subjectParty_DemPos_RepNeg"] < 0]

plt.hist(dems["ageGap"], 
        bins=6, 
        alpha=0.5, 
        label='Democrat Leaning',
        color="blue",
        weights=np.ones(len(dems)) / len(dems))

plt.hist(reps["ageGap"], 
        bins=6, 
        alpha=0.5, 
        label='Republican Leaning',
        color="red",
        weights=np.ones(len(reps)) / len(reps))

plt.gca().yaxis.set_major_formatter(PercentFormatter(1))

plt.title("Democrat and Republican Age Gaps")
plt.legend(loc='upper right')
plt.show()

# %% [markdown]
# **NOTES:**
#
# It seems couple age gaps for both parties is about the same.

# %% [markdown]
# ### Pairplots with top positive correlations with outcome label

# %%
features = ["relationshipQuality_isGood",
            "householdIncome",
            "subjectAge",
            "partnerEduc_years",
            "partnerAge",
            "met_to_shipStart_diff"
           ]

sns.pairplot(training_set[features],
            hue="relationshipQuality_isGood")

# %% [markdown]
# ### Pairplots with top negative correlations with outcome label

# %%
features = ["relationshipQuality_isGood",
            "met_YearFraction",
            "householdMinor_num",
            "subjectParty_DemPos_RepNeg",
            "ageGap",
            "timesDivorcedOrWidowed",
            "partyDifference"
           ]

sns.pairplot(training_set[features],
            hue="relationshipQuality_isGood")

# %% [markdown]
# ---
# ---
#
# # Prepare the Data for Machine Learning

# %% [markdown]
# ### One-Hot Encode Categorical Features

# %%
# First get the numeric columns and the categorical columns

numeric_features = X_train._get_numeric_data().columns

categorical_features = list(set(X_train.columns) - set(numeric_features))

print(len(X_train.columns), len(numeric_features), len(categorical_features))
# Out:
# 69 21 48

# %%
# One hot encode categorical features for the X_train and X_test sets

X_train = pd.get_dummies(X_train, columns=categorical_features, drop_first=True)
X_test = pd.get_dummies(X_test, columns=categorical_features, drop_first=True)

print(len(X_train.columns))

X_train.head(3)
# Out:
# 116
#       ageGap  ageWhenMet  householdAdults_num  householdIncome  \
# 1994     3.0        15.0                    2            45000
# 2178    17.0        42.0                    2            67500
# 2218    10.0        40.0                    1            67500
#
#       householdMinor_num  householdSize  isHispanic  met_YearFraction  \
# 1994                   0              2       False         2004.4584
# 2178                   0              2        True         2015.2916
# 2218                   0              1       False         1998.7084
#
#       met_to_shipStart_diff  numRelativesSeePerMonth  partnerAge  \
# 1994               7.916626                      1.0        31.0
# 2178               0.083374                      0.0        27.0
# 2218               0.250000                      2.0        49.0
#
#       partnerEduc_years  partnerMotherEduc_years  partnerParty_DemPos_RepNeg  \
# 1994               16.0                     17.0                          -1
# ...

# %% [markdown]
# ### Feature Scaling on Numeric Columns with Standardization

# %%
# import scaling & column transformer
from sklearn.preprocessing import StandardScaler
from sklearn.compose import ColumnTransformer

# Create a function to scale the train and test sets

def scaleCategoricalFeatures(X_data):
    
    scaler = StandardScaler()

    X_data[numeric_features] = scaler.fit_transform(X_data[numeric_features])
    
    return X_data

X_train = scaleCategoricalFeatures(X_train)
X_test = scaleCategoricalFeatures(X_test)

print(X_train.shape)
# Out:
# (2086, 116)

# %% [markdown]
# ### Make sure it worked by seeing if Standard Deviations of Numeric Columns are 1

# %%
X_train.describe()
# Out:
#              ageGap    ageWhenMet  householdAdults_num  householdIncome  \
# count  2.086000e+03  2.086000e+03         2.086000e+03     2.086000e+03
# mean  -9.822227e-17 -1.385384e-16         2.194367e-16    -1.277342e-17
# std    1.000240e+00  1.000240e+00         1.000240e+00     1.000240e+00
# min   -8.663993e-01 -2.338727e+00        -1.370496e+00    -1.352377e+00
# 25%   -6.528451e-01 -7.247565e-01        -2.246624e-01    -7.233332e-01
# 50%   -2.257368e-01 -2.764313e-01        -2.246624e-01    -2.052970e-01
# 75%    2.013716e-01  4.408889e-01        -2.246624e-01     2.757367e-01
# max    8.743539e+00  5.193135e+00         7.796171e+00     3.050931e+00
#
#        householdMinor_num  householdSize    isHispanic  met_YearFraction  \
# count        2.086000e+03   2.086000e+03  2.086000e+03      2.086000e+03
# mean        -1.889402e-16  -1.087470e-16 -2.186384e-16      1.468517e-15
# std          1.000240e+00   1.000240e+00  1.000240e+00      1.000240e+00
# ...

# %%
# alphbetize column names

X_train = X_train.sort_index(axis=1)
X_test = X_test.sort_index(axis=1)

X_train.info(verbose=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2086 entries, 1994 to 75
# Data columns (total 116 columns):
#  #    Column                                                                                                Dtype
# ---   ------                                                                                                -----
#  0    ageGap                                                                                                float64
#  1    ageWhenMet                                                                                            float64
#  2    attendReligiousServiceFreq_More than once a week                                                      uint8
#  3    attendReligiousServiceFreq_Never                                                                      uint8
#  4    attendReligiousServiceFreq_Once a week                                                                uint8
# ...

# %% [markdown]
# - White paper structure.
# - Classification types plan order.
# - Fill in code.
