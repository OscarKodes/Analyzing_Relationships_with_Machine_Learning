# %% [markdown]
# # Analyzing Relationships with Machine Learning
#
# By: Oscar Ko
#
# This notebook is created to analyze this dataset on relationships from Stanford:
#
# https://data.stanford.edu/hcmst2017
#
# ---
# ---

# %% [markdown]
# # Imports and Data

# %%
import numpy as np
import pandas as pd

import warnings
warnings.filterwarnings('ignore')


imported_data = pd.read_stata("data/HCMST 2017 fresh sample for public sharing draft v1.1.dta")

imported_data.shape
# Out:
# (3510, 285)

# %%
imported_data.info(verbose=True, show_counts=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 3510 entries, 0 to 3509
# Data columns (total 285 columns):
#  #    Column                            Non-Null Count  Dtype
# ---   ------                            --------------  -----
#  0    CaseID                            3510 non-null   int16
#  1    CASEID_NEW                        3510 non-null   int32
#  2    qflag                             3510 non-null   category
#  3    weight1                           2994 non-null   float64
#  4    weight1_freqwt                    2994 non-null   float32
#  5    weight2                           551 non-null    float64
#  6    weight1a                          3110 non-null   float64
#  7    weight1a_freqwt                   3110 non-null   float32
#  8    weight_combo                      3510 non-null   float32
#  9    weight_combo_freqwt               3510 non-null   float32
#  10   duration                          3510 non-null   int16
#  11   speed_flag                        3510 non-null   category
#  12   consent                           3510 non-null   category
#  13   xlgb                              3510 non-null   category
#  14   S1                                3510 non-null   category
#  15   S2                                1425 non-null   category
#  16   S3                                648 non-null    category
#  17   DOV_Branch                        3403 non-null   category
#  18   Q3_Refused                        9 non-null      category
#  19   Q4                                2856 non-null   category
#  20   Q5                                468 non-null    category
#  21   Q6A                               2856 non-null   category
#  22   Q6B                               2856 non-null   category
#  23   Q9                                2856 non-null   category
#  24   Q10                               2856 non-null   category
#  25   Q11                               2856 non-null   category
#  26   Q12                               2856 non-null   category
#  27   Q14                               2856 non-null   category
#  28   Q15A7                             2856 non-null   category
#  29   Q16                               2836 non-null   float64
#  30   Q16_Refused                       20 non-null     category
#  31   Q17A                              2079 non-null   category
#  32   Q17B                              777 non-null    category
#  33   Q17C                              1442 non-null   category
#  34   Q17D                              1414 non-null   category
#  35   Q19                               2856 non-null   category
#  36   Q20                               465 non-null    category
#  37   Q21A_Year                         2856 non-null   category
#  38   Q21A_Month                        2856 non-null   category
#  39   Q21B_Year                         2856 non-null   category
#  40   Q21B_Month                        2856 non-null   category
#  41   Q21C_Year                         2494 non-null   category
#  42   Q21C_Month                        2494 non-null   category
#  43   Q21D_Year                         2079 non-null   category
#  44   Q21D_Month                        2079 non-null   category
#  45   w6_identity                       2856 non-null   category
#  46   w6_outness                        425 non-null    category
#  47   w6_outness_timing                 371 non-null    category
#  48   Q23                               2856 non-null   category
#  49   Q24_Refused                       70 non-null     category
#  50   Q25                               2856 non-null   category
#  51   Q26                               1597 non-null   category
#  52   Q27                               2856 non-null   category
#  53   Q28                               2856 non-null   category
#  54   w6_friend_connect_1               2856 non-null   category
#  55   w6_friend_connect_2               2856 non-null   category
#  56   w6_friend_connect_3               2856 non-null   category
#  57   w6_friend_connect_4               2856 non-null   category
#  58   w6_friend_connect_Refused         2856 non-null   category
#  59   Q32                               2856 non-null   category
#  60   Q34                               2856 non-null   category
#  61   Q35_Refused                       220 non-null    category
#  62   w6_sex_frequency                  2856 non-null   category
#  63   w6_otherdate                      2856 non-null   category
#  64   w6_how_many                       225 non-null    category
#  65   w6_how_meet_Refused               12 non-null     category
#  66   w6_otherdate_app                  224 non-null    category
#  67   w6_how_many_app                   58 non-null     category
#  68   Past_Partner_Q1                   538 non-null    category
#  69   w6_relationship_end_nonmar        406 non-null    category
#  70   w6_breakup_nonmar                 370 non-null    category
#  71   w6_relationship_end_mar           132 non-null    category
#  72   w6_who_breakup                    68 non-null     category
#  73   Q5_2                              141 non-null    category
#  74   Q6A_2                             538 non-null    category
#  75   Q9B_2                             538 non-null    category
#  76   Q10_2                             538 non-null    category
#  77   Q11_2                             538 non-null    category
#  78   Q12_2                             538 non-null    category
#  79   Q14_2                             538 non-null    category
#  80   Q15A7_2_1                         538 non-null    category
#  81   Q16_2                             538 non-null    category
#  82   Q16_2_Codes                       7 non-null      category
#  83   Q17B_2                            538 non-null    category
#  84   Q17C_2                            280 non-null    category
#  85   Q17D_2                            258 non-null    category
#  86   Q20_2                             538 non-null    category
#  87   Q21A_2_Year                       538 non-null    category
#  88   Q21A_2_Month                      538 non-null    category
#  89   Q21B_2_Year                       538 non-null    category
#  90   Q21B_2_Month                      538 non-null    category
#  91   Q21C_2_Year                       234 non-null    category
#  92   Q21C_2_Month                      234 non-null    category
#  93   Q21D_2_Year                       132 non-null    category
#  94   Q21D_2_Month                      132 non-null    category
#  95   Q21E_2_Year                       438 non-null    category
#  96   Q21E_2_Month                      438 non-null    category
#  97   Q21F_2_start_range                525 non-null    category
#  98   Q21F_2_Year                       100 non-null    category
#  99   Q21F_2_Month                      100 non-null    category
#  100  w6_identity_2                     538 non-null    category
#  101  w6_outness_2                      125 non-null    category
#  102  w6_outness_timing_2               108 non-null    category
#  103  Q23_2                             538 non-null    category
#  104  Q25_2                             538 non-null    category
#  105  Q26_2                             202 non-null    category
#  106  Q27_2                             538 non-null    category
#  107  Q28_2                             538 non-null    category
#  108  w6_friend_connect_2_1             538 non-null    category
#  109  w6_friend_connect_2_2             538 non-null    category
#  110  w6_friend_connect_2_3             538 non-null    category
#  111  w6_friend_connect_2_4             538 non-null    category
#  112  w6_friend_connect_2_Refused       538 non-null    category
#  113  Q32_2                             538 non-null    category
#  114  w6_otherdate_2                    538 non-null    category
#  115  w6_how_many_2                     104 non-null    category
#  116  w6_otherdate_app_2                101 non-null    category
#  117  w6_how_many_app_2                 40 non-null     category
#  118  partyid7                          3394 non-null   category
#  119  PERSNET_hom                       3510 non-null   category
#  120  ppc10017                          3510 non-null   category
#  121  ppc21310                          3510 non-null   category
#  122  ppp20071                          3394 non-null   category
#  123  ppp20072                          3394 non-null   category
#  124  ppage                             3510 non-null   category
#  125  ppagecat                          3510 non-null   category
#  126  ppagect4                          3510 non-null   category
#  127  ppeduc                            3510 non-null   category
#  128  ppeducat                          3510 non-null   category
#  129  ppethm                            3510 non-null   category
#  130  ppgender                          3510 non-null   category
#  131  pphhhead                          3510 non-null   category
#  132  pphhsize                          3510 non-null   category
#  133  pphouse                           3510 non-null   category
#  134  ppincimp                          3510 non-null   category
#  135  ppmarit                           3510 non-null   category
#  136  ppmsacat                          3510 non-null   category
#  137  PPREG4                            3510 non-null   category
#  138  ppreg9                            3510 non-null   category
#  139  pprent                            3510 non-null   category
#  140  PPT01                             3510 non-null   category
#  141  PPT25                             3510 non-null   category
#  142  PPT612                            3510 non-null   category
#  143  PPT1317                           3510 non-null   category
#  144  PPT18OV                           3510 non-null   category
#  145  ppwork                            3510 non-null   category
#  146  Race_1                            3510 non-null   category
#  147  Race_2                            3510 non-null   category
#  148  Race_3                            3510 non-null   category
#  149  Race_4                            3510 non-null   category
#  150  Race_5                            3510 non-null   category
#  151  Race_6                            3510 non-null   category
#  152  race1                             3510 non-null   category
#  153  race2                             3510 non-null   category
#  154  race3                             3510 non-null   category
#  155  race4                             3510 non-null   category
#  156  race5                             3510 non-null   category
#  157  race6                             3510 non-null   category
#  158  race7                             3510 non-null   category
#  159  race8                             3510 non-null   category
#  160  race9                             3510 non-null   category
#  161  race10                            3510 non-null   category
#  162  race11                            3510 non-null   category
#  163  race12                            3510 non-null   category
#  164  race13                            3510 non-null   category
#  165  race14                            3510 non-null   category
#  166  race15                            3510 non-null   category
#  167  w6_took_the_survey                3510 non-null   category
#  168  w6_prior_identity_lgb             3394 non-null   category
#  169  w6_same_sex_couple                3394 non-null   category
#  170  w6_same_sex_couple_gender         3394 non-null   category
#  171  w6_q4                             3394 non-null   category
#  172  w6_q5                             609 non-null    category
#  173  w6_q6a                            3394 non-null   category
#  174  w6_q6b                            3394 non-null   category
#  175  w6_q9                             3374 non-null   float64
#  176  w6_q10                            3394 non-null   category
#  177  w6_q11                            3394 non-null   category
#  178  w6_q12                            3394 non-null   category
#  179  w6_q14                            3394 non-null   category
#  180  w6_q15a1_truncated                3394 non-null   category
#  181  w6_q15a4_truncated                3394 non-null   category
#  182  w6_q15a7                          3394 non-null   category
#  183  w6_q16                            3367 non-null   float64
#  184  w6_q17                            3385 non-null   float64
#  185  w6_attraction                     3381 non-null   category
#  186  w6_q19                            2856 non-null   category
#  187  w6_q20                            1003 non-null   category
#  188  w6_q21a_year                      3341 non-null   float64
#  189  w6_q21a_month                     3350 non-null   category
#  190  w6_q21a_month_flag                3341 non-null   category
#  191  w6_q21b_year                      3276 non-null   float64
#  192  w6_q21b_month                     3301 non-null   category
#  193  w6_q21b_month_flag                3301 non-null   float64
#  194  w6_q21c_year                      2630 non-null   float64
#  195  w6_q21c_month                     2649 non-null   category
#  196  w6_q21c_month_flag                80 non-null     float64
#  197  w6_q21d_year                      2169 non-null   float64
#  198  w6_q21d_month                     2123 non-null   category
#  199  w6_q21e_year                      410 non-null    float64
#  200  w6_q21e_month                     395 non-null    category
#  201  w6_q21f_year                      96 non-null     float64
#  202  w6_q21f_month                     90 non-null     category
#  203  w6_identity_all                   3394 non-null   category
#  204  w6_outness_all                    550 non-null    category
#  205  w6_outness_timing_all             476 non-null    float64
#  206  w6_q23                            3394 non-null   category
#  207  w6_q24_length                     3394 non-null   float32
#  208  w6_q25                            3394 non-null   category
#  209  w6_q26                            1799 non-null   float64
#  210  w6_q27                            3394 non-null   category
#  211  w6_q28                            3394 non-null   category
#  212  w6_friend_connect_1_all           3394 non-null   category
#  213  w6_friend_connect_2_all           3394 non-null   category
#  214  w6_friend_connect_3_all           3394 non-null   category
#  215  w6_friend_connect_4_all           3394 non-null   category
#  216  w6_q32                            3394 non-null   category
#  217  w6_q34                            2856 non-null   category
#  218  w6_otherdate_all                  3394 non-null   category
#  219  w6_how_many_all                   329 non-null    category
#  220  w6_otherdate_app_all              325 non-null    category
#  221  w6_how_many_app_all               98 non-null     category
#  222  w6_number_people_met              3359 non-null   float32
#  223  w6_otherdate_dichotomous          3363 non-null   category
#  224  w6_married                        3394 non-null   category
#  225  relate_duration_at_w6_years       2765 non-null   float32
#  226  w6_number_people_met_app          323 non-null    float32
#  227  weight_combo_v2                   3510 non-null   float32
#  228  partnership_status                3510 non-null   category
#  229  female                            3510 non-null   int8
#  230  year_fraction_met                 3341 non-null   float32
#  231  year_fraction_relstart            3276 non-null   float32
#  232  age_when_met                      3341 non-null   float32
#  233  time_from_met_to_rel              3263 non-null   float32
#  234  year_fraction_first_cohab         2630 non-null   float32
#  235  time_from_rel_to_cohab            2578 non-null   float32
#  236  hcm2017q24_R_cowork               3295 non-null   category
#  237  hcm2017q24_R_friend               3295 non-null   category
#  238  hcm2017q24_R_family               3295 non-null   category
#  239  hcm2017q24_R_sig_other            3295 non-null   category
#  240  hcm2017q24_R_neighbor             3295 non-null   category
#  241  hcm2017q24_P_cowork               3295 non-null   category
#  242  hcm2017q24_P_friend               3295 non-null   category
#  243  hcm2017q24_P_family               3295 non-null   category
#  244  hcm2017q24_P_sig_other            3295 non-null   category
#  245  hcm2017q24_P_neighbor             3295 non-null   category
#  246  hcm2017q24_btwn_I_cowork          3295 non-null   category
#  247  hcm2017q24_btwn_I_friend          3295 non-null   category
#  248  hcm2017q24_btwn_I_family          3295 non-null   category
#  249  hcm2017q24_btwn_I_sig_other       3295 non-null   category
#  250  hcm2017q24_btwn_I_neighbor        3295 non-null   category
#  251  hcm2017q24_school                 3295 non-null   category
#  252  hcm2017q24_college                3295 non-null   category
#  253  hcm2017q24_mil                    3295 non-null   category
#  254  hcm2017q24_church                 3295 non-null   category
#  255  hcm2017q24_vol_org                3295 non-null   category
#  256  hcm2017q24_customer               3295 non-null   category
#  257  hcm2017q24_bar_restaurant         3295 non-null   category
#  258  hcm2017q24_party                  3295 non-null   category
#  259  hcm2017q24_internet_other         3295 non-null   category
#  260  hcm2017q24_internet_dating        3295 non-null   category
#  261  hcm2017q24_internet_soc_network   3295 non-null   category
#  262  hcm2017q24_internet_game          3295 non-null   category
#  263  hcm2017q24_internet_chat          3295 non-null   category
#  264  hcm2017q24_internet_org           3295 non-null   category
#  265  hcm2017q24_public                 3295 non-null   category
#  266  hcm2017q24_blind_date             3295 non-null   category
#  267  hcm2017q24_vacation               3295 non-null   category
#  268  hcm2017q24_single_serve_nonint    3295 non-null   category
#  269  hcm2017q24_business_trip          3295 non-null   category
#  270  hcm2017q24_work_neighbors         3295 non-null   category
#  271  hcm2017q24_met_online             3394 non-null   category
#  272  hcm2017_q24_length                3394 non-null   float32
#  273  hcm2017q24_summary_all_codes      3295 non-null   float64
#  274  w6_relationship_quality           2847 non-null   category
#  275  hcm2017q24_met_through_family     3295 non-null   category
#  276  hcm2017q24_met_through_friend     3295 non-null   category
#  277  hcm2017q24_met_through_as_nghbrs  3295 non-null   category
#  278  hcm2017q24_met_as_through_cowork  3295 non-null   category
#  279  w6_subject_race                   3494 non-null   category
#  280  interracial_5cat                  3365 non-null   category
#  281  partner_mother_yrsed              3323 non-null   float32
#  282  subject_mother_yrsed              3378 non-null   float32
#  283  partner_yrsed                     3383 non-null   float32
#  284  subject_yrsed                     3510 non-null   float32
# dtypes: category(243), float32(20), float64(18), int16(2), int32(1), int8(1)
# memory usage: 1.7 MB

# %% [markdown]
# # Select Specific Features to Keep
#
# - Q4 and w6_q4 contain subject's partner's gender, but only w6_q4 contains gender for couples that are still together AND couples that are broken up.
#
#     - w6_q4 will be selected to use. Q4 will not be used.
#
# All the Q's are combined into the w6's

# %%
features = [
    

    "CASEID_NEW", # ID
    "w6_sex_frequency", # sexFrequency
    "ppp20072", # attendReligiousServiceFreq
    "pphhsize", # household size
    "pphouse", # type of house
    "ppincimp", # household income
    "ppmsacat", # metro area
    "pprent", # own, rent, other
    "ppwork", # employment status
    "w6_q15a1_truncated", # subject grew up in US?
    "w6_q15a4_truncated", # subject's living country when met partner
    "w6_q16", # how many relatives subject sees per month?
    "w6_q17", # how many times has subject been married?
    "w6_q23", # Who earned more (in 2016 or when last together)
    "interracial_5cat", # based on w6_subject_race and w6_q6b
    "w6_q32", # did you use an Internet service to meet partner?
    "age_when_met", # age when met in years,=ppage-(2017- w6_q21a_year)
    "w6_q4", # partner gender
    "partyid7", # subject's political party
    "w6_q12", # partner's political party
    "ppgender", # subject gender
    "S1", # isMarried
    "ppage", # subject age
    "w6_q9", # partner's age in 2017
    "ppeducat", # subject education
    "subject_yrsed", # RECODE of ppeduc (Education (Highest Degree Received))
    "partner_yrsed", # RECODE of w6_q10 (partner's educational attainment)
    "partner_mother_yrsed", # RECODE of w6_q11 (partner's mother's Education)
    "w6_subject_race", # based on single races Race_x
    "w6_q6b", # partner's race
    "PPREG4", # region
    "w6_same_sex_couple_gender", # same sex couple specific (0=straight, 1=gay, 2=lesbian)
    "w6_attraction", # what gender(s) subject attracted to?
    "w6_q19", # couple living together?
    "w6_q34", # how would you describe the quality of your relationship with partner?
    "w6_identity_all", # subject sexual identity
    "PPT01", # household member age (number of babies in household ages 0-1)
    "PPT25", # household member age (number of toddlers in household ages 2-5)
    "PPT612", # household member age (number of children in household ages 6-12)
    "PPT1317", # household member age (number of teens in household ages 13-17)
    "PPT18OV", # household member age (number of adults in household ages 18+)
    
    # Year/Month of Relationship Stages  ---------------------------- 
    
    "w6_q21a_year", # year subject first met partner
    "w6_q21a_month", # month subject first met partner
    "w6_q21b_year", # year subject began romantic relationship w partner
    "w6_q21b_month", # month subject began romantic relationship w partner
    "w6_q21c_year", # year subject first lived with partner
    "w6_q21c_month", # month subject first lived with partner
    "w6_q21d_year", # year subject married partner
    "w6_q21d_month", # month subject married partner
    "w6_q21e_year", # year of breakup
    "w6_q21e_month", # month of breakup
    "w6_q21f_year", # year partner died
    "w6_q21f_month", # month partner died
    
    # (Fractions) Year/Month of Relationship Stages ---------------
    
    "year_fraction_met", # w6_q21a_year+((w6_q21a_month-0.5)/12)
    "year_fraction_relstart", # w6_q21b_year+((w6_q21b_month-0.5)/12)
    "time_from_met_to_rel", # year_fraction_relstart-year_fraction_met
    "year_fraction_first_cohab", # w6_q21c_year+((w6_q21c_month-0.5)/12)
    "time_from_rel_to_cohab", # year_fraction_first_cohab-year_fraction_relstart, neg reset to zero
    
    
    # Met in person -----------------------------------------------
    
    "w6_q25", # did subject and partner attend same H.S.
    "w6_q26", # did subject and partner attend same college
    "w6_q27", # did subject and partner grow up in same city or town
    "w6_q28", # did subject's parents know partner's parents before subject knew partner?
    "w6_friend_connect_1_all", # subject knew partner's friends before meeting partner
    "w6_friend_connect_2_all", # partner knew subjects friends before meeting subject
    "w6_friend_connect_3_all", # subject's friends knew partner's friends before subject and partner met
    "w6_friend_connect_4_all", # no prior connection between subject's friends and partner's friends
    
    "hcm2017q24_R_cowork", # Respondent's coworker: indermediary or partner
    "hcm2017q24_R_friend", # Respondent's friend: intermediary
    "hcm2017q24_R_family", # Respondent's family: intermediary
    "hcm2017q24_R_sig_other", # Respondent's (current or past) Significant Other: Intermediary
    "hcm2017q24_R_neighbor", # Respondent's residential neighbor: intermediary or Partner
    "hcm2017q24_P_cowork", # Partner's coworker: Intermediary or Respondent
    "hcm2017q24_P_friend", # Partner's Friend: Intermediary
    "hcm2017q24_P_family", # Partner's Family: Intermediary
    "hcm2017q24_P_sig_other", # Partner's (current or past) Significant Other: Intermediary
    "hcm2017q24_P_neighbor", # Partner's residential neighbor: Intermediary or Respondent
    
    "hcm2017q24_met_through_family", # 1 if R_family or P_family =1
    "hcm2017q24_met_through_friend", # 1 if R_friend or P_friend=1
    "hcm2017q24_met_through_as_nghbrs", # 1 if R_neighbor or P_neighbor=1
    "hcm2017q24_met_as_through_cowork", # 1 if R_cowork or P_cowork=1

    "hcm2017q24_school", # met in primary or secondary school
    "hcm2017q24_college", # met in college
    "hcm2017q24_mil", # met during military service
    "hcm2017q24_church", # met in or through church or religious organization
    "hcm2017q24_vol_org", # met through voluntary organization (non-church)
    "hcm2017q24_customer", # customer-client relationship
    "hcm2017q24_bar_restaurant", # restaurant, or othe public social gathering place
    "hcm2017q24_party", # private party
    
    "hcm2017q24_public", # met in public place
    "hcm2017q24_blind_date", # met on blind date
    "hcm2017q24_vacation", # met while on vacation
    "hcm2017q24_single_serve_nonint", # non internet single service
    "hcm2017q24_business_trip", # met while on business trip
    "hcm2017q24_work_neighbors", # met as work neighbors
    
    # Met online / dating app -----------------------------------------------
    
    "hcm2017q24_internet_other", # Internet, not otherwise classified
    "hcm2017q24_internet_dating", # met through Internet dating or phone app
    "hcm2017q24_internet_soc_network", # met through internet social networking
    
    "hcm2017q24_internet_game", # met through online gaming
    "hcm2017q24_internet_chat", # met through Internet chat
    "hcm2017q24_internet_org", # met through Internet site not mainly dedicated to dating

    "hcm2017q24_met_online", # met online, all kinds


    # to be filtered ---------------------
    
    "qflag", # DOV: Qualification Flag - Remove 2
    "speed_flag", # Respondents who completed survey in under 2 min - Remove under 2
    "S3", # Ever had a boyfriend or a girlfriend - Remove "No"
    "w6_took_the_survey", # Whether subject took the survey or was excluded
    "partnership_status", # Filter out 4 (never had) married, parner, ex
    
    
    # to be recoded ----------------------
    
    "w6_q10", # partner's education # RECODE THIS TO MATCH PPEDUCAT
    "w6_q11", # partner's mother's education # RECODE THIS TO MATCH PPEDUCAT
    
    "ppethm", # subject is Hispanic -- convert to binary
    "w6_q6a", # partner is Hispanic -- convert to binary
    

]

df = imported_data[features]

pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

df.head(3)
# Out:
#    CASEID_NEW      w6_sex_frequency               ppp20072 pphhsize  \
# 0     2014039                   NaN                  Never        1
# 1     2019003  Once a month or less                  Never        4
# 2     2145527  2 to 3 times a month  Once or twice a month        5
#
#                                             pphouse              ppincimp  \
# 0  A one-family house detached from any other house    $40,000 to $49,999
# 1  A one-family house detached from any other house  $150,000 to $174,999
# 2  A one-family house detached from any other house  $200,000 to $249,999
#
#   ppmsacat                                             pprent  \
# 0    Metro  Owned or being bought by you or someone in you...
# 1    Metro  Owned or being bought by you or someone in you...
# 2    Metro  Owned or being bought by you or someone in you...
#
#                          ppwork               w6_q15a1_truncated  \
# 0  Working - as a paid employee                    United States
# 1           Not working - other                    United States
# 2  Working - as a paid employee  Another country, please specify
#
#                 w6_q15a4_truncated  w6_q16  w6_q17  \
# 0                    United States     1.0     1.0
# 1                    United States     1.0     1.0
# 2  Another country, please specify     0.0     1.0
#
#                        w6_q23 interracial_5cat  \
# 0               I earned more               no
# 1  [Partner Name] earned more               no
# 2               I earned more               no
#
#                                               w6_q32  age_when_met  \
# 0  Yes, an Internet dating or matchmaking site (l...          30.0
# 1  No, I did NOT meet [Partner Name] through the ...          21.0
# 2  Yes, an Internet dating or matchmaking site (l...          36.0
#
#                       w6_q4               partyid7            w6_q12 ppgender  \
# 0    [Partner Name] is Male         Leans Democrat  Leans Republican     Male
# 1    [Partner Name] is Male  Not Strong Republican  Leans Republican   Female
# 2  [Partner Name] is Female         Leans Democrat    Leans Democrat     Male
#
#                      S1 ppage  w6_q9                     ppeducat  \
# 0  No, I am not Married    30   26.0                 Some college
# 1     Yes, I am Married    55   52.0  Bachelor's degree or higher
# 2     Yes, I am Married    47   45.0  Bachelor's degree or higher
#
#    subject_yrsed  partner_yrsed  partner_mother_yrsed w6_subject_race w6_q6b  \
# 0           14.0           12.0                  12.0           White  White
# 1           17.0           17.0                  12.0           White  White
# 2           17.0           14.0                   9.0           White  White
#
#       PPREG4 w6_same_sex_couple_gender  \
# 0  Northeast           gay male couple
# 1    Midwest             hetero couple
# 2      South             hetero couple
#
#                                  w6_attraction w6_q19     w6_q34  \
# 0  sexually attracted to men and women equally    NaN        NaN
# 1   sexually attracted only to opposite gender    Yes  Excellent
# 2   sexually attracted only to opposite gender    Yes       Good
#
#             w6_identity_all PPT01 PPT25 PPT612 PPT1317 PPT18OV  w6_q21a_year  \
# 0                  bisexual     0     0      0       0       1        2017.0
# 1  heterosexual or straight     0     0      0       2       2        1983.0
# 2  heterosexual or straight     0     1      2       0       2        2006.0
#
#   w6_q21a_month  w6_q21b_year w6_q21b_month  w6_q21c_year w6_q21c_month  \
# 0         March        2017.0         March           NaN           NaN
# 1           May        1995.0        August        1996.0      February
# 2       January        2006.0          June        2006.0          July
#
#    w6_q21d_year w6_q21d_month  w6_q21e_year w6_q21e_month  w6_q21f_year  \
# 0           NaN           NaN        2017.0          June           NaN
# 1        1996.0      February           NaN           NaN           NaN
# 2        2008.0           May           NaN           NaN           NaN
#
#   w6_q21f_month  year_fraction_met  year_fraction_relstart  \
# 0           NaN        2017.208374             2017.208374
# 1           NaN        1983.375000             1995.625000
# 2           NaN        2006.041626             2006.458374
#
#    time_from_met_to_rel  year_fraction_first_cohab  time_from_rel_to_cohab  \
# 0              0.000000                        NaN                     NaN
# 1             12.250000                1996.125000                0.500000
# 2              0.416748                2006.541626                0.083252
#
#                   w6_q25  w6_q26 w6_q27 w6_q28 w6_friend_connect_1_all  \
# 0  Different High School     NaN     No     No                      no
# 1  Different High School     2.0     No     No                      no
# 2  Different High School     2.0     No     No                      no
#
#   w6_friend_connect_2_all w6_friend_connect_3_all w6_friend_connect_4_all  \
# 0                      no                      no                     yes
# 1                      no                      no                     yes
# 2                      no                      no                     yes
#
#   hcm2017q24_R_cowork hcm2017q24_R_friend hcm2017q24_R_family  \
# 0                  no                  no                  no
# 1                 yes                  no                  no
# 2                  no                  no                  no
#
#   hcm2017q24_R_sig_other hcm2017q24_R_neighbor hcm2017q24_P_cowork  \
# 0                     no                    no                  no
# 1                     no                    no                 yes
# 2                     no                    no                  no
#
#   hcm2017q24_P_friend hcm2017q24_P_family hcm2017q24_P_sig_other  \
# 0                  no                  no                     no
# 1                  no                  no                     no
# 2                  no                  no                     no
#
#   hcm2017q24_P_neighbor hcm2017q24_met_through_family  \
# 0                    no                            no
# 1                    no                            no
# 2                    no                            no
#
#   hcm2017q24_met_through_friend hcm2017q24_met_through_as_nghbrs  \
# 0                            no                               no
# 1                            no                               no
# 2                            no                               no
#
#   hcm2017q24_met_as_through_cowork hcm2017q24_school hcm2017q24_college  \
# 0                               no                no                 no
# 1                              yes                no                 no
# 2                               no                no                 no
#
#   hcm2017q24_mil hcm2017q24_church hcm2017q24_vol_org hcm2017q24_customer  \
# 0             no                no                 no                  no
# 1             no                no                 no                  no
# 2             no                no                 no                  no
#
#   hcm2017q24_bar_restaurant hcm2017q24_party hcm2017q24_public  \
# 0                        no               no                no
# 1                        no               no                no
# 2                       yes               no                no
#
#   hcm2017q24_blind_date hcm2017q24_vacation hcm2017q24_single_serve_nonint  \
# 0                    no                  no                             no
# 1                    no                  no                             no
# 2                    no                  no                             no
#
#   hcm2017q24_business_trip hcm2017q24_work_neighbors  \
# 0                       no                        no
# 1                       no                        no
# 2                       no                        no
#
#   hcm2017q24_internet_other hcm2017q24_internet_dating  \
# 0                        no                        yes
# 1                        no                         no
# 2                       yes                         no
#
#   hcm2017q24_internet_soc_network hcm2017q24_internet_game  \
# 0                              no                       no
# 1                              no                       no
# 2                              no                       no
#
#   hcm2017q24_internet_chat hcm2017q24_internet_org hcm2017q24_met_online  \
# 0                       no                      no                   yes
# 1                       no                      no                    no
# 2                       no                      no                   yes
#
#        qflag                          speed_flag   S3 w6_took_the_survey  \
# 0  Qualified  Completed survey in over 2 minutes  Yes    took the survey
# 1  Qualified  Completed survey in over 2 minutes  NaN    took the survey
# 2  Qualified  Completed survey in over 2 minutes  NaN    took the survey
#
#                   partnership_status              w6_q10              w6_q11  \
# 0  unpartnered, has had past partner  HS graduate or GED  HS graduate or GED
# 1                            married     Masters degree  HS graduate or GED
# 2                            married    Associate degree           9th grade
#
#                 ppethm                       w6_q6a
# 0  White, Non-Hispanic  No (Not Latino or Hispanic)
# 1  White, Non-Hispanic  No (Not Latino or Hispanic)
# 2  White, Non-Hispanic  No (Not Latino or Hispanic)

# %%
df.info(verbose=True, show_counts=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 3510 entries, 0 to 3509
# Data columns (total 115 columns):
#  #    Column                            Non-Null Count  Dtype
# ---   ------                            --------------  -----
#  0    CASEID_NEW                        3510 non-null   int32
#  1    w6_sex_frequency                  2856 non-null   category
#  2    ppp20072                          3394 non-null   category
#  3    pphhsize                          3510 non-null   category
#  4    pphouse                           3510 non-null   category
#  5    ppincimp                          3510 non-null   category
#  6    ppmsacat                          3510 non-null   category
#  7    pprent                            3510 non-null   category
#  8    ppwork                            3510 non-null   category
#  9    w6_q15a1_truncated                3394 non-null   category
#  10   w6_q15a4_truncated                3394 non-null   category
#  11   w6_q16                            3367 non-null   float64
#  12   w6_q17                            3385 non-null   float64
#  13   w6_q23                            3394 non-null   category
#  14   interracial_5cat                  3365 non-null   category
#  15   w6_q32                            3394 non-null   category
#  16   age_when_met                      3341 non-null   float32
#  17   w6_q4                             3394 non-null   category
#  18   partyid7                          3394 non-null   category
#  19   w6_q12                            3394 non-null   category
#  20   ppgender                          3510 non-null   category
#  21   S1                                3510 non-null   category
#  22   ppage                             3510 non-null   category
#  23   w6_q9                             3374 non-null   float64
#  24   ppeducat                          3510 non-null   category
#  25   subject_yrsed                     3510 non-null   float32
#  26   partner_yrsed                     3383 non-null   float32
#  27   partner_mother_yrsed              3323 non-null   float32
#  28   w6_subject_race                   3494 non-null   category
#  29   w6_q6b                            3394 non-null   category
#  30   PPREG4                            3510 non-null   category
#  31   w6_same_sex_couple_gender         3394 non-null   category
#  32   w6_attraction                     3381 non-null   category
#  33   w6_q19                            2856 non-null   category
#  34   w6_q34                            2856 non-null   category
#  35   w6_identity_all                   3394 non-null   category
#  36   PPT01                             3510 non-null   category
#  37   PPT25                             3510 non-null   category
#  38   PPT612                            3510 non-null   category
#  39   PPT1317                           3510 non-null   category
#  40   PPT18OV                           3510 non-null   category
#  41   w6_q21a_year                      3341 non-null   float64
#  42   w6_q21a_month                     3350 non-null   category
#  43   w6_q21b_year                      3276 non-null   float64
#  44   w6_q21b_month                     3301 non-null   category
#  45   w6_q21c_year                      2630 non-null   float64
#  46   w6_q21c_month                     2649 non-null   category
#  47   w6_q21d_year                      2169 non-null   float64
#  48   w6_q21d_month                     2123 non-null   category
#  49   w6_q21e_year                      410 non-null    float64
#  50   w6_q21e_month                     395 non-null    category
#  51   w6_q21f_year                      96 non-null     float64
#  52   w6_q21f_month                     90 non-null     category
#  53   year_fraction_met                 3341 non-null   float32
#  54   year_fraction_relstart            3276 non-null   float32
#  55   time_from_met_to_rel              3263 non-null   float32
#  56   year_fraction_first_cohab         2630 non-null   float32
#  57   time_from_rel_to_cohab            2578 non-null   float32
#  58   w6_q25                            3394 non-null   category
#  59   w6_q26                            1799 non-null   float64
#  60   w6_q27                            3394 non-null   category
#  61   w6_q28                            3394 non-null   category
#  62   w6_friend_connect_1_all           3394 non-null   category
#  63   w6_friend_connect_2_all           3394 non-null   category
#  64   w6_friend_connect_3_all           3394 non-null   category
#  65   w6_friend_connect_4_all           3394 non-null   category
#  66   w6_otherdate_all                  3394 non-null   category
#  67   w6_how_many_all                   329 non-null    category
#  68   w6_otherdate_app_all              325 non-null    category
#  69   w6_how_many_app_all               98 non-null     category
#  70   w6_number_people_met_app          323 non-null    float32
#  71   qflag                             3510 non-null   category
#  72   speed_flag                        3510 non-null   category
#  73   S3                                648 non-null    category
#  74   w6_took_the_survey                3510 non-null   category
#  75   partnership_status                3510 non-null   category
#  76   w6_q10                            3394 non-null   category
#  77   w6_q11                            3394 non-null   category
#  78   ppethm                            3510 non-null   category
#  79   w6_q6a                            3394 non-null   category
#  80   hcm2017q24_R_cowork               3295 non-null   category
#  81   hcm2017q24_R_friend               3295 non-null   category
#  82   hcm2017q24_R_family               3295 non-null   category
#  83   hcm2017q24_R_sig_other            3295 non-null   category
#  84   hcm2017q24_R_neighbor             3295 non-null   category
#  85   hcm2017q24_P_cowork               3295 non-null   category
#  86   hcm2017q24_P_friend               3295 non-null   category
#  87   hcm2017q24_P_family               3295 non-null   category
#  88   hcm2017q24_P_sig_other            3295 non-null   category
#  89   hcm2017q24_P_neighbor             3295 non-null   category
#  90   hcm2017q24_school                 3295 non-null   category
#  91   hcm2017q24_college                3295 non-null   category
#  92   hcm2017q24_mil                    3295 non-null   category
#  93   hcm2017q24_church                 3295 non-null   category
#  94   hcm2017q24_vol_org                3295 non-null   category
#  95   hcm2017q24_customer               3295 non-null   category
#  96   hcm2017q24_bar_restaurant         3295 non-null   category
#  97   hcm2017q24_party                  3295 non-null   category
#  98   hcm2017q24_internet_other         3295 non-null   category
#  99   hcm2017q24_internet_dating        3295 non-null   category
#  100  hcm2017q24_internet_soc_network   3295 non-null   category
#  101  hcm2017q24_internet_game          3295 non-null   category
#  102  hcm2017q24_internet_chat          3295 non-null   category
#  103  hcm2017q24_internet_org           3295 non-null   category
#  104  hcm2017q24_public                 3295 non-null   category
#  105  hcm2017q24_blind_date             3295 non-null   category
#  106  hcm2017q24_vacation               3295 non-null   category
#  107  hcm2017q24_single_serve_nonint    3295 non-null   category
#  108  hcm2017q24_business_trip          3295 non-null   category
#  109  hcm2017q24_work_neighbors         3295 non-null   category
#  110  hcm2017q24_met_online             3394 non-null   category
#  111  hcm2017q24_met_through_family     3295 non-null   category
#  112  hcm2017q24_met_through_friend     3295 non-null   category
#  113  hcm2017q24_met_through_as_nghbrs  3295 non-null   category
#  114  hcm2017q24_met_as_through_cowork  3295 non-null   category
# dtypes: category(94), float32(10), float64(10), int32(1)
# memory usage: 795.2 KB

# %%
imported_data["Q5"].unique()
# Out:
# [NaN, 'No, we are an opposite-sex couple', 'Yes, we are a same-sex couple']
# Categories (2, object): ['Yes, we are a same-sex couple' < 'No, we are an opposite-sex couple']

# %%
imported_data["w6_q5"].unique()
# Out:
# ['Yes, we are a same-sex couple', NaN, 'No, we are an opposite-sex couple']
# Categories (2, object): ['Yes, we are a same-sex couple' < 'No, we are an opposite-sex couple']

# %%
filterNone_Q = imported_data["Q5"].isnull()
filterNone_w6 = imported_data["w6_q5"].isnull()

imported_data[filterNone_Q & filterNone_w6]

# %%
male_Q4 = df["Q4"] == "[Partner Name] is Male"
female_w6_q4 = df["w6_q4"] == "[Partner Name] is Female"

female_Q4 = df["Q4"] == "[Partner Name] is Female"
male_w6_q4 = df["w6_q4"] == "[Partner Name] is Male"

df[(male_Q4 & female_w6_q4) | (female_Q4 & male_w6_q4)]
# Out:
# Empty DataFrame
# Columns: [CASEID_NEW, Q4, w6_q4]
# Index: []

# %%
imported_data[['Q20', 'Q20_2', 'w6_q20']].head()
# Out:
#    Q20 Q20_2 w6_q20
# 0  NaN    No     No
# 1  NaN   NaN    NaN
# 2  NaN   NaN    NaN
# 3  NaN    No     No
# 4  NaN   NaN    NaN

# %%
imported_data[['Q20', 'Q20_2', 'w6_q20']].tail()
# Out:
#       Q20 Q20_2 w6_q20
# 3505  NaN   NaN    NaN
# 3506   No   NaN     No
# 3507  NaN   NaN    NaN
# 3508  NaN   NaN    NaN
# 3509  NaN   NaN    NaN

# %%
imported_data[['w6_identity', 'w6_identity_2']].head()
# Out:
#                 w6_identity w6_identity_2
# 0                       NaN      bisexual
# 1  heterosexual or straight           NaN
# 2  heterosexual or straight           NaN
# 3                       NaN      bisexual
# 4  heterosexual or straight           NaN

# %%
imported_data[['ppgender', 'female']].head()
# Out:
#   ppgender  female
# 0     Male       0
# 1   Female       1
# 2     Male       0
# 3   Female       1
# 4   Female       1

# %%
imported_data[['S1', 'ppmarit', "w6_married"]].head()
# Out:
#                      S1        ppmarit w6_married
# 0  No, I am not Married       Divorced         no
# 1     Yes, I am Married        Married        yes
# 2     Yes, I am Married        Married        yes
# 3  No, I am not Married  Never married         no
# 4     Yes, I am Married        Married        yes

# %%
imported_data[['ppage', 'ppagecat', "ppagect4"]].head()
# Out:
#   ppage ppagecat ppagect4
# 0    30    25-34    30-44
# 1    55    55-64    45-59
# 2    47    45-54    45-59
# 3    28    25-34    18-29
# 4    59    55-64    45-59

# %%
imported_data[['ppeduc', 'ppeducat', "subject_yrsed"]].head()
# Out:
#                   ppeduc                     ppeducat  subject_yrsed
# 0       Associate degree                 Some college           14.0
# 1         Masters degree  Bachelor's degree or higher           17.0
# 2         Masters degree  Bachelor's degree or higher           17.0
# 3  12th grade NO DIPLOMA        Less than high school           12.0
# 4       Bachelors degree  Bachelor's degree or higher           16.0

# %%
imported_data[['w6_q10', 'partner_yrsed']].head(10)
# Out:
#                              w6_q10  partner_yrsed
# 0                HS graduate or GED           12.0
# 1                   Masters degree           17.0
# 2                  Associate degree           14.0
# 3                HS graduate or GED           12.0
# 4                 Bachelors degree           16.0
# 5                 Bachelors degree           16.0
# 6           Some college, no degree           13.0
# 7  Professional or Doctorate degree           20.0
# 8                               NaN            NaN
# 9             12th grade no diploma           12.0

# %%
imported_data[['ppethm', 'w6_subject_race']].head(10)
# Out:
#                 ppethm         w6_subject_race
# 0  White, Non-Hispanic                   White
# 1  White, Non-Hispanic                   White
# 2  White, Non-Hispanic                   White
# 3  White, Non-Hispanic                   White
# 4  White, Non-Hispanic                   White
# 5  White, Non-Hispanic                   White
# 6  White, Non-Hispanic                   White
# 7  White, Non-Hispanic                   White
# 8  White, Non-Hispanic                   White
# 9             Hispanic  Other (please specify)

# %%
print(imported_data['ppethm'].unique())

print(imported_data['w6_subject_race'].unique())
# Out:
# ['White, Non-Hispanic', 'Hispanic', 'Black, Non-Hispanic', '2+ Races, Non-Hispanic', 'Other, Non-Hispanic']
# Categories (5, object): ['White, Non-Hispanic' < 'Black, Non-Hispanic' < 'Other, Non-Hispanic' < 'Hispanic' < '2+ Races, Non-Hispanic']
# ['White', 'Other (please specify)', 'Black or African American', 'Asian or Pacific Islander', 'American Indian, Aleut, or Eskimo', NaN]
# Categories (5, object): ['White' < 'Black or African American' < 'American Indian, Aleut, or Eskimo' < 'Asian or Pacific Islander' < 'Other (please specify)']

# %%
print(list(imported_data['w6_q6a'].unique()))

print(list(imported_data['w6_q6b'].unique()))
# Out:
# ['No (Not Latino or Hispanic)', nan, 'Yes, Mexican, Mexican American, Chicano', 'Yes, Other Latino/Hispanic', 'Yes, Puerto Rican', 'Yes, Cuban', 'Refused']
# ['White', nan, 'Other (please specify)', 'Asian or Pacific Islander', 'Black or African American', 'American Indian, Aleut, or Eskimo', 'Refused']

# %%
imported_data[['w6_q5', 'w6_same_sex_couple', 'w6_same_sex_couple_gender']].head(10)
# Out:
#                                w6_q5   w6_same_sex_couple  \
# 0      Yes, we are a same-sex couple      same_sex_couple
# 1                                NaN  NOT same-sex souple
# 2                                NaN  NOT same-sex souple
# 3      Yes, we are a same-sex couple      same_sex_couple
# 4                                NaN  NOT same-sex souple
# 5  No, we are an opposite-sex couple  NOT same-sex souple
# 6                                NaN  NOT same-sex souple
# 7                                NaN  NOT same-sex souple
# 8                                NaN                  NaN
# 9                                NaN  NOT same-sex souple
#
#   w6_same_sex_couple_gender
# 0           gay male couple
# 1             hetero couple
# 2             hetero couple
# 3            lesbian couple
# 4             hetero couple
# 5             hetero couple
# 6             hetero couple
# 7             hetero couple
# 8                       NaN
# 9             hetero couple

# %%
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

imported_data[["w6_attraction"]].head(10)
# Out:
#                                        w6_attraction
# 0        sexually attracted to men and women equally
# 1         sexually attracted only to opposite gender
# 2         sexually attracted only to opposite gender
# 3  sexually attracted mostly to same gender, some...
# 4  sexually attracted mostly to opposite gender, ...
# 5             sexually attracted only to same gender
# 6         sexually attracted only to opposite gender
# 7         sexually attracted only to opposite gender
# 8                                                NaN
# 9         sexually attracted only to opposite gender

# %%
print(list(imported_data["w6_attraction"].unique()))
# Out:
# ['sexually attracted to men and women equally', 'sexually attracted only to opposite gender', 'sexually attracted mostly to same gender, sometimes opposite gender', 'sexually attracted mostly to opposite gender, sometimes same gender', 'sexually attracted only to same gender', nan]

# %%
imported_data[['w6_q19', 'w6_q20']].head()
# Out:
#   w6_q19 w6_q20
# 0    NaN     No
# 1    Yes    NaN
# 2    Yes    NaN
# 3    NaN     No
# 4    Yes    NaN

# %%
imported_data[['w6_q34', 'w6_relationship_quality']].tail()
# Out:
#          w6_q34 w6_relationship_quality
# 3505  Excellent               excellent
# 3506       Good                    good
# 3507       Good                    good
# 3508       Good                    good
# 3509       Fair                    fair

# %%
imported_data[["w6_identity", "w6_identity_2", "w6_identity_all"]].head(10)
# Out:
#                 w6_identity             w6_identity_2  \
# 0                       NaN                  bisexual
# 1  heterosexual or straight                       NaN
# 2  heterosexual or straight                       NaN
# 3                       NaN                  bisexual
# 4  heterosexual or straight                       NaN
# 5                  bisexual                       NaN
# 6  heterosexual or straight                       NaN
# 7  heterosexual or straight                       NaN
# 8                       NaN                       NaN
# 9                       NaN  heterosexual or straight
#
#             w6_identity_all
# 0                  bisexual
# 1  heterosexual or straight
# 2  heterosexual or straight
# 3                  bisexual
# 4  heterosexual or straight
# 5                  bisexual
# 6  heterosexual or straight
# 7  heterosexual or straight
# 8                       NaN
# 9  heterosexual or straight
